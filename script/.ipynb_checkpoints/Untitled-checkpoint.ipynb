# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("AFFINITY_API_KEY") 

list_id = 219127

# %%
api_key
# Out:
# 'ut0qdYC5KQlvfchZNaTVsqceUxGO9UqTHFceUQMb8f4'

# %%
def add_global_to_affinity(website_url, source, inbound_boolean):
    # Fetch the organization ID by domain
    url = f"https://api.affinity.co/organizations?term={website_url}"
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    organizations = response.json().get("organizations", [])
    organization_id = None
    for organization in organizations:
        if organization.get("domain", "") == website_url:
            organization_id = organization.get("id", "")
            break

    # Fetch field IDs for "Source" and "Inbound Boolean"
    url = f"https://api.affinity.co/organizations/fields"
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    fields = response.json()
    field_id_source = None
    field_id_inbound = None

    for field in fields:
        if field.get("name", "") == "Source":
            field_id_source = field.get("id", "")
        elif field.get("name", "") == "Inbound Boolean":
            field_id_inbound = field.get("id", "")

    # Update the "Source" field
    url = "https://api.affinity.co/field-values"
    data_source = {"field_id": field_id_source, "entity_id": organization_id, "entity_type": "organization", "value": source}
    requests.post(url, auth=HTTPBasicAuth('', api_key), json=data_source)

    # Update the "Inbound Boolean" field
    data_inbound = {"field_id": field_id_inbound, "entity_id": organization_id, "entity_type": "organization", "value": inbound_boolean}
    requests.post(url, auth=HTTPBasicAuth('', api_key), json=data_inbound)

    return

# %%
add_global_to_affinity("thenewone.com", "Form Inbound", "Yes")

# %%
import requests
from requests.auth import HTTPBasicAuth
import os

api_key = os.getenv("AFFINITY_API_KEY")

def affinity_company_data(body):
    # Extract list_id and list_entry_id from the body
    list_id = body.get('field', {}).get('list_id')
    list_entry_id = body.get('list_entry_id')

    # Construct the API URL to get the list entry
    url = f'https://api.affinity.co/lists/{list_id}/list-entries/{list_entry_id}'
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    list_entry_data = response.json()

    # Get entity details from the list entry
    entity_id = list_entry_data.get('entity_id')

    # Get organization data
    organization_url = f'https://api.affinity.co/organizations/{entity_id}'
    org_response = requests.get(organization_url, auth=HTTPBasicAuth('', api_key))
    organization_data = org_response.json()

    organization_name = organization_data.get('name')
    website_url = organization_data.get('domain') or organization_data.get('url')
    person_ids = organization_data.get('person_ids', [])

    # Retrieve global organization fields
    fields_url = "https://api.affinity.co/organizations/fields"
    fields_response = requests.get(fields_url, auth=HTTPBasicAuth('', api_key))
    fields = fields_response.json()

    # Find "Inbound Boolean" field ID
    inbound_boolean_field_id = None
    for field in fields:
        if field.get("name") == "Inbound Boolean":
            inbound_boolean_field_id = field.get("id")
            break
            
    # Retrieve "Inbound Boolean" field value for the organization
    inbound_boolean_value = None
    if inbound_boolean_field_id:
        field_values_url = f"https://api.affinity.co/field-values?field_id={inbound_boolean_field_id}&organization_id={entity_id}&entity_type=organization"
        field_values_response = requests.get(field_values_url, auth=HTTPBasicAuth('', api_key))
        field_values_data = field_values_response.json()
        if field_values_data:
            inbound_boolean_value = field_values_data[0].get('value')

    # Initialize list to store contact information
    contacts = []

    # Fetch person details for each associated person
    for person_id in person_ids:
        person_url = f'https://api.affinity.co/persons/{person_id}'
        person_response = requests.get(person_url, auth=HTTPBasicAuth('', api_key))
        person_data = person_response.json()
        
        first_name = person_data.get('first_name')
        last_name = person_data.get('last_name')
        primary_email = person_data.get('primary_email')

        if not primary_email:
            emails = person_data.get('emails', [])
            primary_email = emails[0] if emails else None

        contact_info = {
            'FirstName': first_name,
            'LastName': last_name,
            'Email': primary_email
        }
        contacts.append(contact_info)

    # Compile the company information
    company_info = {
        'Name': organization_name,
        'Website URL': website_url,
        'Inbound Boolean': inbound_boolean_value,
        'Contacts': contacts
    }

    return company_info

# %%
body = {'id': 13695568989, 'field_id': 4101993, 'list_entry_id': 172736498, 'entity_type': 1, 'value_type': 7, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:14.990-07:00', 'updated_at': '2024-10-30T02:25:53.825-07:00', 'value': {'id': 16652933, 'text': 'To be contacted', 'rank': 3, 'color': 1}, 'field': {'id': 4101993, 'name': 'Status', 'list_id': 219127, 'enrichment_source': 'none', 'value_type': 7, 'allows_multiple': False, 'track_changes': True, 'dropdown_options': [{'id': 11642141, 'text': 'New', 'rank': 1, 'color': 0}, {'id': 16811002, 'text': 'To screen', 'rank': 2, 'color': 2}, {'id': 16652933, 'text': 'To be contacted', 'rank': 3, 'color': 1}, {'id': 15097555, 'text': 'Contacted', 'rank': 4, 'color': 1}, {'id': 16811001, 'text': 'Meeting planned', 'rank': 5, 'color': 3}, {'id': 11414054, 'text': 'Long list', 'rank': 6, 'color': 3}, {'id': 11414055, 'text': 'Short list', 'rank': 7, 'color': 3}, {'id': 11414056, 'text': 'TS diligence', 'rank': 8, 'color': 3}, {'id': 11414057, 'text': 'Final diligence', 'rank': 9, 'color': 3}, {'id': 11414062, 'text': 'Rejected', 'rank': 10, 'color': 6}, {'id': 16822482, 'text': 'No answer', 'rank': 11, 'color': 5}, {'id': 11414060, 'text': 'Nurture bucket', 'rank': 12, 'color': 5}]}}

# %%
affinity_company_data(body)
# Out:
# [{'id': 13695568816, 'field_id': 3909168, 'list_entry_id': None, 'entity_type': 1, 'value_type': 5, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.024-07:00', 'updated_at': None, 'value': None}, {'id': 13695568819, 'field_id': 3909161, 'list_entry_id': None, 'entity_type': 1, 'value_type': 2, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:14.990-07:00', 'updated_at': None, 'value': None}, {'id': 13695568820, 'field_id': 3909161, 'list_entry_id': None, 'entity_type': 1, 'value_type': 2, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:14.990-07:00', 'updated_at': None, 'value': None}, {'id': 13695568822, 'field_id': 3909161, 'list_entry_id': None, 'entity_type': 1, 'value_type': 2, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:14.990-07:00', 'updated_at': None, 'value': None}, {'id': 13695568823, 'field_id': 3909161, 'list_entry_id': None, 'entity_type': 1, 'value_type': 2, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:14.990-07:00', 'updated_at': None, 'value': None}, {'id': 13695568824, 'field_id': 3909161, 'list_entry_id': None, 'entity_type': 1, 'value_type': 2, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:14.990-07:00', 'updated_at': None, 'value': None}, {'id': 13695568827, 'field_id': 3909165, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.042-07:00', 'updated_at': None, 'value': None}, {'id': 13695568845, 'field_id': 4779122, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.083-07:00', 'updated_at': None, 'value': 33.0}, {'id': 13695568854, 'field_id': 4779121, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.089-07:00', 'updated_at': None, 'value': 33.0}, {'id': 13695568873, 'field_id': 4779120, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.094-07:00', 'updated_at': None, 'value': 33.0}, {'id': 13695568877, 'field_id': 4779119, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.101-07:00', 'updated_at': None, 'value': 34.0}, {'id': 13695568880, 'field_id': 4779118, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.107-07:00', 'updated_at': None, 'value': 31.0}, {'id': 13695568883, 'field_id': 4779117, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.117-07:00', 'updated_at': None, 'value': 22.0}, {'id': 13695568887, 'field_id': 4779114, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.125-07:00', 'updated_at': None, 'value': 0.0}, {'id': 13695568888, 'field_id': 4779113, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.135-07:00', 'updated_at': None, 'value': 0.0}, {'id': 13695568893, 'field_id': 4779112, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.142-07:00', 'updated_at': None, 'value': 0.0}, {'id': 13695568901, 'field_id': 4779111, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.151-07:00', 'updated_at': None, 'value': 0.0}, {'id': 13695568904, 'field_id': 4779110, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.159-07:00', 'updated_at': None, 'value': 0.0}, {'id': 13695568906, 'field_id': 4779109, 'list_entry_id': None, 'entity_type': 1, 'value_type': 3, 'entity_id': 283125178, 'created_at': '2024-10-29T10:00:15.173-07:00', 'updated_at': None, 'value': 0.0}, {'id': 13695568910, 'field_id': 4779108, 'list_entry_id': None, 'entity_type': 1, 'value_ty ...
# {'Name': 'CANNAVIGIA',
#  'Website URL': 'cannavigia.com',
#  'Inbound Boolean': None,
#  'Contacts': []}

# %%
api_key = "e55323a4d96bf60e80271616cb652fe5"
campaigns_url = "https://api.lemlist.com/api/campaigns"
response = requests.get(campaigns_url, auth=HTTPBasicAuth('', api_key))

# %%
import requests
from requests.auth import HTTPBasicAuth
import os

# Define your campaign name and API key
campaign_name = "Outreach Automation"
api_key = os.getenv("LEMLIST_API_KEY")

def lemlist_export(company_info):
    # URL to get the list of campaigns

    api_key = "e55323a4d96bf60e80271616cb652fe5"
    campaigns_url = "https://api.lemlist.com/api/campaigns"
    response = requests.get(campaigns_url, auth=HTTPBasicAuth('', api_key))
    print(response.json())
    campaign_lists = response.json()
    campaign_id = None
    for campaign_list in campaign_lists:
        if campaign_list.get("name", "") == campaign_name:
            campaign_id = campaign_list.get("_id", "")
            break

    # Extract company details
    company_name = company_info.get('Name', '')
    company_domain = company_info.get('Website URL', '')

    # Iterate over each contact in the company_info
    for contact in company_info.get('Contacts', []):
        first_name = contact.get('FirstName', '')
        last_name = contact.get('LastName', '')
        email = contact.get('Email', '')
        params_value = 'true' if email is None or "@" not in email else 'false'

        # Construct the API endpoint URL for each lead
        url = f"https://api.lemlist.com/api/campaigns/{campaign_id}/leads"
        params = {'findEmail': params_value, 'verifyEmail': params_value}
        payload = {"firstName": first_name, "lastName": last_name, "email": email, "companyName": company_name, "companyDomain": company_domain}
        requests.request("POST", url, auth=HTTPBasicAuth('', api_key), params=params, json=payload)

    return

# %%
company_info = {"Name": "Entourage", "Website URL": "entourage.io", "Contacts":[{"FirstName": "Alexander", "LastName": "Wynaendts", "Email": "alexander.wynaendts@entourage.io"}, {"FirstName": "Pieter", "LastName": "jan", "Email": "pj@entourage.io"}]}
lemlist_export(company_info)
# Out:
# [{'_id': 'cam_HnLTA94fCQnNQE924', 'name': 'Outreach Automation', 'createdAt': '2024-10-28T11:03:02.317Z', 'createdBy': 'usr_b6iWbLkNcBRLSoieg', 'status': 'draft'}]

# %%
meeting_id = "EdrQWlrkVM2XeAma"
the_summary = fireflies_transcript_processing(meeting_id)
print(the_summary)
# Out:
# ('## Summary\n\n**Founders**  \n- Lars Moll: Co-founder and CEO, responsible for sales, marketing, and finance.  \n- Alexander: Co-founder and CTO, technical lead with experience in B2B and SaaS companies.  \n\n**One-line description**  \nNana AI offers a browser extension that protects personal data and intellectual property during AI usage, ensuring compliance with EU regulations.\n\n**Traction**  \n- Targeted ARR by year-end: 180-200k  \n- Projected total revenue for next year: 800k  \n- Currently no revenue; piloting several B2B projects that are unpaid as they aim to convert these into clients.\n\n**Why them?**  \nThe founders have relevant experience, particularly Alexander\'s background with two B2B and SaaS exits. Lars\'s expertise in the media and tech space, combined with their drive to integrate compliance with enterprise AI usage, positions them well to solve the identified problems.\n\n**Why now?**  \nThe increasing awareness and regulatory framework around data protection in AI, particularly in Europe with laws such as the EU AI Act, make Nana AI\'s solution timely and relevant for enterprises looking to maintain compliance while harnessing AI technology.\n\n**Too hyped?**  \nWhile AI and data privacy solutions are trending, the specific approach of enabling organizations to use AI while maintaining compliance is not overly hyped; it meets a real market need.\n\n**Too greedy?**  \nThe growth plans appear realistic. With structured pricing and targeted revenue goals, the ARR and revenue forecasts seem achievable given their market focus.\n\n## In-depth part:\n\n**ICP**  \n- Ideal Customer Profile: B2B companies, particularly in the legal, finance, and healthcare sectors, looking for compliance solutions related to data protection.  \n- Company size: Medium to large enterprises, interested in a multi-seat licensing model.  \n- Geography: Primarily Germany and the EU.\n\n**Addressed problem**  \nNana AI addresses the issue of data privacy violations in AI usage, a major concern for enterprises under scrutiny due to increasing regulations. Approximately 70% of companies in Germany report such violations.\n\n**Team**  \n- Lars Moll: Extensive experience in media and digital departments, focusing on B2B SaaS and startup ecosystems.  \n- Alexander: Expertise in technical roles, previously led two exits in B2B/SaaS, understanding of data compliance and user needs.\n\n**Market**  \nThe market focuses on enterprise software solutions that ensure compliance with data regulations while utilizing AI technologies. The B2B sector in the EU, with a particular emphasis on the DACH region, is experiencing increased demand for such services.\n\n**Sales**  \nThey are currently engaging in unpaid pilot projects with legal and financial agencies, aiming to convert these into paying clients by the end of the year. They aim to close five clients as part of their go-to-market strategy.\n\n**Product**  \nNana AI\'s product is a browser extension that masks personal and sensitive data while employees use large language models (LLMs). It consists of a "shield" for data protection, "guardrails" for usage compliance, and an analytics cockpit for monitoring AI interaction by employees.\n\n**Competition**  \nCompetitors in the space include other compliance and data protection software solutions. Nana AI differentiates itself through its unique enablement platform that not only protects data but also facilitates AI usage among employees without hindering productivity.\n\n**Problems?**  \nThere are no specific IP or cap table issues mentioned during the call; however, the founders need to navigate their product development in line with regulatory requirements.\n\n**Current funding situation**  \n- Previous funding: Angel investment of approximately 300k euros with a post-money valuation of 2.5 million euros.  \n- Type: Angel investment.\n\n**Raising funding**  \nNana AI is seeking to raise between 1.5 to 2 million euros at a valuation of 10 mill ...

# %%
import requests
import openai
import os

fireflies_api_key = os.getenv("FIREFLIES_API_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")

def gpt_fireflies_formatting(output):
    # Defining the prompt structure with the transcript and summary included in the content
    prompt = f"""
You are a venture capitalist investing in early-stage B2B companies. Given the following meeting data, including meeting notes and transcript, organize the data into the format below. Each question should be answered as analytically as possible, only using the provided data. Do not add any information not explicitly mentioned. Be critical in your responses and make the layout easy to copy and paste.

Meeting Data:
{output}

TEMPLATE:

Summary

Founders
{{List each founder with their title and a one-line description. Only list founders, not team members or advisors.}}

One-line description
{{Provide a one-line description of what the startup does.}}

Traction
{{Briefly mention key metrics if provided, including ARR and projected ARR, non-recurring revenue and projected revenue, the number of pilot projects (indicating if they are paid), and any relevant extra information.}}

Why them?
{{Analyze if the founders are a strong fit for the company and problem.}}

Why now?
{{Discuss why the product is viable now, including any recent changes in the world that may benefit it.}}

Too hyped?
{{Evaluate if the sector or product is overhyped, and whether the funding expectations are realistic.}}

Too greedy?
{{Assess if the founders’ growth plans are realistic and sufficiently ambitious.}}

In-depth part:

ICP
{{Describe the Ideal Customer Profile, including company size, geography, contract size, and other relevant data.}}

Addressed problem
{{Define the problem the startup addresses, and indicate its scale.}}

Team
{{List relevant experience for each team member (up to one paragraph each).}}

Market
{{Identify the market, its size, and what the company aims to capture.}}

Sales
{{Summarize their sales pipeline, if mentioned.}}

Product
{{Provide a description of the product.}}

Competition
{{Mention any competitors and briefly describe how they are similar or different from the startup.}}

Problems?
{{List any IP or cap table issues, or other specific problems if mentioned.}}

Current funding situation
{{Summarize previous funding details, including amount, valuation, funding type, and funders if available.}}

Raising funding
{{Describe their current fundraising efforts, including the amount, funding type, valuation or equity offered, timeline, and any commitments or lead/follow search.}}

Q&A
{{List any questions and answers from the call, excluding small talk.}}
"""

    # Sending the prompt to the GPT API for analysis and formatting
    response = openai.ChatCompletion.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
    )
    fireflies_note = response['choices'][0]['message']['content'].strip()
    return fireflies_note

def fireflies_transcript_processing(transcript_id):
    url = 'https://api.fireflies.ai/graphql'
    headers = {'Content-Type': 'application/json', 'Authorization': f'Bearer {fireflies_api_key}'}
    query = '''
    query Transcript($transcriptId: String!) {
      transcript(id: $transcriptId) {
        id
        title
        dateString
        speakers {
          id
          name
        }
        sentences {
          index
          speaker_name
          text
          start_time
          end_time
        }
        duration
        summary {
          gist
          bullet_gist
        }
        meeting_attendees {
          displayName
          email
          phoneNumber
          name
          location
        }
      }
    }
    '''
    variables = {"transcriptId": transcript_id}
    response = requests.post(url, headers=headers, json={"query": query, "variables": variables})

    data = response.json()

    # Extract speakers
    speakers = [speaker['name'] for speaker in data['data']['transcript']['speakers']]

    # Extract transcript sentences
    sentences = data['data']['transcript']['sentences']
    transcript_text = [sentence['text'] for sentence in sentences]

    # Extract summary
    summary = data['data']['transcript']['summary']['gist']
    bullet_summary = data['data']['transcript']['summary']['bullet_gist']

    # Extract the first email not ending in '@entourage.io'
    meeting_attendees = data['data']['transcript']['meeting_attendees']
    non_entourage_email = next(
        (attendee['email'] for attendee in meeting_attendees if attendee['email'] and not attendee['email'].endswith('@entourage.io')),
        None
    )
    website_url = non_entourage_email.split('@')[1] if non_entourage_email else "No valid email found"

    # Format the output and store it in a string
    output = f"Speakers: {', '.join(speakers)}\n\nTranscript:\n"
    output += "\n".join(f"- {sentence}" for sentence in transcript_text)
    output += f"\n\nSummary:\n{summary}\n\nDetailed Summary:\n{bullet_summary}"

    fireflies_note = gpt_fireflies_formatting(output)

    return fireflies_note, website_url

# %%
import requests
import openai
import os

fireflies_api_key = os.getenv("FIREFLIES_API_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")

def gpt_fireflies_formatting(output):
    prompt = f"""{output}"""
    response = openai.ChatCompletion.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
    )
    fireflies_note = response['choices'][0]['message']['content'].strip()
    return fireflies_note

def fireflies_transcript_processing(transcript_id):
    url = 'https://api.fireflies.ai/graphql'
    headers = {'Content-Type': 'application/json', 'Authorization': f'Bearer {fireflies_api_key}'}
    query = '''
    query Transcript($transcriptId: String!) {
      transcript(id: $transcriptId) {
        id
        title
        dateString
        speakers {
          id
          name
        }
        sentences {
          index
          speaker_name
          text
          start_time
          end_time
        }
        duration
        summary {
          gist
          bullet_gist
        }
        meeting_attendees {
          displayName
          email
          phoneNumber
          name
          location
        }
      }
    }
    '''
    variables = {"transcriptId": transcript_id}
    response = requests.post(url, headers=headers, json={"query": query, "variables": variables})

    data = response.json()

    # Extract speakers
    speakers = [speaker['name'] for speaker in data['data']['transcript']['speakers']]

    # Extract transcript sentences
    sentences = data['data']['transcript']['sentences']
    transcript_text = [sentence['text'] for sentence in sentences]

    # Extract summary
    summary = data['data']['transcript']['summary']['gist']
    bullet_summary = data['data']['transcript']['summary']['bullet_gist']

    # Extract the first email not ending in '@entourage.io'
    meeting_attendees = data['data']['transcript']['meeting_attendees']
    non_entourage_email = next(
        (attendee['email'] for attendee in meeting_attendees if attendee['email'] and not attendee['email'].endswith('@entourage.io')),
        None
    )
    website_url = non_entourage_email.split('@')[1] if non_entourage_email else "No valid email found"

    # Format the output and store it in a string
    output = f"Speakers: {', '.join(speakers)}\n\nTranscript:\n"
    output += "\n".join(f"- {sentence}" for sentence in transcript_text)
    output += f"\n\nSummary:\n{summary}\n\nDetailed Summary:\n{bullet_summary}"

    #fireflies_note = gpt_fireflies_formatting(output)

    return output, website_url

# %%
meeting_id = "EdrQWlrkVM2XeAma"
fireflies_transcript_processing(meeting_id)
# Out:
# ("Speakers: Lars, Tibe Habils\n\nTranscript:\n- Thank you.\n- Hello.\n- How's it going?\n- Going great.\n- The weather is good, so, you know, it's not hard to be happy for today.\n- All right, where are you located?\n- Ghent, Belgium.\n- I don't know if you're familiar.\n- Okay, okay.\n- You're Berlin based, right?\n- Okay.\n- So you probably have like around the same weather as we have here in Belgium.\n- Like a lot of rain.\n- A lot.\n- But normally a lot of rain and gray.\n- Yeah, yeah.\n- No, no.\n- Nice to hear.\n- Yeah.\n- No, I came across what you're doing, I think, through LinkedIn and I was intrigued.\n- We were looking like, or we're starting to look a bit into the space of like the AI.\n- Like, I don't know how you specifically would call the subsection that you're working in, but we're looking at the privacy protection in AI and like the.\n- Just in general, how enterprises can use it and was intrigued.\n- So, yeah, I don't know how familiar you are with us from the other perspective.\n- So if it's okay, I'll give a quick introduction.\n- So we're both up to speed.\n- So you know what our investment thesis is and.\n- Yeah, just interrupt me if anything would be unclear.\n- Yeah, Great.\n- Yeah.\n- So quickly.\n- Entourage itself.\n- The idea itself started a bit before Entourage Ito by our managing partner, Peter Gambaze, founding and leading a company called Chopin, which is a B2B SaaS company.\n- He led that from 0 to 100 million plus ARR during 12 years.\n- Ish.\n- And in that period he also did a lot of angel investments that kind of grew out to be the idea of Entourage.\n- Entourage is of course, not only Patreon.\n- We also have two other amazing partners who are also former show patterns.\n- We have the former cto Machten, who leads more of our studio effort.\n- The studio part is where we still work on our own ideas, have entrepreneurs in residence, etc.\n- On the other side, we have the capital part, which is led by Evert, which was the former chief of staff at Chopet.\n- And yeah, it's more of a traditional VC.\n- We invest in early stage B2B SaaS companies.\n- Our main focus is like the European geography.\n- We also do uk, us, but yeah, that's like our main focus in general.\n- To quickly get like the bullet points away.\n- Our ticket size is between 300k and 1.5 million.\n- We like to be flexible.\n- We can lead, co lead or follow in rounds.\n- And yeah, we started fairly recently, like seven months ago.\n- We publicly launched in the time.\n- We already have nine portfolio companies, so we're really actively deploying.\n- And yeah, that's a quick, quick Rundown I can give you there.\n- I don't know if I forgot anything.\n- Yeah, personally I have a computer science background, worked a bit in the tech scene, really enjoyed the startup tech scene, really enjoyed the startup ecosystem itself.\n- Don't need to explain that part to you, I don't think.\n- And yeah, I kind of wanted to see what the dark side was, what the investment side was, and here I am.\n- So yeah, I don't know if anything is unclear or.\n- Great to meet you.\n- Where is the, where's the headquarter or where's the company located?\n- Also Belgium.\n- Ghent.\n- Belgium.\n- So okay, okay, so it's in European.\n- European, yeah.\n- Okay, great.\n- And okay, so I can do an introduction myself.\n- So you're looking for early stage.\n- Yeah, 300 to 1.5 million.\n- And how much companies do you have?\n- Have you already invested in?\n- More or less.\n- So currently as mentioned, we have nine portfolio companies, but in the scope of those, it's like as you mentioned, we're industry agnostic.\n- So it's a bit of a lot of different sectors itself, but just B2B SaaS companies in general.\n- We also have one cybersecurity company which might be like the closest thing like sector wise to what you're doing with Aikido, who are doing really well.\n- Yeah.\n- All right, what would be the process?\n- How would you like to handle it?\n- So I mean I will ...
#  'nenna.ai')

# %%
data = response.json()

# Extract speakers
speakers = [speaker['name'] for speaker in data['data']['transcript']['speakers']]

# Extract transcript sentences
sentences = data['data']['transcript']['sentences']
transcript_text = [sentence['text'] for sentence in sentences]

# Extract summary
summary = data['data']['transcript']['summary']['gist']
bullet_summary = data['data']['transcript']['summary']['bullet_gist']

# Format the output and store it in a string
output = f"Speakers: {', '.join(speakers)}\n\nTranscript:\n"
output += "\n".join(f"- {sentence}" for sentence in transcript_text)
output += f"\n\nSummary:\n{summary}\n\nDetailed Summary:\n{bullet_summary}"

print(output)
# Out:
# Speakers: Lars, Tibe Habils
#
# Transcript:
# - Thank you.
# - Hello.
# - How's it going?
# - Going great.
# - The weather is good, so, you know, it's not hard to be happy for today.
# - All right, where are you located?
# - Ghent, Belgium.
# - I don't know if you're familiar.
# - Okay, okay.
# - You're Berlin based, right?
# - Okay.
# - So you probably have like around the same weather as we have here in Belgium.
# - Like a lot of rain.
# - A lot.
# - But normally a lot of rain and gray.
# - Yeah, yeah.
# - No, no.
# - Nice to hear.
# - Yeah.
# - No, I came across what you're doing, I think, through LinkedIn and I was intrigued.
# - We were looking like, or we're starting to look a bit into the space of like the AI.
# - Like, I don't know how you specifically would call the subsection that you're working in, but we're looking at the privacy protection in AI and like the.
# - Just in general, how enterprises can use it and was intrigued.
# - So, yeah, I don't know how familiar you are with us from the other perspective.
# - So if it's okay, I'll give a quick introduction.
# - So we're both up to speed.
# - So you know what our investment thesis is and.
# - Yeah, just interrupt me if anything would be unclear.
# - Yeah, Great.
# - Yeah.
# - So quickly.
# - Entourage itself.
# - The idea itself started a bit before Entourage Ito by our managing partner, Peter Gambaze, founding and leading a company called Chopin, which is a B2B SaaS company.
# - He led that from 0 to 100 million plus ARR during 12 years.
# - Ish.
# - And in that period he also did a lot of angel investments that kind of grew out to be the idea of Entourage.
# - Entourage is of course, not only Patreon.
# - We also have two other amazing partners who are also former show patterns.
# - We have the former cto Machten, who leads more of our studio effort.
# - The studio part is where we still work on our own ideas, have entrepreneurs in residence, etc.
# - On the other side, we have the capital part, which is led by Evert, which was the former chief of staff at Chopet.
# - And yeah, it's more of a traditional VC.
# - We invest in early stage B2B SaaS companies.
# - Our main focus is like the European geography.
# - We also do uk, us, but yeah, that's like our main focus in general.
# - To quickly get like the bullet points away.
# - Our ticket size is between 300k and 1.5 million.
# - We like to be flexible.
# - We can lead, co lead or follow in rounds.
# - And yeah, we started fairly recently, like seven months ago.
# - We publicly launched in the time.
# - We already have nine portfolio companies, so we're really actively deploying.
# - And yeah, that's a quick, quick Rundown I can give you there.
# - I don't know if I forgot anything.
# - Yeah, personally I have a computer science background, worked a bit in the tech scene, really enjoyed the startup tech scene, really enjoyed the startup ecosystem itself.
# - Don't need to explain that part to you, I don't think.
# - And yeah, I kind of wanted to see what the dark side was, what the investment side was, and here I am.
# - So yeah, I don't know if anything is unclear or.
# - Great to meet you.
# - Where is the, where's the headquarter or where's the company located?
# - Also Belgium.
# - Ghent.
# - Belgium.
# - So okay, okay, so it's in European.
# - European, yeah.
# - Okay, great.
# - And okay, so I can do an introduction myself.
# - So you're looking for early stage.
# - Yeah, 300 to 1.5 million.
# - And how much companies do you have?
# - Have you already invested in?
# - More or less.
# - So currently as mentioned, we have nine portfolio companies, but in the scope of those, it's like as you mentioned, we're industry agnostic.
# - So it's a bit of a lot of different sectors itself, but just B2B SaaS companies in general.
# - We also have one cybersecurity company which might be like the closest thing like sector wise to what you're doing with Aikido, who are doing really well.
# - Yeah.
# - All right, what would be the process?
# - How would you like to handle it?
# - So I mean I will do a short introduction, I can tell you something about our product and go to market and all that stuff.
# - But what would, how would the process look like in general?
# - You mean like bigger view or do you mean just of this meeting?
# - Yeah, like no, this meeting and then the potential next steps.
# - Just to quick rundown from this meeting.
# - This is like introductory, introductory.
# - So in this, whatever is most comfortable for you.
# - I'd just like to see and hear what you're doing, what the, what the dynamic is between the founders, what your current metrics are.
# - And yeah, also what you're searching from us like have like a bit of a, you know, understanding that you know who we are, that we know who you are.
# - And yeah, to go higher level of like what our potential next steps are, it also always depends on, you know, your timeline of course as well.
# - But yeah, potential next steps is meeting with a partner probably ever in that part, in that sense.
# - And then it just depends on how it flows.
# - But in general we have a few meetings with the partners.
# - As mentioned, we have Martin, who is like our ct, like was former cto, is really tech savvy most of the times, also meets with the CTO and Then also meeting with the managing partner.
# - It just involves in like our due diligence and you know, trying to find if it's a match.
# - All right, cool.
# - Okay, thank you.
# - Yeah, today.
# - Yeah.
# - Like how you like the introduction itself?
# - For me it's like whatever you're most comfortable with.
# - If you're a pitcher, you like to give a quick pitch deck.
# - All good for me.
# - If you're more of a discussion person.
# - All good for me as well.
# - If you like to do something hybrid, also good for me.
# - I just like to see what you're doing and the format doesn't really matter for me.
# - All right.
# - Yeah.
# - So we have just half an hour.
# - I would suggest I do a short introduction.
# - I would jump in and so you will have an idea on what, what, what we're working on.
# - Have, did you know what we're doing?
# - I mean in general.
# - Have you had a look on our website or should I just start from scratch?
# - I, I looked at it for a bit, but I like to hear what you, how you would give like your elevator pitch.
# - Just quickly run through it.
# - All right.
# - Yeah.
# - I'm, I'm a co founder and I recently started as CEO of the company as and the founder is Alexander who is as well the technical founder and we are right now six people in the company and we hire three people.
# - So marketing manager, two developers are going to start like within the next two weeks.
# - So we'll be approximately with freelancers, almost 10 people working on the project.
# - And my role is sales, marketing, finance.
# - And so I'm here today to present you the product.
# - But if you would like to meet the whole team, we can do it in the next call, the next step when we should or could talk to a partner.
# - So what we do is we do data protection during the direct use of AI with large language models.
# - So we cover personal data and intellectual property while using every single large language model.
# - So this is our usp.
# - We, we are software that is distributed via browser, Edge and Chrome.
# - So there's a huge problem in the EU and in Germany with the shadow usage.
# - You don't know what your employees are putting in large language models.
# - And then we have this EUI act law and we cover.
# - We are not like.
# - We do not prohibit personal data like people to work with it.
# - We enable people to work with it by masking personal data.
# - The large language model can work with it and by de masking it when you would work further with it by copying text into email or Word.
# - And I, I can show you some screens and I will share my screen now, so maybe that's maybe quickly for.
# - The Chrome and Edge.
# - Is that just with an extension in the browser or what.
# - What is the like product itself?
# - It's an.
# - It's more or less is an extension.
# - Yeah.
# - And it's a software, so it's for companies.
# - It's B2B SaaS.
# - As an enterprise, you would buy a number of seats for your employees and you would roll it.
# - The roller will be over your IT infrastructure and then it would sit in the, in the browser people are working with.
# - So and then it's able to cover any large language model.
# - Okay, perfect.
# - Let me see if this is working.
# - All right.
# - You see that?
# - Yes.
# - Let me check where I have to work.
# - Okay.
# - You see the screen?
# - Yes.
# - Okay.
# - Okay.
# - So I mean that's a problem in the beginning.
# - You can tell me how much I should talk about the program.
# - But I mean we know that AI is critical for companies to be more efficient, boost in productivity.
# - I think we don't need to talk about that.
# - Still.
# - It's in the presentation.
# - The thing is that 70% of companies in Germany identify data privacy violations while using AI.
# - So a lot of companies are stopping or do not let their employees work with AI as much as they could or not at all.
# - And this is leading to competitive disadvantage to and to a huge loss of efficiency boost right now.
# - So 40% of workers use bent AI tool even though they are not allowed to.
# - This is like the shadow usage I was talking about.
# - And this is huge problem because you have this DSG4.0, this data privacy law in Europe and the UAI Act.
# - And yes, and this is something we are going to solve because three problems.
# - AI is used by any B2B Z tool.
# - You have a broad shadow usage and you have enterprise data that is gold for AI, but you're not collecting it.
# - You know, as an enterprise you have a lot of people playing around with ChatGPT or whatever, doing translations, doing creative things with large language models.
# - And as a company you're not able to see it.
# - You know, there is like a lot of gold and data people spending the time working with large language models.
# - They will be trained with the data and not only the security risk, but even like intellectual property is leaving your house and your company and you're not collecting it.
# - And this is something what we want to enable.
# - So we want to control the usage data security, but we want to enable the workforce and the company to solve all these problems.
# - So we are not just a data security company.
# - We have an enterprise enablement platform to secure AI to govern AI and to adopt AI to have insights on your internal AI usage and to scale it with own AI models.
# - In the end there is a platform for management or executives to like directly look at the usage and like look at which like how privatizes that, like.
# - How, how much is like an anonymous.
# - It's not like pair employee, it's like per department or whatever.
# - You know, if you, if you have these.
# - We have four layers in the platform.
# - There's a shield.
# - The shield protects the, the usage, the sensitive data.
# - I show you the shield in a minute.
# - Then there are guardrails.
# - So if you drag a PDF or Word document within a large language model, there's a NANA AI overlay that tells you you're dragging a Word document in it.
# - We can cover the personal information, you can check it beforehand.
# - And as a company you can tell NANA AI to not allow an upload of contracts or not allow an upload of CVS or whatever or PDF in general.
# - And you can steer the usage of AI.
# - You can prohibit to use various LLMs.
# - You can say I don't want this LLM to be used, I want this to be used more often or whatever.
# - So you can, you have these guardrails which you can steer the whole AI usage and then you have the insights.
# - And that was your question.
# - You know, you have like, you can see like in a cockpit which LLMs are used by your stuff.
# - What are the prompts, what are they using it for?
# - And but with this knowledge you are able to build your own processes on it.
# - You can tell if people are doing a lot of translation.
# - You can think of how to optimize that for example, or if people are doing a lot of, I don't know, ideation for special topics.
# - You are able to see this and you are able to give them best practices how to prompt and even we are able to push best practices of prompts to the employee while writing on a prompt because we know what works best.
# - So you are not able just not only protecting the data, when you have installed Nano, you are able to see what they are working on.
# - You're able to steal within your company.
# - Not intercompany wise with data regulation.
# - That must not be possible.
# - It's just within a company.
# - Okay.
# - And this is the same thing.
# - Yeah.
# - So we secure the data and people are able to work with LLMs.
# - We have higher productivity, we do this governance stuff.
# - So we have no liability risk.
# - We do this adoption with the insight.
# - So it's your data and it's the first time that you have like usage data with various LLMs, then you have a competitive advantage because you can scale that.
# - This is how it looks like.
# - You have the device of the employee that are installed and if it's contacts or emails or documents or whatever, you can use all AI services.
# - But the personal data is not leaving the device of the employee.
# - And this is why it's EU AI act and with compliance with data law in EU and in Germany, because it's not leaving the device of the employee.
# - To zoom in into the EU AI Act.
# - How enforced is that?
# - Has there been any fines or how should I see this?
# - There will be, there will be.
# - The companies need to be more or less ready mid of next year and next year and they need to show that they are compliant with the UAI act.
# - And there will be like there is the US building an AI, I call Task Force, different name right now and they're going to look into it.
# - And even this, oh, what is the word in English like you know, kpmg, Pricewater.
# - First they will look into it and see if you're compliant when it comes to this.
# - Annual.
# - Inspections of like an audit or like an audit.
# - It's like an art.
# - Yeah.
# - And you need to be compliant and if not there is a risk of fees.
# - You have to.
# - And is that one of the selling points that like if you pitch this to some like a company, is that like one of the first things that you pitch as well in there?
# - Yes, it depends, you know, and we are not.
# - This is a huge reason for people.
# - We do some pilot cases right now and we do demos with companies in Germany, for example, publishing houses, with legal firms and with agencies.
# - And some see this efficiency boost.
# - Some are like, oh, now I can work with it.
# - This is great, you know, because I can let people I don't know compare CVS because the personal data is not in the CVS anymore.
# - You know, something like they see the user case.
# - But some are like, I met someone last week who told me this is a solution for all my legal problems with this data security stuff in the UAI act because they're really afraid of how should I deal with this shadow usage.
# - You know, maybe quickly one you mentioned, for example CVS just, just to get a better understanding also out of PDFs you can filter out.
# - Yes, in PDF.
# - I show you, I show you in a minute.
# - Let's, let's jump into the product.
# - Look, this is like Nana AI secures any itool because we are a plugin in the browser Chrome in Edge.
# - So we have it installed.
# - You see it in the front end, you have this, you have this layer and you can choose if it's on or it's off.
# - As a company you do default settings but just like you can say where it's on, normally it's on.
# - So it's there as a layer.
# - And then you have the shield here in the middle.
# - It controls the usage of AI with PAI and IP on the device of the employee.
# - So and then you have the governance cockpit and as a company or your enterprise AI team you can, you can tell Nana what is allowed and what is not allowed.
# - The employee cannot change it, you know, and this is like the rule set you set as a company and then they're able to work with it and you have to shield on the, on the computer of the employees.
# - And during the usage you gain the insights I talked about beforehand.
# - And it looks like this.
# - You have the browser plugin and if this is a chatgpt prompt, you see that there are names and there is a street and there's a city and a bank account and this is like the mail to I think an insurance company.
# - Do you recognize that with your own LLM or how do you recognize that?
# - Well, but we have a recognition software as part of our.
# - And that's run locally or how does that work?
# - It's run locally, yeah.
# - Okay, so in the true the browser itself or is there is it just an on premise cloud that you need to use for that or how does that work?
# - Through the browser?
# - Through the browser.
# - Through the browser.
# - So in the browser you run that.
# - Okay, interesting.
# - And do you also have like the platform itself?
# - So you mentioned you can see the usage etc do you also have like screenshots or something of a demo of that insights?
# - Not right now.
# - This is what we.
# - I show you in a minute.
# - This is like the insight is the next step, right?
# - What's life right now is the shield and the guardrails.
# - Okay.
# - And the Insights are going to be launched begin beginning of next year.
# - Okay.
# - And you see that okay, this is a prompt that I do you know and what Nana is doing.
# - You see that the person becomes like this.
# - The name is.
# - The LLM knows that it's a person and that is an email.
# - That is a phone number.
# - And the LLM knows that this.
# - So you can compare CVS for example because you know which person it is but just with this mask ask thing, you know.
# - So you have this on your fly masking company brands, phone number, whatever.
# - As a company you can do, I don't know, you can upload a set of 1,000 data points that you would like to have masked like brand names, client names, whatever.
# - And then the prompt is going to the LLM and it's no sensitive data or personal data.
# - With the LLM it stays on.
# - On premise of the, of the employee.
# - So the prompt output is working.
# - So here the subject was to write an email.
# - So it writes an email, it says dear Person, dear State, and then you copy this into your email program or Word or whatever and de mask the content and the name is there again, the bank account is there again, everything is there again.
# - And this happens on the computer of the employee.
# - So the LLM hasn't seen any sensitive data.
# - This is why it's compliant with data law.
# - And this is what you were asking.
# - If I drag a Word or PDF file into the browser, there is this nanoshield and it says you're uploading a PDF file.
# - It is masked.
# - Please check it before and so you can check it and then you see that with the PDF.
# - Yes, but with PDF you cannot retrieve the data.
# - It's just cover and that's it.
# - With Word it works like the same way as I showed you in the.
# - In the prompt and with the PDFs.
# - Does it?
# - Is it only for searchable PDFs that this is doable or does it.
# - Is it also working for like non searchable PDFs?
# - I'm not sure.
# - Okay.
# - I think it works with any PDF.
# - What is.
# - Yeah, like you know the, the PDF, sorry, you can like select the text and then you have PDF so you can't.
# - I'm not the technical guy, but I think it works with all PDFs.
# - Yeah, yeah.
# - And we can show you.
# - But we can show you a demo if you're interested.
# - A live demo of this.
# - Maybe for the time's sake, not now, but like I definitely.
# - If you have like a video or something or do you have like a clip of it?
# - No, I just have the screens right now.
# - Okay, I know.
# - If you would.
# - Yeah, we'll leave that for now because I think there's still a few things to do for time's sake.
# - I think the live demo is hard to see.
# - I'm done in three minutes.
# - So you see this data show policy details and whatever.
# - So you can use in different ways as a copy.
# - You can use it just as to be data safe.
# - And you say no personal data, no documents or whatever.
# - And so you're in control of the shadow usage.
# - But this is, let's say, the default case.
# - The more interesting case is to say what is allowed and let people work with it and not stopping the usage of AI in your company.
# - We have free packages, we have like it depends on the seat and of the functions you have.
# - So it starts with a team that's up to 20 seats, department is up to 150 seat enterprises up to 1000 seats and only with department you are able to start using these insights.
# - And as an enterprise you can do own insight models, own shield models and a custom AI.
# - This is not something we would do with a team, you know, you see, let's say the bigger it gets, the more individualization is there and the more you can, you can build your own functions with our tools.
# - So team is more or less what you see is what you get, you know.
# - And with enterprise you have more or less strategic partnership and you're working on how they really would like to work with these insights and have more functions within the shield and not just like the standard thing.
# - And how does that work pricing wise?
# - What should I like per seat or per company or.
# - I don't know how you do pricing.
# - Yeah, we are middle.
# - We are the 20 seats are like.
# - €300Amonth or just in general.
# - Or in general.
# - In general, yeah.
# - So we are looking for a long term login effect, you know, because as an enterprise if you have NANA installed, you have the shield and the guardrails.
# - But because with our tool you're able to have these insight and custom AI.
# - Yeah, we call it gravity.
# - We have this gravity effect or login effect that we are not just a protection software, we are an ailment software.
# - And it makes sense to work with us over a longer period of time and for not just for teams but for whole enterprises.
# - These are the sectors we are looking in.
# - Legal, we're working legal agencies, finance, you know, where data protection is very important as well Health and insurance and public sector and as well E commerce.
# - But right now we are focusing on legal agencies and finance and we are building pilot cases there.
# - These are with agencies.
# - Do you mean consultancy or what kind of agencies?
# - Yeah, like yes, agencies.
# - Like yes, it's good question.
# - Like different kind of agencies.
# - It's like could be brand agencies or marketing agencies, but they work with sensitive data as well.
# - You know when they are creating intellectual property or they don't want the large language model to know which client you're talking about.
# - Now it's done.
# - Okay, perfect.
# - These are some use cases.
# - I will spare them right now.
# - But this is legal.
# - You have to compare contract versions, automate emails, confidential data, CVS and hr.
# - This is like the agency stuff, idea generation Texting translation We have pilot cases in legal consulting and marketing right now and we are negotiating reselling partners.
# - So they.
# - It's a great distribution model for us because this is like a legal partner and a consulting agency and we have B2B pilots, their agencies.
# - There is a publishing and invest investment.
# - Houses as well to quickly zoom into that.
# - So like traction wise, how does that work?
# - Pilot cases, is that paid?
# - Not paid.
# - And.
# - Cases are demo cases that are not paid right now.
# - But the idea is to turn them into clients.
# - We do these pilot cases for free just to enter the market.
# - But the objective to end of year is to have five clients closed.
# - And what kind of action should you get out of that?
# - Or what are you aiming for?
# - Like traction wise, MRR or ARR wise?
# - Out of those end of year?
# - Yes.
# - Yeah, it's ARR.
# - End of year is more or less like 180 200,000.
# - And currently.
# - There'S no revenue.
# - Yeah, we're like we started go to market beginning of October, but next year we are aiming at 800k.
# - Okay.
# - Total revenue, not ARR total.
# - Because there's a lot of service fee in the setup itself or just currently.
# - No, it's, it's.
# - It's the seats and the contracts.
# - Yeah.
# - So it is ARR.
# - Yeah.
# - Excuse me.
# - So, so wait, you mentioned that the 800k is not ARR, but what is there like service associated?
# - Like total net revenue next year but.
# - Like just a part of that is service based or why, why is it not ARR?
# - Ah, okay.
# - No, ARR is.
# - Ah, no, for the next year the ARR is even higher when it comes to the yearly contracts and stuff like this.
# - It's not ARR because it's a total annual revenue, not recurring revenue, you know.
# - Yeah, so it's not recurring because there's service fees included in that 800k or why is it not recurring?
# - Service fees in it?
# - Yes.
# - Okay.
# - And how much?
# - Even higher because you have like I show you where is it?
# - So we start right now with just team setup and next year we have department clients and enterprise clients.
# - And let's assume that the enterprise client is stepping in like in March or in June and they have a yearly contract or even longer.
# - So this is how I understand it.
# - The total revenue next year, the ARR for 2026, well end of 2025 is more than 800k.
# - Okay, perfect.
# - Yeah, maybe for sake.
# - I'll try to like quickly go through the other questions.
# - So like two quick ones.
# - So you mentioned something with the founder setup.
# - I'm not completely Clear of what?
# - What, like how it currently works.
# - So you have Alexander, he's moving into more of a CTO function.
# - And you're joining as like a founder, as a CEO, right?
# - Or is that misunderstood?
# - Let's say I do the thing, a lot of the outbound stuff, events, marketing, sales.
# - And Alex is the founder, the technical brain and he's doing a lot of investor relations as well.
# - But you're joining more as like your late joining founder or how should I see that?
# - No, I was a very early founder, but I was working with a media company and digital department 12 years and my terms of notice was, were like six months.
# - So I was.
# - I co founded in May, but I just, I could start right now.
# - Yeah.
# - Alex is a founder.
# - He did two exit within B2B and SaaS companies.
# - Alexis is a CTO, like the operating CTO.
# - And Florian is a business development.
# - Yeah.
# - And maybe to zoom in, like just a quick question, like the website itself is like fully in German.
# - Is that because your current focus is just the German market or how should I see that?
# - This is something we see as a usp.
# - We communicate in German because we want to have trust.
# - We start in German, or let's say Dach as a German company and we want to build trust.
# - We do not want to be a company that is seated.
# - I don't know, somewhere.
# - We want to show our clients that we understand European law and German law and data protection and that we work with local servers only and all the tools we are using are compliant with data law, even our CRM.
# - So we want to build trust by communicating in German and we want to start in German market.
# - Yeah, I see that we're over the time limit.
# - Can I quickly grab like two more minutes or do you have a back to back?
# - Okay, sorry.
# - No worries.
# - Sorry for interrupting.
# - I just wanted to ensure.
# - No.
# - And the tool Nana AI is able to work in English.
# - Okay.
# - But we are focusing go to markets in Germany.
# - Right?
# - Okay.
# - Yeah, no, definitely.
# - Interesting.
# - And maybe to zoom into that like competition wise, how would you say, how would you place yourself in the space itself?
# - Like what is your main differentiator in comparison to.
# - So for the German thing made in Germany, we position ourselves that we are like.
# - We understand data, but we are an enablement platform.
# - I haven't seen our idea before and there's a lot of guardrail stuff and IT security and custom AI.
# - But we have a different approach when it comes to how you protect and enable people.
# - Because we sit there where the employees are working with AI.
# - We do not build like we are easy to install.
# - You can roll us roll out our software very fast and in a simple way.
# - And you do not need to build like huge IT infrastructures first and then understand how you are going to develop an own LLM and stuff.
# - Because we suggest in front of it.
# - So we our USP is that we make data protection feasible and possible with any AI.
# - So this is something we haven't seen in the market and this is very special.
# - And then it's for German companies.
# - Okay, maybe interesting to look at.
# - I just sent it in chat Collider.
# - They're like an Italian company who is like in a similar space.
# - Might be interesting for you to look at as well.
# - Of course as you mentioned, if one of your differentiators is currently like chairman.
# - It's different but might be interesting to see them as well.
# - Yeah.
# - Maybe to quickly look into like what you're searching for.
# - Like are you currently raising or what is your timeline raising wise.
# - We have angel investment.
# - Okay.
# - These are our angels and they support us by with the go to market.
# - A lot of knowledge in B2B SaaS and agency as well.
# - What we are looking for right now we have an angel invest of approximately 300k with a post money evaluation of 2.5 million and we are looking into 1.5 to 2 million let's say end of year, beginning of next year to be able to scale and to be able to invest in marketing and more people team stuffing sales and building the product.
# - So ideally you would be done raising before your revenue.
# - Like it would be like kind of a pre revenue round because you mentioned or like you mentioned that you're trying to get the revenue like end of year.
# - Yeah.
# - So it's like starting to be there.
# - Okay.
# - Yeah.
# - And what kind of valuation are you looking at for the 1.5 to 2?
# - We need to talk about that.
# - Do you have like a range?
# - I don't want to like hard fit you to something but I just want like if there's a range that you already have in mind.
# - Yeah.
# - For what?
# - Yeah, for us it would be to pose to be a 10 million evaluation and total web.
# - Okay.
# - I know it's in no way to like.
# - I just need like based on the.
# - Model and the setup and what kind of investment it is.
# - So you know I'm.
# - I was just.
# - It's hard to say if you do not know the.
# - I totally.
# - It's just like as mentioned like I have an internal debrief about this later and it's just easier if I have like some guidelines of what the amount is.
# - It's in no way to, like, have a gotcha moment after this, so no worries about that.
# - Yeah, no, definitely.
# - Interesting.
# - Thank you for your time.
# - I really enjoyed hearing about it.
# - Really interesting space as well.
# - And, yeah, as mentioned, I'll try to get back to you as soon as possible with potential next steps.
# - If you could send me your slides as well, that would make my life a bit easier.
# - Yeah.
# - Thank you so much.
# - Yeah, of course.
# - Thank you very much.
# - Have a nice day.
# - Bye.
#
# Summary:
# Lars Moll pitched Nana AI's data protection software to Tibe Habils, seeking funding to expand their B2B services in Europe.
#
# Detailed Summary:
# 🚀 Innovative Product: Nana AI offers a browser extension that protects personal data and IP, ensuring compliance with EU regulations.
# 💼 Targeted Market: The company is focused on the European B2B market, particularly in sectors like legal, finance, and healthcare.
# 📈 Revenue Goals: Nana AI aims for 180-200k ARR by year-end and 800k in total revenue next year.
# 💰 Funding Request: Lars requested 1.5-2 million euros at a valuation of 10 million euros to support expansion.
# 📊 Next Steps: Follow-up actions include sending presentation slides to Tibe for consideration of future collaboration.

# %%
formatted_summary
# Out:
# ''

# %%
def fetch_transcript(meeting_id, api_key):
    url = 'https://api.fireflies.ai/graphql'
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {api_key}'
    }
    # GraphQL query to fetch transcript details
    query = '''
    query Transcript($transcriptId: String!) {
      transcript(id: $transcriptId) {
        id
        title
        dateString
        speakers {
          id
          name
        }
        sentences {
          index
          speaker_name
          text
          start_time
          end_time
        }
        duration
        summary {
          gist
          bullet_gist
        }
      }
    }
    '''
    variables = {"transcriptId": meeting_id}
    response = requests.post(url, headers=headers, json={"query": query, "variables": variables})

    if response.status_code == 200:
        transcript_data = response.json().get('data', {}).get('transcript', {})
        
        # Format transcript into a readable format
        fireflies_transcript = {
            "Title": transcript_data.get('title', 'N/A'),
            "Date": transcript_data.get('dateString', 'N/A'),
            "Duration (mins)": transcript_data.get('duration', 0) / 60,
            "Speakers": [speaker['name'] for speaker in transcript_data.get('speakers', [])],
            "Summary": transcript_data.get('summary', {}).get('gist', 'No summary available'),
            "Sentences": [
                {
                    "Speaker": sentence.get('speaker_name', 'Unknown'),
                    "Text": sentence.get('text', ''),
                    "Start": sentence.get('start_time'),
                    "End": sentence.get('end_time')
                } for sentence in transcript_data.get('sentences', [])
            ]
        }
        
        # Store or print the formatted transcript
        return fireflies_transcript
    else:
        print(f"Failed to fetch transcript. Status code: {response.status_code}")
        return None

# Replace 'meeting_id' and 'api_key' with your actual meeting ID and API key
meeting_id = "EdrQWlrkVM2XeAma"
api_key = "your_api_key"
fireflies_transcript = fetch_transcript(meeting_id, api_key)

# Display or use fireflies_transcript as needed
print(json.dumps(fireflies_transcript, indent=2))

# %%
sender = email_info.get('sender', '')
match = re.match(r'.*<(.+?)>', sender)
if match:
    sender_email = match.group(1)
else:
    sender_email = sender

# %%
import requests
from requests.auth import HTTPBasicAuth
import os

# Define your campaign name and API key
campaign_name = "Outreach Automation"
api_key = os.getenv("LEMLIST_API_KEY")

def lemlist_export(company_info):
    # URL to get the list of campaigns
    campaigns_url = "https://api.lemlist.com/api/campaigns"
    response = requests.get(campaigns_url, auth=HTTPBasicAuth('', api_key))
    campaign_lists = response.json()
    campaign_id = None
    for campaign_list in campaign_lists:
        if campaign_list.get("name", "") == campaign_name:
            campaign_id = campaign_list.get("_id", "")
            break

    # Extract company details
    company_name = company_info.get('Name', '')
    company_domain = company_info.get('Website URL', '')

    # Iterate over each contact in the company_info
    for contact in company_info.get('Contacts', []):
        first_name = contact.get('FirstName', '')
        last_name = contact.get('LastName', '')
        email = contact.get('Email', '')
        params_value = 'false' if "@" in email else 'true'
        
        # Construct the API endpoint URL for each lead
        url = f"https://api.lemlist.com/api/campaigns/{campaign_id}/leads"
        params = {'findEmail': params_value, 'verifyEmail': params_value}
        payload = {"firstName": first_name, "lastName": last_name, "email": email, "companyName": company_name, "companyDomain": company_domain}
        response = requests.request("POST", url, auth=HTTPBasicAuth('', api_key), params=params, json=payload)
        print(response.json())

    return

company_info = {'Name': 'Calendly', 'Website URL': 'calendly.com', 'Contacts': [{'FirstName': 'Charlotte', 'LastName': 'Deprez', 'Email': 'charlotte@lewagon.org'}]}
lemlist_export(company_info)
# Out:
# {'campaignId': 'cam_q5T2Q3fq8tLD9ZukH', 'campaignName': 'Outreach Automation', 'firstName': 'Charlotte', 'lastName': 'Deprez', 'email': 'charlotte@lewagon.org', 'companyName': 'Calendly', 'companyDomain': 'calendly.com', '_id': 'lea_ST5fiDnt9K5n6MxZv', 'isPaused': False}

# %%
website_url = "entourage.io"

# %%
api_key = "969b59bdb038d4673319b34e74cc3047"

url = f"https://api.lemlist.com/api/campaigns"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
campain_lists = response.json()
from campain_list in campain_lists:
    if campain_list.get("name", "") == campaign_name
# Out:
# [{'_id': 'cam_q5T2Q3fq8tLD9ZukH',
#   'name': 'Outreach Automation',
#   'createdAt': '2024-10-23T13:46:49.918Z',
#   'createdBy': 'usr_Mv9KSoTQx7ozZhyje',
#   'status': 'draft',
#   'hasError': True,
#   'errors': ['Your step have an invalid message.']}]

# %%
import requests
from requests.auth import HTTPBasicAuth
import os

api_key = os.getenv("AFFINITY_API_KEY")

url = f"https://api.affinity.co/organizations?term={website_url}"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))

# %%
import requests
from requests.auth import HTTPBasicAuth
import os

api_key = os.getenv("AFFINITY_API_KEY")

list_id = 219127

def update_affinity_field(company_info):

    # Clean up the website URL by removing prefixes
    website_url = company_info.get("Website URL")
    prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
    for prefix in prefixes:
        if website_url.startswith(prefix):
            website_url = website_url[len(prefix):]
            break

    # Find the organization by domain
    url = f"https://api.affinity.co/organizations?term={website_url}"
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    organizations = response.json().get("organizations", [])
    organization_id = None
    for organization in organizations:
        if organization.get('domain') == website_url:
            organization_id = organization.get('id')
            break

    # Get the list fields
    url = f'https://api.affinity.co/lists/{list_id}'
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    list_fields = response.json().get("fields", [])

    url = f"https://api.affinity.co/lists/{list_id}/list-entries"
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    list_entries = response.json()
    list_entry_id = None
    for list_entry in list_entries:
        entity = list_entry.get('entity', {})
        entity_domain = entity.get('domain', '')
        if entity_domain == website_url:
            list_entry_id = list_entry.get('id')
            break

    # For each field in the list, update it with the corresponding value from company_info
    for list_field in list_fields:
        field_name = list_field.get("name")
        field_id = list_field.get("id")
        if field_name in company_info:
            new_value = company_info[field_name]
            dropdown_options = list_field.get('dropdown_options', [])
            if dropdown_options:
                dropdown_option_id = None
                for option in dropdown_options:
                    if option.get('text') == new_value:
                        new_value = option.get('id')
                        break

            # Get existing field values for the organization
            url = f"https://api.affinity.co/field-values?organization_id={organization_id}"
            response = requests.get(url, auth=HTTPBasicAuth('', api_key))
            organization_fields = response.json()
            field_value_id = None
            for field_value in organization_fields:
                if field_value.get("field_id") == field_id:
                    field_value_id = field_value.get("id")
                    break
            if field_value_id:
                # Update existing field value
                url = f"https://api.affinity.co/field-values/{field_value_id}"
                data = {'value': new_value}
                response = requests.put(url, auth=HTTPBasicAuth('', api_key), json=data)
            else:
                url = "https://api.affinity.co/field-values"
                data = {'field_id': field_id, 'value': new_value, 'entity_id': organization_id, 'list_entry_id': list_entry_id}
                response = requests.post(url, auth=HTTPBasicAuth('', api_key), json=data)

    return

company_info = {"Website URL": "psg.fr", "Name": "Space X", "GPT Description": "La description", "Status": "Rejected"}
update_affinity_field(company_info)

# %%
url = "https://api.affinity.co/notes"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
notes = response.json().get("notes", [])
for note in notes:
    find all where organization_id is in note.get("organization_ids", []):
    if any existe:
        note_id = note.get("id", "")
        update_url = f"https://api.affinity.co/notes/{note_id}"
        data = {'content': note_content}
        update_response = requests.put(update_url, auth=HTTPBasicAuth('', api_key), json=data)
    if no exist:
        create_url = "https://api.affinity.co/notes"
        data = {'content': note_content, 'type': 2, organization_ids[organization_id]}
        update_response = requests.put(update_url, auth=HTTPBasicAuth('', api_key), json=data)

# %%
def add_note_to_affinity(website_url, note_content):
    # Fetch the organization by its website URL
    url = f"https://api.affinity.co/organizations?term={website_url}"
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    organizations = response.json().get("organizations", [])
    organization_id = None
    for organization in organizations:
        if organization.get("domain", "") == website_url:
            organization_id = organization.get("id", "")
            break

    # Fetch existing notes for the organization
    url = "https://api.affinity.co/notes"
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    notes = response.json().get("notes", [])
    note_exists = False
    note_id = None

    # Check if any note exists for this organization
    for note in notes:
        if organization_id in note.get("organization_ids", []):
            note_exists = True
            note_id = note.get("id", "")
            break

    if note_exists and note_id:
        # Update the existing note
        update_url = f"https://api.affinity.co/notes/{note_id}"
        data = {'content': note_content}
        requests.put(update_url, auth=HTTPBasicAuth('', api_key), json=data)
    else:
        # Create a new note if no existing note is found
        create_url = "https://api.affinity.co/notes"
        data = {'content': note_content, 'type': 2, 'organization_ids': [organization_id]}
        requests.post(create_url, auth=HTTPBasicAuth('', api_key), json=data)

    return

add_note_to_affinity("spacex.com", "New note")

# %%
url = f"https://api.affinity.co/lists/219127"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
response.json()
# Out:
# {'id': 219127,
#  'type': 1,
#  'name': 'Deal Flow',
#  'public': True,
#  'owner_id': 165338308,
#  'creator_id': 165338308,
#  'list_size': 1137,
#  'fields': [{'id': 4101993,
#    'name': 'Status',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 7,
#    'allows_multiple': False,
#    'track_changes': True,
#    'dropdown_options': [{'id': 11642141,
#      'text': 'Leads',
#      'rank': 1,
#      'color': 0},
#     {'id': 16811002, 'text': 'To Screen', 'rank': 2, 'color': 0},
#     {'id': 16652933, 'text': 'To be contacted', 'rank': 3, 'color': 0},
#     {'id': 16822340, 'text': 'In email flow', 'rank': 4, 'color': 0},
#     {'id': 15097555, 'text': 'Contacted', 'rank': 5, 'color': 1},
#     {'id': 16811001, 'text': 'Call planned', 'rank': 6, 'color': 1},
#     {'id': 11414054, 'text': 'Long list', 'rank': 7, 'color': 3},
#     {'id': 11414055, 'text': 'Short list', 'rank': 8, 'color': 3},
#     {'id': 11414056, 'text': 'TS diligence', 'rank': 9, 'color': 3},
#     {'id': 11414057, 'text': 'Final diligence', 'rank': 10, 'color': 3},
#     {'id': 11414058, 'text': 'Closed', 'rank': 11, 'color': 2},
#     {'id': 11414059, 'text': 'Lost', 'rank': 12, 'color': 4},
#     {'id': 16822482, 'text': 'No answer', 'rank': 13, 'color': 0},
#     {'id': 11414060, 'text': 'Nurture bucket', 'rank': 14, 'color': 5},
#     {'id': 11414062, 'text': 'Rejected', 'rank': 15, 'color': 5}]},
#   {'id': 4101995,
#    'name': 'Owners',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 0,
#    'allows_multiple': True,
#    'track_changes': True,
#    'dropdown_options': []},
#   {'id': 4101994,
#    'name': 'Amount',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 3,
#    'allows_multiple': False,
#    'track_changes': True,
#    'dropdown_options': []},
#   {'id': 4102040,
#    'name': 'Investment Round',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 2,
#    'allows_multiple': False,
#    'track_changes': False,
#    'dropdown_options': [{'id': 11628935,
#      'text': 'Other',
#      'rank': 0,
#      'color': 0},
#     {'id': 11628930, 'text': 'Pre-Seed', 'rank': 0, 'color': 0},
#     {'id': 11628931, 'text': 'Seed', 'rank': 0, 'color': 0},
#     {'id': 11628932, 'text': 'Seed Extension', 'rank': 0, 'color': 0},
#     {'id': 11628933, 'text': 'Series A', 'rank': 0, 'color': 0},
#     {'id': 11628934, 'text': 'Series B', 'rank': 0, 'color': 0}]},
#   {'id': 4102041,
#    'name': 'Priority',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 7,
#    'allows_multiple': False,
#    'track_changes': True,
#    'dropdown_options': []},
#   {'id': 4761545,
#    'name': 'Email',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 6,
#    'allows_multiple': False,
#    'track_changes': False,
#    'dropdown_options': []},
#   {'id': 4102043,
#    'name': 'Pass Reason',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 2,
#    'allows_multiple': True,
#    'track_changes': False,
#    'dropdown_options': [{'id': 11756572,
#      'text': 'Are looking for an exit',
#      'rank': 0,
#      'color': 0},
#     {'id': 16656896, 'text': 'B2C', 'rank': 0, 'color': 0},
#     {'id': 16708218, 'text': 'Finished fundraising', 'rank': 0, 'color': 0},
#     {'id': 11684359, 'text': 'Founded too long ago', 'rank': 0, 'color': 0},
#     {'id': 16601223, 'text': 'Hardware', 'rank': 0, 'color': 0},
#     {'id': 16708181, 'text': 'No response', 'rank': 0, 'color': 0},
#     {'id': 12069094,
#      'text': 'Not convinced by the founder',
#      'rank': 0,
#      'color': 0},
#     {'id': 15196469, 'text': 'Not early stage anymore', 'rank': 0, 'color': 0},
#     {'id': 12011695, 'text': 'Not enough traction', 'rank': 0, 'color': 0},
#     {'id': 11987946, 'text': 'Not in scope', 'rank': 0, 'color': 0},
#     {'id': 11799665,
#      'text': 'Too early for Entourage Capital',
#      'rank': 0,
#      'color': 0},
#     {'id': 15305049, 'text': 'To small of a market', 'rank': 0, 'color': 0},
#     {'id': 16650565, 'text': 'Valuation too high', 'rank': 0, 'color': 0}]},
#   {'id': 4733170,
#    'name': 'Miles Ahead',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 3,
#    'allows_multiple': False,
#    'track_changes': True,
#    'dropdown_options': []},
#   {'id': 4760125,
#    'name': 'Suggested action',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 6,
#    'allows_multiple': False,
#    'track_changes': False,
#    'dropdown_options': []},
#   {'id': 4784338,
#    'name': 'GPT Description',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 6,
#    'allows_multiple': False,
#    'track_changes': False,
#    'dropdown_options': []},
#   {'id': 4784339,
#    'name': 'GPT Client Type',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 6,
#    'allows_multiple': False,
#    'track_changes': False,
#    'dropdown_options': []},
#   {'id': 4784340,
#    'name': 'GPT Industry',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 6,
#    'allows_multiple': False,
#    'track_changes': False,
#    'dropdown_options': []},
#   {'id': 4784341,
#    'name': 'GPT Revenue Model',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 6,
#    'allows_multiple': False,
#    'track_changes': False,
#    'dropdown_options': []},
#   {'id': 4784342,
#    'name': 'GPT Region',
#    'list_id': 219127,
#    'enrichment_source': 'none',
#    'value_type': 6,
#    'allows_multiple': False,
#    'track_changes': False,
#    'dropdown_options': []}]}

# %%
field_id = 4696722

# %%
url = f"https://api.affinity.co/field-values?organization_id={organization_id}"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
organization_fields = response.json()

# %%
organization_fields
# Out:
# [{'id': 13572633739,
#   'field_id': 4696722,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 299266107,
#   'created_at': '2024-10-23T06:23:36.862-07:00',
#   'updated_at': None,
#   'value': 'New tag'},
#  {'id': 13567512466,
#   'field_id': 4768744,
#   'list_entry_id': 172098674,
#   'entity_type': 1,
#   'value_type': 7,
#   'entity_id': 299266107,
#   'created_at': '2024-10-22T09:04:09.250-07:00',
#   'updated_at': None,
#   'value': {'id': 16696433, 'text': 'New', 'rank': 1, 'color': 1}}]

# %%
url = f"https://api.affinity.co/fields"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
fields = response.json()
for field in fields:
    if field.get("name", "") == "Tag":
        field_id = field.get("id", "")
        dropdown_options = field.get("dropdown_options", "")
        for dropdown_option in dropdown_options:
            if dropdown_option.get("text", "") == tag_value:
                dropdown_option_id = dropdown_option.get("text", "")
# Out:
# {'id': 4696722, 'name': 'Tag', 'list_id': None, 'enrichment_source': 'none', 'value_type': 2, 'allows_multiple': True, 'track_changes': False, 'dropdown_options': [{'id': 16673587, 'text': 'CBE Oktober', 'rank': 0, 'color': 0}, {'id': 16650877, 'text': 'Cbe_screen (2) F', 'rank': 0, 'color': 0}, {'id': 16652444, 'text': 'Combined_startups_urls', 'rank': 0, 'color': 0}, {'id': 15091553, 'text': 'Erwan Shared Dealflow', 'rank': 0, 'color': 0}, {'id': 15290235, 'text': 'Evert VC share 26/09', 'rank': 0, 'color': 0}, {'id': 16691204, 'text': "Ghent Slush'D 2024", 'rank': 0, 'color': 0}, {'id': 16690887, 'text': 'Health_Tech_101824_One_Pager_18-10-2024', 'rank': 0, 'color': 0}, {'id': 16544171, 'text': 'HF0', 'rank': 0, 'color': 0}, {'id': 16416172, 'text': 'Miles Ahead', 'rank': 0, 'color': 0}, {'id': 16696612, 'text': 'Ping Evert', 'rank': 0, 'color': 0}, {'id': 16696623, 'text': 'Ping Tibe', 'rank': 0, 'color': 0}, {'id': 16514649, 'text': 'Pipeline review', 'rank': 0, 'color': 0}, {'id': 16671074, 'text': 'Plug & Play University Of Oxford 10 16 2024', 'rank': 0, 'color': 0}, {'id': 16697795, 'text': 'To Screen', 'rank': 0, 'color': 0}, {'id': 15023041, 'text': 'Wintercircus Campus', 'rank': 0, 'color': 0}, {'id': 16697132, 'text': 'YAYAYA', 'rank': 0, 'color': 0}]}

# %%
url = f"https://api.affinity.co/organizations/fields"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
fields = response.json()

# %%
fields
# Out:
# [{'id': 3909160,
#   'name': 'Investment Stage',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 2,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909163,
#   'name': 'Description',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909165,
#   'name': 'Year Founded',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909164,
#   'name': 'Number of Employees',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909168,
#   'name': 'Location',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 5,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909161,
#   'name': 'Industry',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909169,
#   'name': 'Last Funding Date',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 4,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909162,
#   'name': 'Investors',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909170,
#   'name': 'Source of Introduction',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 0,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909166,
#   'name': 'Total Funding Amount (USD)',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909167,
#   'name': 'Last Funding Amount (USD)',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909174,
#   'name': 'Description',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909175,
#   'name': 'Number of Employees',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909172,
#   'name': 'Industry',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909171,
#   'name': 'Investment Stage',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 2,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909173,
#   'name': 'Investors',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909178,
#   'name': 'Last Funding Amount (USD)',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909180,
#   'name': 'Last Funding Date',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 4,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909179,
#   'name': 'Location',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 5,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909177,
#   'name': 'Total Funding Amount (USD)',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909176,
#   'name': 'Year Founded',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909182,
#   'name': 'LinkedIn URL',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909183,
#   'name': 'Dealroom.co URL',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909193,
#   'name': 'Corporate Industries',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909189,
#   'name': 'Service Industries',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909188,
#   'name': 'Technologies',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909191,
#   'name': 'Income Streams',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909195,
#   'name': 'Revenue Model',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909190,
#   'name': 'Ownership Types',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909187,
#   'name': 'Total Tweets',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909185,
#   'name': 'Last Month Change in Twitter Followers',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909186,
#   'name': 'Last Month Twitter Favorites',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909192,
#   'name': 'Number of Employees',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909201,
#   'name': 'Location',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 5,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909194,
#   'name': 'Client Type',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909199,
#   'name': 'Description',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909200,
#   'name': 'Industry',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909198,
#   'name': 'Year Founded',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909197,
#   'name': 'Total Funding Amount (EUR)',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909196,
#   'name': 'Last Funding Amount (EUR)',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909184,
#   'name': 'Last Month Twitter Followers',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 4696722,
#   'name': 'Tag',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': [{'id': 16673587,
#     'text': 'CBE Oktober',
#     'rank': 0,
#     'color': 0},
#    {'id': 16650877, 'text': 'Cbe_screen (2) F', 'rank': 0, 'color': 0},
#    {'id': 16652444, 'text': 'Combined_startups_urls', 'rank': 0, 'color': 0},
#    {'id': 15091553, 'text': 'Erwan Shared Dealflow', 'rank': 0, 'color': 0},
#    {'id': 15290235, 'text': 'Evert VC share 26/09', 'rank': 0, 'color': 0},
#    {'id': 16691204, 'text': "Ghent Slush'D 2024", 'rank': 0, 'color': 0},
#    {'id': 16690887,
#     'text': 'Health_Tech_101824_One_Pager_18-10-2024',
#     'rank': 0,
#     'color': 0},
#    {'id': 16544171, 'text': 'HF0', 'rank': 0, 'color': 0},
#    {'id': 16416172, 'text': 'Miles Ahead', 'rank': 0, 'color': 0},
#    {'id': 16732722, 'text': 'New tag', 'rank': 0, 'color': 0},
#    {'id': 16696612, 'text': 'Ping Evert', 'rank': 0, 'color': 0},
#    {'id': 16696623, 'text': 'Ping Tibe', 'rank': 0, 'color': 0},
#    {'id': 16514649, 'text': 'Pipeline review', 'rank': 0, 'color': 0},
#    {'id': 16671074,
#     'text': 'Plug & Play University Of Oxford 10 16 2024',
#     'rank': 0,
#     'color': 0},
#    {'id': 16697795, 'text': 'To Screen', 'rank': 0, 'color': 0},
#    {'id': 15023041, 'text': 'Wintercircus Campus', 'rank': 0, 'color': 0},
#    {'id': 16697132, 'text': 'YAYAYA', 'rank': 0, 'color': 0}]},
#  {'id': 4102034,
#   'name': 'Amount Invested $',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': True,
#   'dropdown_options': []},
#  {'id': 4102044,
#   'name': 'Talent we should track?',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 2,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 4102045,
#   'name': 'Talent comment',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 4129749,
#   'name': 'Source',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 4771841,
#   'name': 'Outreach status',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 7,
#   'allows_multiple': False,
#   'track_changes': True,
#   'dropdown_options': [{'id': 16713560,
#     'text': 'PJ to reach out',
#     'rank': 1,
#     'color': 0},
#    {'id': 16713561, 'text': 'Evert to reach out', 'rank': 2, 'color': 0},
#    {'id': 16713562, 'text': 'Outreach completed', 'rank': 3, 'color': 0}]},
#  {'id': 4541158,
#   'name': 'Synopsis',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 4541157,
#   'name': 'Oneliner',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 4763673,
#   'name': 'Tag List',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 2,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': [{'id': 16670849,
#     'text': 'Non-US Software ICP',
#     'rank': 0,
#     'color': 0},
#    {'id': 16684084, 'text': 'PE', 'rank': 0, 'color': 0},
#    {'id': 16670805, 'text': 'Software Consolidators', 'rank': 0, 'color': 0}]}]

# %%
url = "https://api.affinity.co/field-values"
data = {
    "field_id": field_id,
    "entity_id": organization_id,
    "entity_type": "organization",
    "value": "New tag"
}
requests.post(url, auth=HTTPBasicAuth('', api_key), json=data)
response.json()
# Out:
# {'id': 13572633739,
#  'field_id': 4696722,
#  'list_entry_id': None,
#  'entity_type': 1,
#  'value_type': 2,
#  'entity_id': 299266107,
#  'created_at': '2024-10-23T06:23:36.862-07:00',
#  'updated_at': None,
#  'value': 'New tag'}

# %%
def create_organization(name, website_url):
    prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
    for prefix in prefixes:
        if website_url.startswith(prefix):
            website_url = website_url[len(prefix):]
            break

    url = "https://api.affinity.co/organizations"
    data = {'name': name, 'domain': website_url}

    response = requests.post(url, auth=HTTPBasicAuth('', api_key), json=data)
    organization = response.json()
    organization_id = organization.get('id')
    return organization_id

# %%
create_organization("NewTestCompany", "NewTestCompany.com")
# Out:
# {'id': 299266107,
#  'name': 'NewTestCompany',
#  'domain': 'newtestcompany.com',
#  'domains': ['newtestcompany.com'],
#  'crunchbase_uuid': None,
#  'global': False,
#  'person_ids': []}

# %%
website_url = "https://neo-mobility.be"

prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
for prefix in prefixes:
    if website_url.startswith(prefix):
        website_url = website_url[len(prefix):]
        break

# %%
url = f"https://api.affinity.co/field-values?organization_id={organization_id}"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
print(response.json())
organizations = response.json().get("organizations", [])
for organization in organizations:
    if organization.get('domain') == website_url:
        organisation_id = organization.get('id')
# Out:
# [{'id': 13567512466, 'field_id': 4768744, 'list_entry_id': 172098674, 'entity_type': 1, 'value_type': 7, 'entity_id': 299266107, 'created_at': '2024-10-22T09:04:09.250-07:00', 'updated_at': None, 'value': {'id': 16696433, 'text': 'New', 'rank': 1, 'color': 1}}]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 4
#       2 response = requests.get(url, auth=HTTPBasicAuth('', api_key))
#       3 print(response.json())
# ----> 4 organizations = response.json().get("organizations", [])
#       5 for organization in organizations:
#       6     if organization.get('domain') == website_url:
#
# AttributeError: 'list' object has no attribute 'get'

# %%
organisation_id = 1687144

# %%
def update_affinity_field(company_info):
    # Clean up the website URL by removing prefixes
    website_url = company_info.get("Website URL")
    prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
    for prefix in prefixes:
        if website_url.startswith(prefix):
            website_url = website_url[len(prefix):]
            break

    # Find the organization by domain
    url = f"https://api.affinity.co/organizations?term={website_url}"
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    organizations = response.json().get("organizations", [])
    organization_id = None
    for organization in organizations:
        if organization.get('domain') == website_url:
            organization_id = organization.get('id')
            break

    # Get the list fields
    url = f'https://api.affinity.co/lists/{list_id}'
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    list_fields = response.json().get("fields", [])

    url = f"https://api.affinity.co/lists/{list_id}/list-entries"
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    list_entries = response.json()
    list_entry_id = None
    for list_entry in list_entries:
        entity = list_entry.get('entity', {})
        entity_domain = entity.get('domain', '')
        if entity_domain == website_url:
            list_entry_id = list_entry.get('id')
            break

    # For each field in the list, update it with the corresponding value from company_info
    for list_field in list_fields:
        field_name = list_field.get("name")
        field_id = list_field.get("id")
        if field_name in company_info:
            new_value = company_info[field_name]
            dropdown_options = list_field.get('dropdown_options', [])
            if dropdown_options:
                dropdown_option_id = None
                for option in dropdown_options:
                    if option.get('text') == new_value:
                        new_value = option.get('id')
                        break

            # Get existing field values for the organization
            url = f"https://api.affinity.co/field-values?organization_id={organization_id}"
            response = requests.get(url, auth=HTTPBasicAuth('', api_key))
            organization_fields = response.json()
            field_value_id = None
            for field_value in organization_fields:
                if field_value.get("field_id") == field_id:
                    field_value_id = field_value.get("id")
                    break
            if field_value_id:
                # Update existing field value
                url = f"https://api.affinity.co/field-values/{field_value_id}"
                data = {'value': new_value}
                response = requests.put(url, auth=HTTPBasicAuth('', api_key), json=data)
            else:
                url = "https://api.affinity.co/field-values"
                data = {'field_id': field_id, 'value': new_value, 'entity_id': organization_id, 'list_entry_id': list_entry_id}
                response = requests.post(url, auth=HTTPBasicAuth('', api_key), json=data)

    return

# %%
company_info = {"Website URL": "psg.fr", "Test": "Ok boy", 'Status': "To be contacted"}
update_affinity_field(company_info)
# Out:
# 16696435 4768744
# Ok boy 4769046

# %%
import requests
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
api_key = os.getenv("AFFINITY_API_KEY")

list_id = 271745

def create_organization(name, website_url):
    # Remove all prefixes from website_url
    prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
    for prefix in prefixes:
        if website_url.startswith(prefix):
            website_url = website_url[len(prefix):]
            break

    url = "https://api.affinity.co/organizations"
    data = {
        'name': name,
        'domain': website_url
    }

    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    organization = response.json()
    organization_id = organization.get('id')
    return organization_id

def create_list_entry(organization_id):
    url = f"https://api.affinity.co/lists/{list_id}/list-entries"
    headers = {
        'Content-Type': 'application/json',
        'X-API-Key': api_key
    }
    data = {
        'entity_id': organization_id
    }

    response = requests.post(url, headers=headers, json=data)
    if response.status_code == 201:
        return
    else:
        print(f"Error adding organization to list: {response.text}")
        return

def update_status_field(organization_id):
    # Get the field ID for the "Status" field
    field_id = get_field_id("Status")
    if not field_id:
        print("Status field not found.")
        return

    url = "https://api.affinity.co/field-values"
    headers = {
        'Content-Type': 'application/json',
        'X-API-Key': api_key
    }
    data = {
        'field_id': field_id,
        'organization_id': organization_id,
        'value': 'To Screen'
    }

    response = requests.post(url, headers=headers, json=data)
    if response.status_code in [200, 201]:
        return
    else:
        print(f"Error updating status field: {response.text}")
        return

def get_field_id(field_name):
    url = "https://api.affinity.co/fields"
    headers = {
        'X-API-Key': api_key
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        fields = response.json()
        for field in fields:
            if field['name'] == field_name:
                return field['id']
    else:
        print(f"Error fetching fields: {response.text}")
    return None

def add_company_to_affinity(company_info):
    name = company_info.get("Name")
    website_url = company_info.get("Website URL")

    organization_id = create_organization(name, website_url)
    if organization_id:
        create_list_entry(organization_id)
        update_status_field(organization_id)
    return

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("AFFINITY_API_KEY") 

list_id = 271745

# %%
def create_organization(name, website_url):

    remove all https://, http://, http://www., https://www., www. from website_url
    
curl -X POST "https://api.affinity.co/organizations" \
   -u :$APIKEY \
   -H "Content-Type: application/json" \
   -d '{"name": name, "domain": website_url
    
    return organization_id

# %%
def create_list_entry(organization_id):

    curl -X POST “https://api.affinity.co/lists/{list_id}/list-entries” \
   -u :$APIKEY \
   -H "Content-Type: application/json" \
   -d '{"entity_id": organization_id}'
    
    return

# %%
def update_field(organization_id, list_id):

    url = f'https://api.affinity.co/fields?list_id={list_id}'
    all_list_fields = requests.get(url, auth=HTTPBasicAuth('', api_key))
    
    for field_name in company_info:
        field_id = all_list_fields.get("id", "") where all_list_fields.get("name", "") == field_name

    return

# %%
def find a name to say that I add a company to affinity but stay short(company_info)
    company_info.get("Name" and "Website URL")
    organization_id = create_organization(name, website_url)
    update_field(organization_id, list_id)
    return

# %%
def update_field(organization_id, list_id):

    url = f'https://api.affinity.co/fields?list_id={list_id}'
    all_list_fields = requests.get(url, auth=HTTPBasicAuth('', api_key))
    
    for field_name in company_info:
        field_id = all_list_fields.get("id", "") where all_list_fields.get("name", "") == field_name
    
    


        
        field_id = get_field_id(field_name, headers)
    if not field_id:
        return f"Field '{field_name}' not found."

    organization_id = company_info['organization_id']

    # Step 2: Check if a field value already exists for the organization
    existing_field_value = get_existing_field_value(organization_id, field_id, headers)

    if existing_field_value:
        # Step 3: Update the existing field value
        field_value_id = existing_field_value['id']
        url = f'https://api.affinity.co/field-values/{field_value_id}'
        data = {'value': 'To Screen'}
        response = requests.patch(url, headers=headers, json=data)
    else:
        # Step 4: Create a new field value
        url = 'https://api.affinity.co/field-values'
        data = {
            'field_id': field_id,
            'organization_id': organization_id,
            'value': 'To Screen'
        }
        response = requests.post(url, headers=headers, json=data)

    if response.status_code in [200, 201]:
        return "Affinity updated successfully"
    else:
        return f"Error updating Affinity: {response.text}"

def get_existing_field_value(organization_id, field_id, headers):
    url = f'https://api.affinity.co/organizations/{organization_id}/field-values'
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return None
    field_values = response.json()
    for fv in field_values:
        if fv['field']['id'] == field_id:
            return fv
    return None

# %%
url = 'https://api.affinity.co/fields'

# %%
url = f'https://api.affinity.co/organizations/{oragnization_id}'
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
person_ids = response.json().get("person_ids")
for person_id in person_ids:
    url = f'https://api.affinity.co/persons/{person_id}'
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    "FirstName" = response.json().get("first_name")
    "LastName" = response.json().get("last_name")
    "Email" = response.json().get("primary_email" if not emails[0])
# Out:
# {'id': 166524725, 'type': 0, 'first_name': 'Wim', 'last_name': 'Vernaeve', 'primary_email': 'wim.vernaeve@gmail.com', 'emails': ['wim.vernaeve@gmail.com', 'wim.vernaeve@greenparkinvest.com', 'wim.vernaeve@googlemail.com', 'wim@bragster.com', 'wim_vernaeve@hotmail.com', 'mlnamc17tpfh20u0vp25fsrmn4@group.calendar.google.com'], 'organization_ids': [1516330, 1687144, 163299958], 'list_entries': []}
# {'id': 168464200, 'type': 0, 'first_name': 'NoName', 'last_name': 'Inthepocket.mobi@allusers.d.calendar.google.com', 'primary_email': 'inthepocket.mobi@allusers.d.calendar.google.com', 'emails': ['inthepocket.mobi@allusers.d.calendar.google.com'], 'organization_ids': [1687144], 'list_entries': []}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 6
#       4 for person_id in person_ids:
#       5     url = f'https://api.affinity.co/persons/{person_id}'
# ----> 6     response = requests.get(url, auth=HTTPBasicAuth('', api_key))
#       7     print(response.json())
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#     730 response_conn = conn if not release_conn else None
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463             httplib_response = conn.getresponse()
#     464         except BaseException as e:
#     465             # Remove the TypeError from the exception chain in
#     466             # Python 3 (including for exceptions like SystemExit).
#     467             # Otherwise it looks like a bug in the code.
# --> 468             six.raise_from(e, None)
#     469 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     470     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:463, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 except TypeError:
#     461     # Python 3
#     462     try:
# --> 463         httplib_response = conn.getresponse()
#     464     except BaseException as e:
#     465         # Remove the TypeError from the exception chain in
#     466         # Python 3 (including for exceptions like SystemExit).
#     467         # Otherwise it looks like a bug in the code.
#     468         six.raise_from(e, None)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
person_ids = response.json().get("person_ids")
for person_id in person_ids:
    url = f'https://api.affinity.co/persons/{person_id}'
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    print(response.json())

# %%
url = f"{base_url}/lists/{list_id}/list-entries"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))

response.json()
# Out:
# [{'id': 171964735,
#   'list_id': 271745,
#   'creator_id': 185792297,
#   'entity_id': 224088093,
#   'entity_type': 1,
#   'created_at': '2024-10-21T06:10:54.842-07:00',
#   'entity': {'id': 224088093,
#    'name': 'Cytocast',
#    'domain': 'cytocast.com',
#    'domains': ['cytocast.com'],
#    'crunchbase_uuid': None,
#    'global': True}},
#  {'id': 171964736,
#   'list_id': 271745,
#   'creator_id': 185792297,
#   'entity_id': 299211990,
#   'entity_type': 1,
#   'created_at': '2024-10-21T06:10:54.842-07:00',
#   'entity': {'id': 299211990,
#    'name': 'Neo mobility',
#    'domain': 'neo-mobility.be',
#    'domains': ['neo-mobility.be'],
#    'crunchbase_uuid': None,
#    'global': False}},
#  {'id': 171705227,
#   'list_id': 271745,
#   'creator_id': 185792297,
#   'entity_id': 1687144,
#   'entity_type': 1,
#   'created_at': '2024-10-18T05:25:21.785-07:00',
#   'entity': {'id': 1687144,
#    'name': 'Google',
#    'domain': 'google.com',
#    'domains': ['google.com',
#     'greenparrotpictures.com',
#     'newsinitiative.withgoogle.com',
#     'infinitypocket.blogspot.in',
#     'midnightboom.blogspot.co.uk'],
#    'crunchbase_uuid': None,
#    'global': True}},
#  {'id': 171704891,
#   'list_id': 271745,
#   'creator_id': 185792297,
#   'entity_id': 294139876,
#   'entity_type': 1,
#   'created_at': '2024-10-18T05:12:46.467-07:00',
#   'entity': {'id': 294139876,
#    'name': 'Tekst.ai',
#    'domain': 'tekst.com',
#    'domains': ['tekst.com'],
#    'crunchbase_uuid': None,
#    'global': True}}]

# %%
url = f"{base_url}/field-values?organization_id=224088093"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
response.json()
# Out:
# [{'id': 13542527317,
#   'field_id': 4711807,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 7,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': {'id': 16671075, 'text': 'To Screen', 'rank': 7, 'color': 0}},
#  {'id': 13542527318,
#   'field_id': 4711827,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': 'Advanced simulation technology for drug discovery and personalized medicine using multi-omics data.'},
#  {'id': 13542527319,
#   'field_id': 4711828,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': 'TechBio'},
#  {'id': 13542527320,
#   'field_id': 4711829,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': '-'},
#  {'id': 13542527321,
#   'field_id': 4733935,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': 'B2B'},
#  {'id': 13542527322,
#   'field_id': 4733936,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': 'Subscription'},
#  {'id': 13542527323,
#   'field_id': 4761134,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': '{\'https://www.cytocast.com\': "H1: Home\\nH1: Imagine...a world where new therapies can be discovered and developed in a fraction of what it takes now.\\nH1: How can we help?\\nH1: People and Values\\nH1: How we do it\\nH1: 0\\nH1: 0\\nH1: 0\\nH1: 0\\nH1: News\\nH1: Blog\\nH1: Interested in a demo?\\nH2: Drug Discovery\\nH2: Precision medicine\\nH2: MAKE MEDICINE BETTER WITH ADVANCED CELL SIMULATION TECHNOLOGY\\nH2: Cytocast is using computer simulations to determine the most effective treatment for patients while minimazing potential side effects\\nH2: Proteins per simulation\\nH2: Protein-protein interactions\\nH2: Binding sites per simulation\\nH2: Nr. of cell types\\nH3: OUR VALUES\\nH3: THE TEAM\\nPARAGRAPH: Join our pilot study partnership to test Cytocast Simulated Cell!\\nPARAGRAPH: a world where new therapies can be discovered and developed in a fraction of what it takes now.\\nPARAGRAPH: Cytocast is an emerging TechBio startup based in Budapest that  specializes in data-driven medical technology. We leverage this data to  add value and achieve impactful results.\\nPARAGRAPH: We are proud to be a company with a curious mindset and a strong research orientation.  What sets us apart is the way we integrate multi-omics data, extensive scientific knowledge, expertise, high-performance computing, and cutting-edge data science methods to maximize insights into patient biology and accelerate the pace of drug discovery and development.  We also have the privilege of working with numerous collaborative partners.  We value these partnerships and recognize their importance in advancing our mission.\\nPARAGRAPH: At Cytocast, we believe in creative solutions and in the power of teamwork in a familiar atmosphere. Many of our team members have university affiliations continually exploring new possibilities.\\nPARAGRAPH: Last week, we had the pleasure of presenting Cytocast\'s cutting-edge technology at the 4th Digital Health Summit as the Best Solution in the Digital Therapy category winner.\\nPARAGRAPH: We are thrilled to announce that we have successfully secured our second investment round...\\nPARAGRAPH: Cytocast team recently participated in the Hungarian Molecular Life Science Conference held in Eger. The conference...\\nPARAGRAPH: Cytocast\\xa0 has made significant strides during the second quarter of 2024, advancing its cutting-edge technology in the field of digital twin simulations and predictive algorithms.\\nPARAGRAPH: Cytocast, at the forefront of innovation, utilizes AI in the Cytocast Simulated Cell to model drug-target interactions, predict efficacy, and identify potential side effects early in drug development. Our commitment extends to ethical considerations, ensuring responsible AI use in shaping the future of drug discovery.\\nPARAGRAPH: Get in touch today to see how the Cytocast platform works.", \'https://www.cytocast.com/cytocast-digital-twin/\': "H1: No Title\\nPARAGRAPH: Join our pilot study partnership to test Cytocast Simulated Cell!\\nH1: Transforming Patient CareEmbark on a groundbreaking journey towards personalized medicine with Cytocast Digital Twin. Our revolutionary technology combines multi-omics data and patient-specific clinical information to create an exact digital replica of each individual.\\nPARAGRAPH: Embark on a groundbreaking journey towards personalized medicine with Cytocast Digital Twin. Our revolutionary technology combines multi-omics data and patient-specific clinical information to create an exact digital replica of each individual.\\nH1: Cytocast™ Digital Twin\\nPARAGRAPH: We use data to add value and generate meaningful results thatdrive positive technological progress in precision medicine. Our aim with Cytocast™ Digital Twin is to significantly improve treatment efficacy and provide patients with effective therapeutic options.\\n**drive positive technological progress in precision medicine**\\nPARAGRAPH: Our latest breakthrough technology, the Cytocast™ Digital Twi ...
#  {'id': 13542527640,
#   'field_id': 3909160,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.221-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527645,
#   'field_id': 3909163,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.265-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527650,
#   'field_id': 3909164,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.305-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527668,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527666,
#   'field_id': 3909168,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 5,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.338-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527670,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527671,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527672,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527673,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527674,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527683,
#   'field_id': 3909169,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 4,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.418-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527693,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527694,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527695,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527709,
#   'field_id': 3909166,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.488-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527697,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527698,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527699,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527719,
#   'field_id': 3909165,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.525-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527724,
#   'field_id': 3909167,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.553-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527729,
#   'field_id': 3909177,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.595-07:00',
#   'updated_at': None,
#   'value': 2340900.0},
#  {'id': 13542527743,
#   'field_id': 3909178,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.638-07:00',
#   'updated_at': None,
#   'value': 1836000.0},
#  {'id': 13542527772,
#   'field_id': 3909175,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.827-07:00',
#   'updated_at': None,
#   'value': 15.0},
#  {'id': 13542527752,
#   'field_id': 3909174,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.696-07:00',
#   'updated_at': None,
#   'value': "Cytocast is a TechBio startup company pioneering the future of drug development with its revolutionary Cytocast Simulated Cell platform. We're transforming the landscape by enabling safer and smarter drug development, putting patient well-being at the forefront. By combining multi-omics data integration with advanced computational modeling, we're redefining drug development. Our platform allows us to predict how different drugs will affect cellular processes, making drug side effect predictions in the early phases of drug development a reality. Our focus extends to the future of personalized medicine. We're advancing beyond one-size-fits-all treatments, embracing tailored therapies powered by advanced technologies to revolutionize drug development."},
#  {'id': 13542527776,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Bioinformatics'},
#  {'id': 13542527777,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Biotechnology'},
#  {'id': 13542527778,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Computer'},
#  {'id': 13542527779,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Pharmaceutical'},
#  {'id': 13542527780,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Simulation'},
#  {'id': 13542527784,
#   'field_id': 3909176,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.865-07:00',
#   'updated_at': None,
#   'value': 2019.0},
#  {'id': 13542527788,
#   'field_id': 3909182,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.910-07:00',
#   'updated_at': None,
#   'value': 'https://linkedin.com/company/cytocast'},
#  {'id': 13542527793,
#   'field_id': 3909179,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 5,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.970-07:00',
#   'updated_at': None,
#   'value': {'street_address': None,
#    'city': 'Budapest',
#    'state': 'Budapest',
#    'country': 'Hungary',
#    'continent': None}},
#  {'id': 13542529074,
#   'field_id': 3909195,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.590-07:00',
#   'updated_at': None,
#   'value': 'SaaS'},
#  {'id': 13542529142,
#   'field_id': 3909190,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.778-07:00',
#   'updated_at': None,
#   'value': 'Venture Capital'},
#  {'id': 13542529145,
#   'field_id': 3909190,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.778-07:00',
#   'updated_at': None,
#   'value': 'accelerator'},
#  {'id': 13542529159,
#   'field_id': 3909197,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.821-07:00',
#   'updated_at': None,
#   'value': 2040000.0},
#  {'id': 13542529081,
#   'field_id': 3909194,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.611-07:00',
#   'updated_at': None,
#   'value': 'b2b'},
#  {'id': 13542529140,
#   'field_id': 3909201,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 5,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.770-07:00',
#   'updated_at': None,
#   'value': {'street_address': None,
#    'city': 'Budapest',
#    'state': 'Budapest',
#    'country': 'Hungary',
#    'continent': None}},
#  {'id': 13542529116,
#   'field_id': 3909191,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.678-07:00',
#   'updated_at': None,
#   'value': 'Subscription'},
#  {'id': 13542529153,
#   'field_id': 3909188,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.803-07:00',
#   'updated_at': None,
#   'value': 'Artificial Intelligence'},
#  {'id': 13542529154,
#   'field_id': 3909188,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.803-07:00',
#   'updated_at': None,
#   'value': 'Big Data'},
#  {'id': 13542529176,
#   'field_id': 3909186,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.862-07:00',
#   'updated_at': None,
#   'value': 97.0},
#  {'id': 13542529091,
#   'field_id': 3909199,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.646-07:00',
#   'updated_at': None,
#   'value': 'Simulated cells to shape the future of medicine'},
#  {'id': 13542529102,
#   'field_id': 3909192,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.667-07:00',
#   'updated_at': None,
#   'value': '11-50'},
#  {'id': 13542529120,
#   'field_id': 3909200,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.710-07:00',
#   'updated_at': None,
#   'value': 'Health'},
#  {'id': 13542529121,
#   'field_id': 3909200,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.710-07:00',
#   'updated_at': None,
#   'value': 'Pharmaceutical'},
#  {'id': 13542529122,
#   'field_id': 3909200,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.710-07:00',
#   'updated_at': None,
#   'value': 'BioTechnology'},
#  {'id': 13542529136,
#   'field_id': 3909196,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.749-07:00',
#   'updated_at': None,
#   'value': 1600000.0},
#  {'id': 13542529165,
#   'field_id': 3909187,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.832-07:00',
#   'updated_at': None,
#   'value': 57.0},
#  {'id': 13542529183,
#   'field_id': 3909185,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.886-07:00',
#   'updated_at': None,
#   'value': 1.0},
#  {'id': 13542529197,
#   'field_id': 3909184,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.916-07:00',
#   'updated_at': None,
#   'value': 53.0},
#  {'id': 13542529200,
#   'field_id': 3909183,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.929-07:00',
#   'updated_at': None,
#   'value': 'https://app.dealroom.co/companies/cytocast'},
#  {'id': 13542529212,
#   'field_id': 3909198,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.962-07:00',
#   'updated_at': None,
#   'value': 2019.0}]

# %%
field_value_id = 13542527317  # The field value ID you're trying to update
value = 16696434  # The dropdown ID for 'To Screen'

# Update URL
url = f"{base_url}/field-values/{field_value_id}"

# Correct payload: just send the integer value (dropdown option ID)
payload = {
    "value": {"id": (value)}  # Use the ID of the dropdown option as the value
}

# Make the PUT request to update the field value
response = requests.put(url, json=payload, auth=HTTPBasicAuth('', api_key))

# Check the response
print(response.status_code)
print(response.json())
# Out:
# 422
# ["Field value: Record doesn't have field entity_attribute_id set to 4711807 (Affinity::Validator::HasFieldError)"]

# %%
response.json()
# Out:
# ["Field value: Record doesn't have field entity_attribute_id set to 4711807 (Affinity::Validator::HasFieldError)"]

# %%
Hello,

I have a problem to update the Status field via an API request here is a simple python example:

from the list ID "271745" I want to modify the entity Cytocast here is it's dictionnary:
{'id': 171964735,
  'list_id': 271745,
  'creator_id': 185792297,
  'entity_id': 224088093,
  'entity_type': 1,
  'created_at': '2024-10-21T06:10:54.842-07:00',
  'entity': {'id': 224088093,
   'name': 'Cytocast',
   'domain': 'cytocast.com',
   'domains': ['cytocast.com'],
   'crunchbase_uuid': None,
   'global': True}}

from the Status filed in the API-test list here is it's dictionnary of the field:
[{'id': 13542527317,
  'field_id': 4711807,
  'list_entry_id': 171673564,
  'entity_type': 1,
  'value_type': 7,
  'entity_id': 224088093,
  'created_at': '2024-10-18T01:35:15.900-07:00',
  'updated_at': None,
  'value': {'id': 16671075, 'text': 'To Screen', 'rank': 7, 'color': 0}},

 the field value id is this:
[{'id': 13542527317,
  'field_id': 4711807,
  'list_entry_id': 171673564,
  'entity_type': 1,
  'value_type': 7,
  'entity_id': 224088093,
  'created_at': '2024-10-18T01:35:15.900-07:00',
  'updated_at': None,
  'value': {'id': 16671075, 'text': 'To Screen', 'rank': 7, 'color': 0}},

 But when I try:
    
field_value_id = 13542527317
value = 16696434

# Update URL
url = f"{base_url}/field-values/{field_value_id}"

# Correct payload: just send the integer value (dropdown option ID)
payload = {
    "value": str(value)  # Use the ID of the dropdown option as the value
}

# Make the PUT request to update the field value
response = requests.put(url, json=payload, auth=HTTPBasicAuth('', api_key))

I get:
["Field value: Record doesn't have field entity_attribute_id set to 4711807 (Affinity::Validator::HasFieldError)"]
# Out:
#   Cell In[48], line 5
#     from the list ID "271745" I want to modify the entity Cytocast here is it's dictionnary:
#                                                                              ^
# SyntaxError: unterminated string literal (detected at line 5)
