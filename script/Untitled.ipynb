# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("AFFINITY_API_KEY") 

list_id = 271745

# %%
organization_id = 299266107

# %%
email = "gmail"

# %%
url = f"https://api.affinity.co/organizations/fields"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
global_fields = response.json()

for global_field in global_fields:
    where global_field.get("list_id", "") == 271745:
    print global_field
# Out:
# [{'id': 3909160,
#   'name': 'Investment Stage',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 2,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909163,
#   'name': 'Description',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909165,
#   'name': 'Year Founded',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909164,
#   'name': 'Number of Employees',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909168,
#   'name': 'Location',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 5,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909161,
#   'name': 'Industry',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909169,
#   'name': 'Last Funding Date',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 4,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909162,
#   'name': 'Investors',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909170,
#   'name': 'Source of Introduction',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 0,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909166,
#   'name': 'Total Funding Amount (USD)',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909167,
#   'name': 'Last Funding Amount (USD)',
#   'list_id': None,
#   'enrichment_source': 'crunchbase',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909174,
#   'name': 'Description',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909175,
#   'name': 'Number of Employees',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909172,
#   'name': 'Industry',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909171,
#   'name': 'Investment Stage',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 2,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909173,
#   'name': 'Investors',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909178,
#   'name': 'Last Funding Amount (USD)',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909180,
#   'name': 'Last Funding Date',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 4,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909179,
#   'name': 'Location',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 5,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909177,
#   'name': 'Total Funding Amount (USD)',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909176,
#   'name': 'Year Founded',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909182,
#   'name': 'LinkedIn URL',
#   'list_id': None,
#   'enrichment_source': 'affinity-data',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909183,
#   'name': 'Dealroom.co URL',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909193,
#   'name': 'Corporate Industries',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909189,
#   'name': 'Service Industries',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909188,
#   'name': 'Technologies',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909191,
#   'name': 'Income Streams',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909195,
#   'name': 'Revenue Model',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909190,
#   'name': 'Ownership Types',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909187,
#   'name': 'Total Tweets',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909185,
#   'name': 'Last Month Change in Twitter Followers',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909186,
#   'name': 'Last Month Twitter Favorites',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909192,
#   'name': 'Number of Employees',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909201,
#   'name': 'Location',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 5,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909194,
#   'name': 'Client Type',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909199,
#   'name': 'Description',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909200,
#   'name': 'Industry',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909198,
#   'name': 'Year Founded',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909197,
#   'name': 'Total Funding Amount (EUR)',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909196,
#   'name': 'Last Funding Amount (EUR)',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 3909184,
#   'name': 'Last Month Twitter Followers',
#   'list_id': None,
#   'enrichment_source': 'dealroom',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 4696722,
#   'name': 'Tag',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 2,
#   'allows_multiple': True,
#   'track_changes': False,
#   'dropdown_options': [{'id': 16673587,
#     'text': 'CBE Oktober',
#     'rank': 0,
#     'color': 0},
#    {'id': 16650877, 'text': 'Cbe_screen (2) F', 'rank': 0, 'color': 0},
#    {'id': 16652444, 'text': 'Combined_startups_urls', 'rank': 0, 'color': 0},
#    {'id': 15091553, 'text': 'Erwan Shared Dealflow', 'rank': 0, 'color': 0},
#    {'id': 15290235, 'text': 'Evert VC share 26/09', 'rank': 0, 'color': 0},
#    {'id': 16691204, 'text': "Ghent Slush'D 2024", 'rank': 0, 'color': 0},
#    {'id': 16690887,
#     'text': 'Health_Tech_101824_One_Pager_18-10-2024',
#     'rank': 0,
#     'color': 0},
#    {'id': 16544171, 'text': 'HF0', 'rank': 0, 'color': 0},
#    {'id': 16416172, 'text': 'Miles Ahead', 'rank': 0, 'color': 0},
#    {'id': 16696612, 'text': 'Ping Evert', 'rank': 0, 'color': 0},
#    {'id': 16696623, 'text': 'Ping Tibe', 'rank': 0, 'color': 0},
#    {'id': 16514649, 'text': 'Pipeline review', 'rank': 0, 'color': 0},
#    {'id': 16671074,
#     'text': 'Plug & Play University Of Oxford 10 16 2024',
#     'rank': 0,
#     'color': 0},
#    {'id': 16697795, 'text': 'To Screen', 'rank': 0, 'color': 0},
#    {'id': 15023041, 'text': 'Wintercircus Campus', 'rank': 0, 'color': 0},
#    {'id': 16697132, 'text': 'YAYAYA', 'rank': 0, 'color': 0}]},
#  {'id': 4102034,
#   'name': 'Amount Invested $',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 3,
#   'allows_multiple': False,
#   'track_changes': True,
#   'dropdown_options': []},
#  {'id': 4102044,
#   'name': 'Talent we should track?',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 2,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 4102045,
#   'name': 'Talent comment',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 4129749,
#   'name': 'Source',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 4771841,
#   'name': 'Outreach status',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 7,
#   'allows_multiple': False,
#   'track_changes': True,
#   'dropdown_options': [{'id': 16713560,
#     'text': 'PJ to reach out',
#     'rank': 1,
#     'color': 0},
#    {'id': 16713561, 'text': 'Evert to reach out', 'rank': 2, 'color': 0},
#    {'id': 16713562, 'text': 'Outreach completed', 'rank': 3, 'color': 0}]},
#  {'id': 4541158,
#   'name': 'Synopsis',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 4541157,
#   'name': 'Oneliner',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 6,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': []},
#  {'id': 4763673,
#   'name': 'Tag List',
#   'list_id': None,
#   'enrichment_source': 'none',
#   'value_type': 2,
#   'allows_multiple': False,
#   'track_changes': False,
#   'dropdown_options': [{'id': 16670849,
#     'text': 'Non-US Software ICP',
#     'rank': 0,
#     'color': 0},
#    {'id': 16684084, 'text': 'PE', 'rank': 0, 'color': 0},
#    {'id': 16670805, 'text': 'Software Consolidators', 'rank': 0, 'color': 0}]}]

# %%
url = f"https://api.affinity.co/persons?term={email}"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
persons = response.json().get("persons", []):
if persons empty:
    curl -X POST "https://api.affinity.co/persons" \
   -u :$APIKEY \
   -H "Content-Type: application/json" \
   -d '{"first_name": first_name, "last_name": last_name, "emails": it's a list [email], "organization_ids": its a list [organization_id]}'
# Out:
# {'persons': [{'id': 209030676,
#    'type': 0,
#    'first_name': 'Louis',
#    'last_name': 'Rombouts',
#    'primary_email': 'louisrombouts93@gmail.com',
#    'emails': ['louisrombouts93@gmail.com']},
#   {'id': 209010826,
#    'type': 0,
#    'first_name': 'Hendrik',
#    'last_name': 'Vervust',
#    'primary_email': 'hendrik.vervust@gmail.com',
#    'emails': ['hendrik.vervust@gmail.com']},
#   {'id': 208989436,
#    'type': 0,
#    'first_name': 'Wim',
#    'last_name': 'Focquet',
#    'primary_email': 'wim.foc@gmail.com',
#    'emails': ['wim.foc@gmail.com']},
#   {'id': 208902069,
#    'type': 0,
#    'first_name': 'Jesus',
#    'last_name': 'Castello',
#    'primary_email': 'jemonleon@gmail.com',
#    'emails': ['jemonleon@gmail.com']},
#   {'id': 208877399,
#    'type': 0,
#    'first_name': 'Gino',
#    'last_name': 'Engels',
#    'primary_email': 'engels.gino@gmail.com',
#    'emails': ['engels.gino@gmail.com']},
#   {'id': 208714487,
#    'type': 0,
#    'first_name': 'Milan',
#    'last_name': 'Simic',
#    'primary_email': 'simicmilan593@gmail.com',
#    'emails': ['simicmilan593@gmail.com']},
#   {'id': 208712504,
#    'type': 0,
#    'first_name': 'Pieter',
#    'last_name': 'Mollet',
#    'primary_email': 'pmollet@gmail.com',
#    'emails': ['pmollet@gmail.com', 'pieter.mollet@molecubes.com']},
#   {'id': 208608265,
#    'type': 0,
#    'first_name': 'David',
#    'last_name': 'Mary',
#    'primary_email': 'david.mary1980@gmail.com',
#    'emails': ['david.mary1980@gmail.com']},
#   {'id': 208604102,
#    'type': 0,
#    'first_name': 'Paul',
#    'last_name': 'Haspeslagh',
#    'primary_email': 'paul.haspeslagh@gmail.com',
#    'emails': ['paul.haspeslagh@gmail.com']},
#   {'id': 208566242,
#    'type': 0,
#    'first_name': 'Markus',
#    'last_name': 'Seebacher',
#    'primary_email': 'm.seebacher@gmail.com',
#    'emails': ['m.seebacher@gmail.com']},
#   {'id': 208484682,
#    'type': 0,
#    'first_name': 'Shivakumar',
#    'last_name': 'Marulshetty',
#    'primary_email': 'withshivukumar@gmail.com',
#    'emails': ['withshivukumar@gmail.com']},
#   {'id': 208381174,
#    'type': 0,
#    'first_name': 'Charlotte',
#    'last_name': 'Bussche',
#    'primary_email': 'charlotte.vandenbussche@gmail.com',
#    'emails': ['charlotte.vandenbussche@gmail.com',
#     'charlotte.vandenbusshce@gmail.com']},
#   {'id': 208339835,
#    'type': 0,
#    'first_name': 'Servaas',
#    'last_name': 'Strobbe',
#    'primary_email': 'servaasstrobbe@gmail.com',
#    'emails': ['servaasstrobbe@gmail.com']},
#   {'id': 208124381,
#    'type': 0,
#    'first_name': 'Garage',
#    'last_name': 'Dépannage Loriers & Fils SPRL',
#    'primary_email': 'depannage.loriers@gmail.com',
#    'emails': ['depannage.loriers@gmail.com']},
#   {'id': 208024231,
#    'type': 0,
#    'first_name': 'Robby',
#    'last_name': 'Van den Wyngaert',
#    'primary_email': 'robbyvandenwyngaert@gmail.com',
#    'emails': ['robbyvandenwyngaert@gmail.com']},
#   {'id': 207939375,
#    'type': 0,
#    'first_name': 'Pieter',
#    'last_name': 'Heytens',
#    'primary_email': 'pieter.heytens@gmail.com',
#    'emails': ['pieter.heytens@gmail.com']},
#   {'id': 207909904,
#    'type': 0,
#    'first_name': 'Andra',
#    'last_name': 'Kopandi',
#    'primary_email': 'andrakopandi@gmail.com',
#    'emails': ['andrakopandi@gmail.com']},
#   {'id': 207485695,
#    'type': 0,
#    'first_name': 'Lucas',
#    'last_name': 'Tamboryn',
#    'primary_email': 'lucas.tamboryn@gmail.com',
#    'emails': ['lucas.tamboryn@gmail.com']},
#   {'id': 207481803,
#    'type': 0,
#    'first_name': 'Rik',
#    'last_name': 'Bauwens',
#    'primary_email': 'rikbauwens1@gmail.com',
#    'emails': ['rikbauwens1@gmail.com']},
#   {'id': 207093760,
#    'type': 0,
#    'first_name': 'Jens',
#    'last_name': 'Debergh',
#    'primary_email': 'jensdebergh@gmail.com',
#    'emails': ['jensdebergh@gmail.com', 'jens@bizzey.com']},
#   {'id': 207076261,
#    'type': 0,
#    'first_name': 'Michiel',
#    'last_name': 'Van Gendt',
#    'primary_email': 'michiel.vangendt@gmail.com',
#    'emails': ['michiel.vangendt@gmail.com']},
#   {'id': 207008702,
#    'type': 0,
#    'first_name': 'Erik',
#    'last_name': 'Vandeputte',
#    'primary_email': 'erik.vandeputte@gmail.com',
#    'emails': ['erik.vandeputte@gmail.com']},
#   {'id': 206921150,
#    'type': 0,
#    'first_name': 'Vicente',
#    'last_name': 'Alabau',
#    'primary_email': 'vicentealabau106@gmail.com',
#    'emails': ['vicentealabau106@gmail.com']},
#   {'id': 206524805,
#    'type': 0,
#    'first_name': 'Alireza',
#    'last_name': 'Mahdavi',
#    'primary_email': 'arzpmv@gmail.com',
#    'emails': ['arzpmv@gmail.com']},
#   {'id': 206425109,
#    'type': 0,
#    'first_name': 'Thomas',
#    'last_name': 'Verhoef',
#    'primary_email': 'verhoef.thomas@gmail.com',
#    'emails': ['verhoef.thomas@gmail.com']},
#   {'id': 206274703,
#    'type': 0,
#    'first_name': 'Jeroen',
#    'last_name': 'Ducorney',
#    'primary_email': 'jeroenducorney@gmail.com',
#    'emails': ['jeroenducorney@gmail.com']},
#   {'id': 206235510,
#    'type': 0,
#    'first_name': 'Francesco',
#    'last_name': 'Buscaglia',
#    'primary_email': 'frabrux@gmail.com',
#    'emails': ['frabrux@gmail.com']},
#   {'id': 206189909,
#    'type': 0,
#    'first_name': 'Mikhail',
#    'last_name': 'Israelashvili',
#    'primary_email': 'mi.israelashvili@gmail.com',
#    'emails': ['mi.israelashvili@gmail.com']},
#   {'id': 206074489,
#    'type': 0,
#    'first_name': 'Matthias',
#    'last_name': 'Mandiau',
#    'primary_email': 'mmandiau@gmail.com',
#    'emails': ['mmandiau@gmail.com']},
#   {'id': 205927598,
#    'type': 0,
#    'first_name': 'Jeroen',
#    'last_name': 'Van Loock',
#    'primary_email': 'jeroenvanloock@gmail.com',
#    'emails': ['jeroenvanloock@gmail.com']},
#   {'id': 205798712,
#    'type': 0,
#    'first_name': 'Enrique',
#    'last_name': 'Sarap',
#    'primary_email': 'sarapenrique@gmail.com',
#    'emails': ['sarapenrique@gmail.com']},
#   {'id': 205776889,
#    'type': 0,
#    'first_name': 'Salah',
#    'last_name': 'Cherif',
#    'primary_email': 'salaheddinecherif9@gmail.com',
#    'emails': ['salaheddinecherif9@gmail.com']},
#   {'id': 205072661,
#    'type': 0,
#    'first_name': 'Walter',
#    'last_name': 'Vandeperre',
#    'primary_email': 'w.l.d.vandeperre@gmail.com',
#    'emails': ['w.l.d.vandeperre@gmail.com']},
#   {'id': 204986562,
#    'type': 0,
#    'first_name': 'Jordan',
#    'last_name': 'Vlietinck',
#    'primary_email': 'vlietinck86@gmail.com',
#    'emails': ['vlietinck86@gmail.com']},
#   {'id': 204750785,
#    'type': 0,
#    'first_name': 'Robbe',
#    'last_name': 'Lamaire',
#    'primary_email': 'robbe.lamaire@gmail.com',
#    'emails': ['robbe.lamaire@gmail.com']},
#   {'id': 204712191,
#    'type': 0,
#    'first_name': 'Steven',
#    'last_name': 'Ryse',
#    'primary_email': 'vande.ryse.steven@gmail.com',
#    'emails': ['vande.ryse.steven@gmail.com']},
#   {'id': 204700394,
#    'type': 0,
#    'first_name': 'Matt',
#    'last_name': 'McNeill',
#    'primary_email': 'matt.mcneill@gmail.com',
#    'emails': ['matt.mcneill@gmail.com']},
#   {'id': 204540412,
#    'type': 0,
#    'first_name': 'Jules',
#    'last_name': 'Herlem',
#    'primary_email': 'julesherlem@gmail.com',
#    'emails': ['julesherlem@gmail.com']},
#   {'id': 204469376,
#    'type': 0,
#    'first_name': 'Grzegorz',
#    'last_name': 'Kowalczyk',
#    'primary_email': 'grzegorzkowalczyk987@gmail.com',
#    'emails': ['grzegorzkowalczyk987@gmail.com']},
#   {'id': 204290281,
#    'type': 0,
#    'first_name': 'Lieselotte',
#    'last_name': 'Maenhout',
#    'primary_email': 'lieselotte.maenhout@gmail.com',
#    'emails': ['lieselotte.maenhout@gmail.com']},
#   {'id': 204290280,
#    'type': 0,
#    'first_name': 'Johan',
#    'last_name': 'Maenhout',
#    'primary_email': 'johan.maenhout@gmail.com',
#    'emails': ['johan.maenhout@gmail.com']},
#   {'id': 204183969,
#    'type': 0,
#    'first_name': 'Ithri',
#    'last_name': 'Benamara',
#    'primary_email': 'ithri2@gmail.com',
#    'emails': ['ithri2@gmail.com']},
#   {'id': 203967122,
#    'type': 0,
#    'first_name': 'Charles',
#    'last_name': 'Geurtjens',
#    'primary_email': 'charlesgeurtjens.work@gmail.com',
#    'emails': ['charlesgeurtjens.work@gmail.com']},
#   {'id': 203909852,
#    'type': 0,
#    'first_name': 'Tom',
#    'last_name': 'Volckaert',
#    'primary_email': 'ttvolcka@gmail.com',
#    'emails': ['ttvolcka@gmail.com']},
#   {'id': 203790039,
#    'type': 0,
#    'first_name': 'Henri',
#    'last_name': 'K',
#    'primary_email': 'henri.kaar@gmail.com',
#    'emails': ['henri.kaar@gmail.com']},
#   {'id': 203420151,
#    'type': 0,
#    'first_name': 'Henry',
#    'last_name': 'Wynaendts',
#    'primary_email': 'h.p.wynaendts@gmail.com',
#    'emails': ['h.p.wynaendts@gmail.com']},
#   {'id': 203414741,
#    'type': 0,
#    'first_name': 'Samuel',
#    'last_name': 'Calef',
#    'primary_email': 'samuelcalef@gmail.com',
#    'emails': ['samuelcalef@gmail.com']},
#   {'id': 203194722,
#    'type': 0,
#    'first_name': 'Yavuz',
#    'last_name': 'Ugurtas',
#    'primary_email': 'yavuzugurtas@gmail.com',
#    'emails': ['yavuzugurtas@gmail.com']},
#   {'id': 202884534,
#    'type': 0,
#    'first_name': 'Joachim',
#    'last_name': 'Jonkers',
#    'primary_email': 'joachimjonkers@gmail.com',
#    'emails': ['joachimjonkers@gmail.com']},
#   {'id': 202605462,
#    'type': 0,
#    'first_name': 'Joost',
#    'last_name': 'Lubach',
#    'primary_email': 'joostlubach@gmail.com',
#    'emails': ['joostlubach@gmail.com']},
#   {'id': 202493062,
#    'type': 0,
#    'first_name': 'Marco',
#    'last_name': 'Fazio',
#    'primary_email': 'marcofazio.it@gmail.com',
#    'emails': ['marcofazio.it@gmail.com']},
#   {'id': 202451553,
#    'type': 0,
#    'first_name': 'Benoit',
#    'last_name': 'Baervoets',
#    'primary_email': 'benoit.baervoets@gmail.com',
#    'emails': ['benoit.baervoets@gmail.com']},
#   {'id': 202242328,
#    'type': 0,
#    'first_name': 'Daan',
#    'last_name': 'Aerts',
#    'primary_email': 'daan@wildflyer.co',
#    'emails': ['daan@wildflyer.co', 'daanaerts@gmail.com']},
#   {'id': 201487750,
#    'type': 0,
#    'first_name': 'Dann',
#    'last_name': 'Bibas',
#    'primary_email': 'dannbibas@gmail.com',
#    'emails': ['dannbibas@gmail.com']},
#   {'id': 201260327,
#    'type': 0,
#    'first_name': 'Valentin',
#    'last_name': 'Grel',
#    'primary_email': 'valentingrel@gmail.com',
#    'emails': ['valentingrel@gmail.com']},
#   {'id': 200789230,
#    'type': 0,
#    'first_name': 'Jonathan',
#    'last_name': 'Amsallem',
#    'primary_email': 'jonathan.amsallem@gmail.com',
#    'emails': ['jonathan.amsallem@gmail.com']},
#   {'id': 200401554,
#    'type': 0,
#    'first_name': 'Laura',
#    'last_name': 'Oliveira',
#    'primary_email': 'lauradeoliveira.email@gmail.com',
#    'emails': ['lauradeoliveira.email@gmail.com']},
#   {'id': 200395889,
#    'type': 0,
#    'first_name': 'Theodore',
#    'last_name': 'Bourgeon',
#    'primary_email': 'theodore.bourgeon@gmail.com',
#    'emails': ['theodore.bourgeon@gmail.com']},
#   {'id': 200394432,
#    'type': 0,
#    'first_name': 'Eymeric',
#    'last_name': 'Beyo',
#    'primary_email': 'eymeric.beyo@gmail.com',
#    'emails': ['eymeric.beyo@gmail.com', 'eymeric@deal--flow.com']},
#   {'id': 200376194,
#    'type': 0,
#    'first_name': 'Samuel',
#    'last_name': 'Molnar',
#    'primary_email': 'molnar.samuel@gmail.com',
#    'emails': ['molnar.samuel@gmail.com']},
#   {'id': 200376192,
#    'type': 0,
#    'first_name': 'Roel',
#    'last_name': 'Van Holen',
#    'primary_email': 'roelvanholen@gmail.com',
#    'emails': ['roelvanholen@gmail.com']},
#   {'id': 200316080,
#    'type': 0,
#    'first_name': 'Alex',
#    'last_name': 'Rosemblat',
#    'primary_email': 'alex.rosemblat@gmail.com',
#    'emails': ['alex.rosemblat@gmail.com']},
#   {'id': 200288084,
#    'type': 0,
#    'first_name': 'Sergio',
#    'last_name': 'Miñano',
#    'primary_email': 'sergioayala.contacto@gmail.com',
#    'emails': ['sergioayala.contacto@gmail.com']},
#   {'id': 200195372,
#    'type': 0,
#    'first_name': 'Cédric',
#    'last_name': 'Josi',
#    'primary_email': 'cedriclaurentjosi@gmail.com',
#    'emails': ['cedriclaurentjosi@gmail.com', 'cedric@hexa.com']},
#   {'id': 199918073,
#    'type': 0,
#    'first_name': 'Shubham',
#    'last_name': 'Kumar',
#    'primary_email': 'shubhamkr63@gmail.com',
#    'emails': ['shubhamkr63@gmail.com']},
#   {'id': 199917274,
#    'type': 0,
#    'first_name': 'Slim',
#    'last_name': 'Gaessler',
#    'primary_email': 's.gaesslerpro@gmail.com',
#    'emails': ['s.gaesslerpro@gmail.com']},
#   {'id': 199600098,
#    'type': 0,
#    'first_name': 'Lukas',
#    'last_name': 'Demey',
#    'primary_email': 'lukas@entourage.io',
#    'emails': ['lukas@entourage.io', 'lukas.demey11@gmail.com']},
#   {'id': 199514389,
#    'type': 0,
#    'first_name': 'Elise',
#    'last_name': 'Vanspeybrouck',
#    'primary_email': 'elisevanspeybrouck@gmail.com',
#    'emails': ['elisevanspeybrouck@gmail.com']},
#   {'id': 199075084,
#    'type': 0,
#    'first_name': 'Paula',
#    'last_name': 'Sotelo',
#    'primary_email': 'paulamercedes.sotelo@gmail.com',
#    'emails': ['paulamercedes.sotelo@gmail.com']},
#   {'id': 198907250,
#    'type': 0,
#    'first_name': 'Laura',
#    'last_name': 'Lannoo',
#    'primary_email': 'laura.lannoo@gmail.com',
#    'emails': ['laura.lannoo@gmail.com']},
#   {'id': 198753009,
#    'type': 0,
#    'first_name': 'Jens',
#    'last_name': 'Segers',
#    'primary_email': 'segers.jens@gmail.com',
#    'emails': ['segers.jens@gmail.com']},
#   {'id': 198324188,
#    'type': 0,
#    'first_name': 'Klaas',
#    'last_name': 'Willaert',
#    'primary_email': 'klaas@tekst.com',
#    'emails': ['klaas@tekst.com', 'willaert.klaas@gmail.com']},
#   {'id': 198172571,
#    'type': 0,
#    'first_name': 'Luc',
#    'last_name': 'Mey',
#    'primary_email': 'lucdemey@gmail.com',
#    'emails': ['lucdemey@gmail.com']},
#   {'id': 197950144,
#    'type': 0,
#    'first_name': 'Lara',
#    'last_name': 'Deraes',
#    'primary_email': 'lara.deraes@gmail.com',
#    'emails': ['lara.deraes@gmail.com']},
#   {'id': 197655714,
#    'type': 0,
#    'first_name': 'Kawther',
#    'last_name': 'Zouari',
#    'primary_email': 'zouariakawther@gmail.com',
#    'emails': ['zouariakawther@gmail.com']},
#   {'id': 197655711,
#    'type': 0,
#    'first_name': 'Bart',
#    'last_name': 'Garré',
#    'primary_email': 'bartgarre@gmail.com',
#    'emails': ['bartgarre@gmail.com']},
#   {'id': 197655710,
#    'type': 0,
#    'first_name': 'Seraina',
#    'last_name': 'Karouti',
#    'primary_email': 'serainakarouti@gmail.com',
#    'emails': ['serainakarouti@gmail.com']},
#   {'id': 197214267,
#    'type': 0,
#    'first_name': 'Marc',
#    'last_name': 'Peeters',
#    'primary_email': 'marcpeetersvijf@gmail.com',
#    'emails': ['marcpeetersvijf@gmail.com']},
#   {'id': 197170910,
#    'type': 0,
#    'first_name': 'Cathrine',
#    'last_name': 'Andersen',
#    'primary_email': 'cathrinewerthwein@gmail.com',
#    'emails': ['cathrinewerthwein@gmail.com']},
#   {'id': 196815717,
#    'type': 0,
#    'first_name': 'Dries',
#    'last_name': 'Meeren',
#    'primary_email': 'vandermeerendries@gmail.com',
#    'emails': ['vandermeerendries@gmail.com']},
#   {'id': 196707030,
#    'type': 0,
#    'first_name': 'Alon',
#    'last_name': 'Meidan',
#    'primary_email': 'alon.meidan@dealroom.co',
#    'emails': ['alon.meidan@dealroom.co', 'alonmeidan@gmail.com']},
#   {'id': 195456732,
#    'type': 0,
#    'first_name': 'Stefania',
#    'last_name': 'Arioli',
#    'primary_email': 'stefy.arioli@gmail.com',
#    'emails': ['stefy.arioli@gmail.com']},
#   {'id': 195247292,
#    'type': 0,
#    'first_name': 'Roelant',
#    'last_name': 'Wijngaards',
#    'primary_email': 'rwijngaards@gmail.com',
#    'emails': ['rwijngaards@gmail.com']},
#   {'id': 195247290,
#    'type': 0,
#    'first_name': 'Mattijs',
#    'last_name': 'Tant',
#    'primary_email': 'mattijstant1@gmail.com',
#    'emails': ['mattijstant1@gmail.com']},
#   {'id': 195247289,
#    'type': 0,
#    'first_name': 'Jasper',
#    'last_name': 'Decleer',
#    'primary_email': 'decleerjasper1@gmail.com',
#    'emails': ['decleerjasper1@gmail.com']},
#   {'id': 195247288,
#    'type': 0,
#    'first_name': 'Jan',
#    'last_name': 'Beukelaer',
#    'primary_email': 'jan.beukelaer@gmail.com',
#    'emails': ['jan.beukelaer@gmail.com']},
#   {'id': 195168955,
#    'type': 0,
#    'first_name': 'Maarten',
#    'last_name': 'Schuymer',
#    'primary_email': 'maarten@aikido.dev',
#    'emails': ['maarten@aikido.dev', 'maartendeschuymer@gmail.com']},
#   {'id': 195144892,
#    'type': 0,
#    'first_name': 'Chetan',
#    'last_name': 'Kadam',
#    'primary_email': 'chetan.kadam@gmail.com',
#    'emails': ['chetan.kadam@gmail.com']},
#   {'id': 195078292,
#    'type': 0,
#    'first_name': 'Léonard',
#    'last_name': 'Julémont',
#    'primary_email': 'leonard.julemont@gmail.com',
#    'emails': ['leonard.julemont@gmail.com']},
#   {'id': 194683144,
#    'type': 0,
#    'first_name': 'Francesca',
#    'last_name': 'Giovanni',
#    'primary_email': 'degiovanni.f@gmail.com',
#    'emails': ['degiovanni.f@gmail.com']},
#   {'id': 194553808,
#    'type': 0,
#    'first_name': 'Vincent',
#    'last_name': 'Jocquet',
#    'primary_email': 'vincentjocquet@gmail.com',
#    'emails': ['vincentjocquet@gmail.com']},
#   {'id': 193662196,
#    'type': 0,
#    'first_name': 'Ser',
#    'last_name': 'Cappelle',
#    'primary_email': 'ser.cappelle@gmail.com',
#    'emails': ['ser.cappelle@gmail.com']},
#   {'id': 193062246,
#    'type': 0,
#    'first_name': 'Dan',
#    'last_name': 'Kibkalo',
#    'primary_email': 'dkibkalo@gmail.com',
#    'emails': ['dkibkalo@gmail.com']},
#   {'id': 192468656,
#    'type': 0,
#    'first_name': 'Natalia',
#    'last_name': 'Khamraeva',
#    'primary_email': 'natalia@auditstage.com',
#    'emails': ['nataliakhamraeva@gmail.com', 'natalia@auditstage.com']},
#   {'id': 192358605,
#    'type': 0,
#    'first_name': 'Nick',
#    'last_name': 'Meerlaen',
#    'primary_email': 'nick.meerlaen@gmail.com',
#    'emails': ['nick.meerlaen@gmail.com']},
#   {'id': 191718684,
#    'type': 0,
#    'first_name': 'Szabolcs',
#    'last_name': 'Pápai',
#    'primary_email': 'papai.szabolcs@gmail.com',
#    'emails': ['papai.szabolcs@gmail.com']},
#   {'id': 191536359,
#    'type': 0,
#    'first_name': 'Helin',
#    'last_name': 'Geleri',
#    'primary_email': 'helingeleri@gmail.com',
#    'emails': ['helingeleri@gmail.com']},
#   {'id': 191364173,
#    'type': 0,
#    'first_name': 'Anna',
#    'last_name': 'Suchy',
#    'primary_email': 'ania.suchy@gmail.com',
#    'emails': ['ania.suchy@gmail.com']},
#   {'id': 191364172,
#    'type': 0,
#    'first_name': 'Patricia',
#    'last_name': 'De La Sierra',
#    'primary_email': 'pfalagands@gmail.com',
#    'emails': ['pfalagands@gmail.com']},
#   {'id': 190955781,
#    'type': 0,
#    'first_name': 'Jonas',
#    'last_name': 'Maeyens',
#    'primary_email': 'jonas@entourage.io',
#    'emails': ['jonas@entourage.io',
#     'jonas.maeyens@gmail.com',
#     'jonas.maeyens@roborana.be',
#     'jonas@highsail.com']},
#   {'id': 190168248,
#    'type': 0,
#    'first_name': 'Marie',
#    'last_name': 'Zedler',
#    'primary_email': 'marie.zedler5@gmail.com',
#    'emails': ['marie.zedler5@gmail.com', 'ams307@cam.ac.uk']},
#   {'id': 190159965,
#    'type': 0,
#    'first_name': 'Elien',
#    'last_name': 'Vandenbroucke',
#    'primary_email': 'elien.vandenbroucke@gmail.com',
#    'emails': ['elien.vandenbroucke@gmail.com']},
#   {'id': 189944348,
#    'type': 0,
#    'first_name': 'Steven',
#    'last_name': 'Aanen',
#    'primary_email': 'ssaanen@gmail.com',
#    'emails': ['ssaanen@gmail.com']},
#   {'id': 189715766,
#    'type': 0,
#    'first_name': 'Daan',
#    'last_name': 'Arijs',
#    'primary_email': 'daanarijs@gmail.com',
#    'emails': ['daanarijs@gmail.com']},
#   {'id': 189523333,
#    'type': 0,
#    'first_name': 'Bouchra',
#    'last_name': 'Mehraj',
#    'primary_email': 'balmehraj@gmail.com',
#    'emails': ['balmehraj@gmail.com']},
#   {'id': 188929657,
#    'type': 0,
#    'first_name': 'Karel',
#    'last_name': 'Gmail',
#    'primary_email': 'karel.ribbens@gmail.com',
#    'emails': ['karel.ribbens@gmail.com']},
#   {'id': 188793778,
#    'type': 0,
#    'first_name': 'Philippe',
#    'last_name': 'Van Ophem',
#    'primary_email': 'philippe.van.ophem@gmail.com',
#    'emails': ['philippe.van.ophem@gmail.com']},
#   {'id': 188775799,
#    'type': 0,
#    'first_name': 'Maya',
#    'last_name': 'Spivak',
#    'primary_email': 'spivakmaiia@gmail.com',
#    'emails': ['spivakmaiia@gmail.com']},
#   {'id': 188775798,
#    'type': 0,
#    'first_name': 'Natalya',
#    'last_name': 'Vilyavina',
#    'primary_email': 'natasha.vilyavina@googlemail.com',
#    'emails': ['natasha.vilyavina@googlemail.com',
#     'natasha.vilyavina@gmail.com']},
#   {'id': 188720507,
#    'type': 0,
#    'first_name': 'Olivier',
#    'last_name': 'Leirman',
#    'primary_email': 'leirman.olivier@gmail.com',
#    'emails': ['leirman.olivier@gmail.com']},
#   {'id': 188584628,
#    'type': 0,
#    'first_name': 'Natalia',
#    'last_name': 'Arcila',
#    'primary_email': 'n.arcila.b@gmail.com',
#    'emails': ['n.arcila.b@gmail.com']},
#   {'id': 188472633,
#    'type': 0,
#    'first_name': 'Sandra',
#    'last_name': 'Araujo',
#    'primary_email': 'sandraaj97@gmail.com',
#    'emails': ['sandraaj97@gmail.com']},
#   {'id': 188472632,
#    'type': 0,
#    'first_name': 'Miguel',
#    'last_name': 'Ángel Fernández Lara',
#    'primary_email': 'mianferla@gmail.com',
#    'emails': ['mianferla@gmail.com']},
#   {'id': 188472631,
#    'type': 0,
#    'first_name': 'Pavel',
#    'last_name': 'Pravosud',
#    'primary_email': 'pavel.pravosud.pm@gmail.com',
#    'emails': ['pavel.pravosud.pm@gmail.com']},
#   {'id': 188344529,
#    'type': 0,
#    'first_name': 'Sabir',
#    'last_name': 'Kerkich',
#    'primary_email': 'sabirkerkich@gmail.com',
#    'emails': ['sabirkerkich@gmail.com']},
#   {'id': 188343532,
#    'type': 0,
#    'first_name': 'Koushik',
#    'last_name': 'Radhakrishnan',
#    'primary_email': 'koushikr626@gmail.com',
#    'emails': ['koushikr626@gmail.com']},
#   {'id': 188292422,
#    'type': 0,
#    'first_name': 'Louis',
#    'last_name': 'Segers',
#    'primary_email': 'segerslouis96@gmail.com',
#    'emails': ['segerslouis96@gmail.com']},
#   {'id': 188001505,
#    'type': 0,
#    'first_name': 'Wouter',
#    'last_name': 'Devos',
#    'primary_email': 'wouter.devos11@gmail.com',
#    'emails': ['wouter.devos11@gmail.com']},
#   {'id': 187675843,
#    'type': 0,
#    'first_name': 'Frederik',
#    'last_name': 'Van Hool',
#    'primary_email': 'vanhoolfred@gmail.com',
#    'emails': ['vanhoolfred@gmail.com']},
#   {'id': 187672770,
#    'type': 0,
#    'first_name': 'Evgeniya',
#    'last_name': 'Pozhilova',
#    'primary_email': 'epozhilova@gmail.com',
#    'emails': ['epozhilova@gmail.com']},
#   {'id': 187598085,
#    'type': 0,
#    'first_name': 'Matthias',
#    'last_name': 'Dubaere',
#    'primary_email': 'dubaere.matthias@gmail.com',
#    'emails': ['dubaere.matthias@gmail.com']},
#   {'id': 187598084,
#    'type': 0,
#    'first_name': 'Valentine',
#    'last_name': 'Daenens',
#    'primary_email': 'valentinedaenens@gmail.com',
#    'emails': ['valentinedaenens@gmail.com']},
#   {'id': 187598083,
#    'type': 0,
#    'first_name': 'Caroline',
#    'last_name': 'Snoeks',
#    'primary_email': 'snoeks.caroline@gmail.com',
#    'emails': ['snoeks.caroline@gmail.com']},
#   {'id': 187501191,
#    'type': 0,
#    'first_name': 'Jo',
#    'last_name': 'Degraef',
#    'primary_email': 'jo.degraef@gmail.com',
#    'emails': ['jo.degraef@gmail.com']},
#   {'id': 187500624,
#    'type': 0,
#    'first_name': 'Alexander',
#    'last_name': 'Wynaendts',
#    'primary_email': 'alexander.wynaendts@entourage.io',
#    'emails': ['alexander.wynaendts@entourage.io',
#     'alexander.wynaendts@gmail.com']},
#   {'id': 187500623,
#    'type': 0,
#    'first_name': 'Finian',
#    'last_name': 'Carey',
#    'primary_email': 'finian.carey@gmail.com',
#    'emails': ['finian.carey@gmail.com']},
#   {'id': 187500622,
#    'type': 0,
#    'first_name': 'Yannick',
#    'last_name': 'Joachim',
#    'primary_email': 'yannick.joachim89@gmail.com',
#    'emails': ['yannick.joachim89@gmail.com']},
#   {'id': 187500621,
#    'type': 0,
#    'first_name': 'Antoon',
#    'last_name': 'Piens',
#    'primary_email': 'antoon.piens@inthepocket.com',
#    'emails': ['piens.antoon@gmail.com', 'antoon.piens@inthepocket.com']},
#   {'id': 187475036,
#    'type': 0,
#    'first_name': 'Hussam',
#    'last_name': 'Ramadan',
#    'primary_email': 'hussamaburamadan@gmail.com',
#    'emails': ['hussamaburamadan@gmail.com']},
#   {'id': 187036467,
#    'type': 0,
#    'first_name': 'Nicolas',
#    'last_name': 'Spillemaeckers',
#    'primary_email': 'nicolas.spillemaeckers@gmail.com',
#    'emails': ['nicolas.spillemaeckers@gmail.com']},
#   {'id': 187030982,
#    'type': 0,
#    'first_name': 'Audrey',
#    'last_name': 'Hanard',
#    'primary_email': 'ahanard@gmail.com',
#    'emails': ['ahanard@gmail.com']},
#   {'id': 187025204,
#    'type': 0,
#    'first_name': 'Peter',
#    'last_name': 'Van Wijnaerde',
#    'primary_email': 'petervw@gmail.com',
#    'emails': ['petervw@gmail.com']},
#   {'id': 186912926,
#    'type': 0,
#    'first_name': 'Jules',
#    'last_name': 'Van Reempts',
#    'primary_email': 'jules@wintro.ai',
#    'emails': ['jules@wintro.ai', 'j.vanreempts@gmail.com']},
#   {'id': 186780208,
#    'type': 0,
#    'first_name': 'Shubham',
#    'last_name': 'Jaipuria',
#    'primary_email': 'shubham2808@gmail.com',
#    'emails': ['shubham2808@gmail.com', 'shubham@sifted.eu']},
#   {'id': 186780022,
#    'type': 0,
#    'first_name': 'Auriane',
#    'last_name': 'Legrand',
#    'primary_email': 'auriane.lgrd@gmail.com',
#    'emails': ['auriane.lgrd@gmail.com']},
#   {'id': 186344611,
#    'type': 0,
#    'first_name': 'Benjamin',
#    'last_name': 'Van Oudenhove',
#    'primary_email': 'benjaminvanoudenhove@gmail.com',
#    'emails': ['benjaminvanoudenhove@gmail.com']},
#   {'id': 186338302,
#    'type': 0,
#    'first_name': 'Finn',
#    'last_name': 'Peacocke',
#    'primary_email': 'finn.peacocke@gmail.com',
#    'emails': ['finn.peacocke@gmail.com']},
#   {'id': 186314848,
#    'type': 0,
#    'first_name': 'Nicolas',
#    'last_name': 'Debray',
#    'primary_email': 'nicdebray@gmail.com',
#    'emails': ['nicdebray@gmail.com']},
#   {'id': 186234660,
#    'type': 0,
#    'first_name': 'Ara',
#    'last_name': 'Sriskandarajah',
#    'primary_email': 'a.t.sriskandarajah@gmail.com',
#    'emails': ['a.t.sriskandarajah@gmail.com']},
#   {'id': 186132919,
#    'type': 0,
#    'first_name': 'Jeroen',
#    'last_name': 'Van Den Bossche',
#    'primary_email': 'jeroen@m1-app.com',
#    'emails': ['jeroen@m1-app.com', 'vanbosse.jeroen@gmail.com']},
#   {'id': 186116900,
#    'type': 0,
#    'first_name': 'Jeroen',
#    'last_name': 'Paepe',
#    'primary_email': 'depaepe.jeroen@gmail.com',
#    'emails': ['depaepe.jeroen@gmail.com']},
#   {'id': 185996141,
#    'type': 0,
#    'first_name': 'Dan',
#    'last_name': 'Duggan',
#    'primary_email': 'd.duggan31@gmail.com',
#    'emails': ['d.duggan31@gmail.com']},
#   {'id': 185993645,
#    'type': 0,
#    'first_name': 'Ali',
#    'last_name': 'Elsabagh',
#    'primary_email': 'alimokhtar020@gmail.com',
#    'emails': ['alimokhtar020@gmail.com']},
#   {'id': 185990607,
#    'type': 0,
#    'first_name': 'Laurane',
#    'last_name': 'Potié',
#    'primary_email': 'laurane.potie@gmail.com',
#    'emails': ['laurane.potie@gmail.com']},
#   {'id': 185989266,
#    'type': 0,
#    'first_name': 'Dries',
#    'last_name': 'Van Cauwenbergh',
#    'primary_email': 'dries.vancauwenbergh@gmail.com',
#    'emails': ['dries.vancauwenbergh@gmail.com']},
#   {'id': 185910947,
#    'type': 0,
#    'first_name': 'Nikolaas',
#    'last_name': 'Zeghers',
#    'primary_email': 'zeghers.nikolaas@gmail.com',
#    'emails': ['zeghers.nikolaas@gmail.com']},
#   {'id': 185838496,
#    'type': 0,
#    'first_name': 'Aditya',
#    'last_name': 'Jain',
#    'primary_email': 'jainaditya94@gmail.com',
#    'emails': ['jainaditya94@gmail.com']},
#   {'id': 185792589,
#    'type': 0,
#    'first_name': 'Kasper',
#    'last_name': 'Smaele',
#    'primary_email': 'kasper.desmaele@gmail.com',
#    'emails': ['kasper.desmaele@gmail.com']},
#   {'id': 185792297,
#    'type': 1,
#    'first_name': 'Tibe',
#    'last_name': 'Habils',
#    'primary_email': 'tibe.habils@entourage.io',
#    'emails': ['tibe.habils@entourage.io', 'tibe.habils@gmail.com']},
#   {'id': 185764247,
#    'type': 0,
#    'first_name': 'Benjamin',
#    'last_name': 'Vandermarliere',
#    'primary_email': 'bvandermarliere@gmail.com',
#    'emails': ['bvandermarliere@gmail.com']},
#   {'id': 185523113,
#    'type': 0,
#    'first_name': 'Gauthier',
#    'last_name': 'Rodaro',
#    'primary_email': 'gauthier.rodaro@gmail.com',
#    'emails': ['gauthier.rodaro@gmail.com']},
#   {'id': 185412297,
#    'type': 0,
#    'first_name': 'Renaud',
#    'last_name': 'Visage',
#    'primary_email': 'renaudvisage@gmail.com',
#    'emails': ['renaudvisage@gmail.com']},
#   {'id': 184796329,
#    'type': 0,
#    'first_name': 'Zhong',
#    'last_name': 'Xu',
#    'primary_email': 'zhongyuanxu@gmail.com',
#    'emails': ['zhongyuanxu@gmail.com']},
#   {'id': 184491354,
#    'type': 0,
#    'first_name': 'Willem',
#    'last_name': 'Dumon',
#    'primary_email': 'willem.dumon@gmail.com',
#    'emails': ['willem.dumon@gmail.com']},
#   {'id': 184249951,
#    'type': 0,
#    'first_name': 'Louis',
#    'last_name': 'Debaere',
#    'primary_email': 'debaere.louis@gmail.com',
#    'emails': ['debaere.louis@gmail.com']},
#   {'id': 182492001,
#    'type': 0,
#    'first_name': 'Anthony',
#    'last_name': 'Hoebeeck',
#    'primary_email': 'anthonyhoebeeck@gmail.com',
#    'emails': ['anthonyhoebeeck@gmail.com']},
#   {'id': 182086140,
#    'type': 0,
#    'first_name': 'Thomas',
#    'last_name': 'Sweertvaegher',
#    'primary_email': 'switnphoto@gmail.com',
#    'emails': ['switnphoto@gmail.com']},
#   {'id': 181818938,
#    'type': 0,
#    'first_name': 'Dieter',
#    'last_name': 'Dejonckheere',
#    'primary_email': 'dejonckheere.dieter@gmail.com',
#    'emails': ['dejonckheere.dieter@gmail.com']},
#   {'id': 181816540,
#    'type': 0,
#    'first_name': 'Jorn',
#    'last_name': 'Van Loock',
#    'primary_email': 'vanloockjorn@gmail.com',
#    'emails': ['vanloockjorn@gmail.com']},
#   {'id': 181699583,
#    'type': 0,
#    'first_name': 'Michele',
#    'last_name': 'Noten',
#    'primary_email': 'notenm@gmail.com',
#    'emails': ['notenm@gmail.com']},
#   {'id': 181199934,
#    'type': 0,
#    'first_name': 'Robin',
#    'last_name': 'Geers',
#    'primary_email': 'geers.robin@gmail.com',
#    'emails': ['geers.robin@gmail.com']},
#   {'id': 181004972,
#    'type': 0,
#    'first_name': 'Maarten',
#    'last_name': 'Fish',
#    'primary_email': 'fishm.dev@gmail.com',
#    'emails': ['fishm.dev@gmail.com']},
#   {'id': 180141128,
#    'type': 0,
#    'first_name': 'Julie',
#    'last_name': 'Becampar',
#    'primary_email': 'juliezxccbecampar@gmail.com',
#    'emails': ['juliezxccbecampar@gmail.com']},
#   {'id': 180125861,
#    'type': 0,
#    'first_name': 'Kwinten',
#    'last_name': 'Smits',
#    'primary_email': 'kwinten.smits@gmail.com',
#    'emails': ['kwinten.smits@gmail.com']},
#   {'id': 179634186,
#    'type': 0,
#    'first_name': 'Jennifer',
#    'last_name': 'Sotnichenko',
#    'primary_email': 'jenyferjane@gmail.com',
#    'emails': ['jenyferjane@gmail.com']},
#   {'id': 179634185,
#    'type': 0,
#    'first_name': 'Mariia',
#    'last_name': 'Kryvoruchko',
#    'primary_email': 'kryvoruchko.m@gmail.com',
#    'emails': ['kryvoruchko.m@gmail.com']},
#   {'id': 179634184,
#    'type': 0,
#    'first_name': 'Emmelie',
#    'last_name': 'Verborgh',
#    'primary_email': 'emmelie.verborgh@gmail.com',
#    'emails': ['emmelie.verborgh@gmail.com']},
#   {'id': 179634181,
#    'type': 0,
#    'first_name': 'Lenie',
#    'last_name': 'Van Hecke',
#    'primary_email': 'lenievanhecke@gmail.com',
#    'emails': ['lenievanhecke@gmail.com']},
#   {'id': 179634175,
#    'type': 0,
#    'first_name': 'Rosalien',
#    'last_name': 'Saer',
#    'primary_email': 'rosaliendesaer@gmail.com',
#    'emails': ['rosaliendesaer@gmail.com']},
#   {'id': 179634161,
#    'type': 0,
#    'first_name': 'Angelique',
#    'last_name': 'Clercq',
#    'primary_email': 'angeliquedc92@gmail.com',
#    'emails': ['angeliquedc92@gmail.com']},
#   {'id': 179634159,
#    'type': 0,
#    'first_name': 'Tessa',
#    'last_name': 'Ickx',
#    'primary_email': 'tessa.ickx@gmail.com',
#    'emails': ['tessa.ickx@gmail.com']},
#   {'id': 179375966,
#    'type': 0,
#    'first_name': 'Andy',
#    'last_name': 'Gijbels',
#    'primary_email': 'gijbels.andy@gmail.com',
#    'emails': ['gijbels.andy@gmail.com', 'andy@syndicate.one']},
#   {'id': 179154872,
#    'type': 0,
#    'first_name': 'Tom',
#    'last_name': 'Wouters',
#    'primary_email': 'tom.wouters1972@gmail.com',
#    'emails': ['tom.wouters1972@gmail.com']},
#   {'id': 177415268,
#    'type': 0,
#    'first_name': 'Paul',
#    'last_name': 'Mertens',
#    'primary_email': 'paul.mj.mertens@gmail.com',
#    'emails': ['paul.mj.mertens@gmail.com']},
#   {'id': 177056501,
#    'type': 0,
#    'first_name': 'Sibylle',
#    'last_name': 'Greindl',
#    'primary_email': 'sibylle.greindl@gmail.com',
#    'emails': ['sibylle.greindl@gmail.com', 'sibylle@syndicate.one']},
#   {'id': 176469553,
#    'type': 0,
#    'first_name': 'Paul',
#    'last_name': 'Thiers',
#    'primary_email': 'pauljuniorthiers@gmail.com',
#    'emails': ['pauljuniorthiers@gmail.com', 'paul@maxus.capital']},
#   {'id': 176161461,
#    'type': 0,
#    'first_name': 'Frederik',
#    'last_name': 'Vandenbriele',
#    'primary_email': 'fvandenbriele@gmail.com',
#    'emails': ['fvandenbriele@gmail.com']},
#   {'id': 176160515,
#    'type': 0,
#    'first_name': 'Minwei',
#    'last_name': 'Wang',
#    'primary_email': 'minweiwang1023@gmail.com',
#    'emails': ['minweiwang1023@gmail.com']},
#   {'id': 176158602,
#    'type': 0,
#    'first_name': 'Niels',
#    'last_name': 'Buverie',
#    'primary_email': 'niels.vandenbuverie@gmail.com',
#    'emails': ['niels.vandenbuverie@gmail.com']},
#   {'id': 176020458,
#    'type': 0,
#    'first_name': 'Geoffroy',
#    'last_name': 'Cooman',
#    'primary_email': 'geoffroy.decooman@gmail.com',
#    'emails': ['geoffroy.decooman@gmail.com']},
#   {'id': 175995763,
#    'type': 0,
#    'first_name': 'William',
#    'last_name': 'Mertens',
#    'primary_email': 'william.jm.mertens@gmail.com',
#    'emails': ['william.jm.mertens@gmail.com']},
#   {'id': 175892451,
#    'type': 0,
#    'first_name': 'Nicolas',
#    'last_name': 'Biet',
#    'primary_email': 'nicolas.biet@gmail.com',
#    'emails': ['nicolas.biet@thefaktory.com', 'nicolas.biet@gmail.com']},
#   {'id': 175892449,
#    'type': 0,
#    'first_name': 'Eric',
#    'last_name': 'Archambeau',
#    'primary_email': 'earchambeau@gmail.com',
#    'emails': ['earchambeau@gmail.com']},
#   {'id': 175674211,
#    'type': 0,
#    'first_name': 'Matteo',
#    'last_name': 'Roussis',
#    'primary_email': 'matteo.roussis@gmail.com',
#    'emails': ['matteo.roussis@gmail.com']},
#   {'id': 175569338,
#    'type': 0,
#    'first_name': 'Vladimir',
#    'last_name': 'Sizikov',
#    'primary_email': 'vsizikov@gmail.com',
#    'emails': ['vsizikov@gmail.com']},
#   {'id': 175569337,
#    'type': 0,
#    'first_name': 'Tuti',
#    'last_name': 'Fornari',
#    'primary_email': 'tutifornari@gmail.com',
#    'emails': ['tutifornari@gmail.com']},
#   {'id': 175569152,
#    'type': 0,
#    'first_name': 'Pieter',
#    'last_name': 'Smet',
#    'primary_email': 'pdsmet1@gmail.com',
#    'emails': ['pdsmet1@gmail.com']},
#   {'id': 175569136,
#    'type': 0,
#    'first_name': 'Gregoire',
#    'last_name': 'Carpentier',
#    'primary_email': 'gregoire.carpentier@gmail.com',
#    'emails': ['gregoire.carpentier@gmail.com']},
#   {'id': 175569112,
#    'type': 0,
#    'first_name': 'Luca',
#    'last_name': 'Cazzanti',
#    'primary_email': 'lucacazzanti@gmail.com',
#    'emails': ['lucacazzanti@gmail.com']},
#   {'id': 175569110,
#    'type': 0,
#    'first_name': 'Karan',
#    'last_name': 'Mehra',
#    'primary_email': 'kmehra@gmail.com',
#    'emails': ['kmehra@gmail.com']},
#   {'id': 175569089,
#    'type': 0,
#    'first_name': 'Zhang',
#    'last_name': 'Bingjun',
#    'primary_email': 'eddymier@gmail.com',
#    'emails': ['eddymier@gmail.com']},
#   {'id': 175569087,
#    'type': 0,
#    'first_name': 'Claudio',
#    'last_name': 'B',
#    'primary_email': 'claudiob@gmail.com',
#    'emails': ['claudiob@gmail.com']},
#   {'id': 175569061,
#    'type': 0,
#    'first_name': 'Katrien',
#    'last_name': 'Verpoest',
#    'primary_email': 'katrienverpoest@gmail.com',
#    'emails': ['katrienverpoest@gmail.com']},
#   {'id': 175569042,
#    'type': 0,
#    'first_name': 'Douglas',
#    'last_name': 'Turnbull',
#    'primary_email': 'dougturnbull@gmail.com',
#    'emails': ['dougturnbull@gmail.com']},
#   {'id': 175569039,
#    'type': 0,
#    'first_name': 'Tom',
#    'last_name': 'Verbruggen',
#    'primary_email': 'tomverbruggen@gmail.com',
#    'emails': ['tomverbruggen@gmail.com']},
#   {'id': 175569010,
#    'type': 0,
#    'first_name': 'Gene',
#    'last_name': 'Kogan',
#    'primary_email': 'kogan.gene@gmail.com',
#    'emails': ['kogan.gene@gmail.com']},
#   {'id': 175569007,
#    'type': 0,
#    'first_name': 'Megan',
#    'last_name': 'Schindele',
#    'primary_email': 'mhschind@gmail.com',
#    'emails': ['mhschind@gmail.com']},
#   {'id': 175568999,
#    'type': 0,
#    'first_name': 'Greg',
#    'last_name': 'VantyghemNew',
#    'primary_email': 'vantyghem.greg@gmail.com',
#    'emails': ['vantyghem.greg@gmail.com']},
#   {'id': 175568979,
#    'type': 0,
#    'first_name': 'João',
#    'last_name': 'Macaíba',
#    'primary_email': 'joao.macaiba@gmail.com',
#    'emails': ['joao.macaiba@gmail.com']},
#   {'id': 175568972,
#    'type': 0,
#    'first_name': 'Thomas',
#    'last_name': 'Nolf',
#    'primary_email': 'nolfthomas@gmail.com',
#    'emails': ['nolfthomas@gmail.com']},
#   {'id': 175568936,
#    'type': 0,
#    'first_name': 'Frederic',
#    'last_name': 'Coene',
#    'primary_email': 'fcoene@gmail.com',
#    'emails': ['fcoene@gmail.com']},
#   {'id': 175568784,
#    'type': 0,
#    'first_name': 'Pei-Yin',
#    'last_name': 'Tsai',
#    'primary_email': 'vivian7684@gmail.com',
#    'emails': ['vivian7684@gmail.com']},
#   {'id': 175568780,
#    'type': 0,
#    'first_name': 'Vesa',
#    'last_name': 'Norilo',
#    'primary_email': 'vnorilo@gmail.com',
#    'emails': ['vnorilo@gmail.com']},
#   {'id': 175568777,
#    'type': 0,
#    'first_name': 'Graham',
#    'last_name': 'Coleman',
#    'primary_email': 'ravelite@gmail.com',
#    'emails': ['ravelite@gmail.com']},
#   {'id': 175568769,
#    'type': 0,
#    'first_name': 'Matthieu',
#    'last_name': 'Hodgkinson',
#    'primary_email': 'saintmatthieu@gmail.com',
#    'emails': ['saintmatthieu@gmail.com']},
#   {'id': 175568759,
#    'type': 0,
#    'first_name': 'Tania',
#    'last_name': 'Habib',
#    'primary_email': 'taniahabib@gmail.com',
#    'emails': ['taniahabib@gmail.com']},
#   {'id': 175568740,
#    'type': 0,
#    'first_name': 'Fabio',
#    'last_name': 'Tesser',
#    'primary_email': 'fabio.tesser@gmail.com',
#    'emails': ['fabio.tesser@gmail.com']},
#   {'id': 175568724,
#    'type': 0,
#    'first_name': 'Greg',
#    'last_name': 'Byrnes',
#    'primary_email': 'gregbyrnes@gmail.com',
#    'emails': ['gregbyrnes@gmail.com']},
#   {'id': 175568709,
#    'type': 0,
#    'first_name': 'Jean-Marc',
#    'last_name': 'Jot',
#    'primary_email': 'jean-marc.jot@dts.com',
#    'emails': ['jean-marc.jot@dts.com', 'jmmjot@gmail.com']},
#   {'id': 175568689,
#    'type': 0,
#    'first_name': 'Antonín',
#    'last_name': 'Novák',
#    'primary_email': 'ant.novak@gmail.com',
#    'emails': ['ant.novak@gmail.com']},
#   {'id': 175568670,
#    'type': 0,
#    'first_name': 'Tariq',
#    'last_name': 'Daouda',
#    'primary_email': 'tariq.daouda@gmail.com',
#    'emails': ['tariq.daouda@gmail.com']},
#   {'id': 175568669,
#    'type': 0,
#    'first_name': 'Manu',
#    'last_name': 'Baere',
#    'primary_email': 'manu.de.baere@gmail.com',
#    'emails': ['manu.de.baere@gmail.com']},
#   {'id': 175568667,
#    'type': 0,
#    'first_name': 'David',
#    'last_name': 'Bouckenhove',
#    'primary_email': 'davidbouckenhove@gmail.com',
#    'emails': ['davidbouckenhove@gmail.com']},
#   {'id': 175568652,
#    'type': 0,
#    'first_name': 'Christopher',
#    'last_name': 'Raphael',
#    'primary_email': 'chrissraphael@gmail.com',
#    'emails': ['chrissraphael@gmail.com']},
#   {'id': 175568638,
#    'type': 0,
#    'first_name': 'Bryan',
#    'last_name': 'Duggan',
#    'primary_email': 'skooter500@gmail.com',
#    'emails': ['skooter500@gmail.com']},
#   {'id': 175568633,
#    'type': 0,
#    'first_name': 'Adriano',
#    'last_name': 'Mitre',
#    'primary_email': 'adriano.mitre@gmail.com',
#    'emails': ['adriano.mitre@gmail.com']},
#   {'id': 175568625,
#    'type': 0,
#    'first_name': 'Jon',
#    'last_name': 'Van Hoff',
#    'primary_email': 'theduffbunny@gmail.com',
#    'emails': ['theduffbunny@gmail.com']},
#   {'id': 175568609,
#    'type': 0,
#    'first_name': 'Xinglin',
#    'last_name': 'Zhang',
#    'primary_email': 'xinglinzh@gmail.com',
#    'emails': ['xinglinzh@gmail.com']},
#   {'id': 175568597,
#    'type': 0,
#    'first_name': 'Ives',
#    'last_name': 'Chor',
#    'primary_email': 'iveschor+musicir@gmail.com',
#    'emails': ['iveschor+musicir@gmail.com']},
#   {'id': 175568553,
#    'type': 0,
#    'first_name': 'Gaetan',
#    'last_name': 'Agneray',
#    'primary_email': 'gaetan.agneray@gmail.com',
#    'emails': ['gaetan.agneray@gmail.com']},
#   {'id': 175568546,
#    'type': 0,
#    'first_name': 'Massoomeh',
#    'last_name': 'Niknia',
#    'primary_email': 'massoomeh.niknia@gmail.com',
#    'emails': ['massoomeh.niknia@gmail.com']},
#   {'id': 175568528,
#    'type': 0,
#    'first_name': 'Vinyl',
#    'last_name': 'Squeegee',
#    'primary_email': 'vinylsqueegee@gmail.com',
#    'emails': ['vinylsqueegee@gmail.com']},
#   {'id': 175568490,
#    'type': 0,
#    'first_name': 'John',
#    'last_name': 'Glover',
#    'primary_email': 'glover.john@gmail.com',
#    'emails': ['glover.john@gmail.com']},
#   {'id': 175568466,
#    'type': 0,
#    'first_name': 'Esteban',
#    'last_name': 'Ulke',
#    'primary_email': 'teteulke@gmail.com',
#    'emails': ['teteulke@gmail.com']},
#   {'id': 175568385,
#    'type': 0,
#    'first_name': 'Tiago',
#    'last_name': 'Tavares',
#    'primary_email': 'tiagoft@gmail.com',
#    'emails': ['tiagoft@gmail.com']},
#   {'id': 175568380,
#    'type': 0,
#    'first_name': 'Luc',
#    'last_name': 'Poppe',
#    'primary_email': 'poppe.luc@gmail.com',
#    'emails': ['poppe.luc@gmail.com']},
#   {'id': 175568369,
#    'type': 0,
#    'first_name': 'Sam',
#    'last_name': 'Redele',
#    'primary_email': 'sam.redele@gmail.com',
#    'emails': ['sam.redele@gmail.com']},
#   {'id': 175568368,
#    'type': 0,
#    'first_name': 'Micha',
#    'last_name': 'Libert',
#    'primary_email': 'micha.libert@gmail.com',
#    'emails': ['micha.libert@gmail.com']},
#   {'id': 175568365,
#    'type': 0,
#    'first_name': 'Julie',
#    'last_name': 'Lafontaine',
#    'primary_email': 'lafontainejulie@gmail.com',
#    'emails': ['lafontainejulie@gmail.com']},
#   {'id': 175568364,
#    'type': 0,
#    'first_name': 'Joris',
#    'last_name': 'Thoné',
#    'primary_email': 'joristhone@gmail.com',
#    'emails': ['joristhone@gmail.com']},
#   {'id': 175568363,
#    'type': 0,
#    'first_name': 'Jeroen',
#    'last_name': 'Struys',
#    'primary_email': 'jeroen.struys@gmail.com',
#    'emails': ['jeroen.struys@gmail.com']},
#   {'id': 175568353,
#    'type': 0,
#    'first_name': 'Ellen',
#    'last_name': 'Waelbroeck',
#    'primary_email': 'wolketje@gmail.com',
#    'emails': ['wolketje@gmail.com']},
#   {'id': 175568347,
#    'type': 0,
#    'first_name': 'Merel',
#    'last_name': 'Groenenboom',
#    'primary_email': 'merel.groenenboom@gmail.com',
#    'emails': ['merel.groenenboom@gmail.com']},
#   {'id': 175568346,
#    'type': 0,
#    'first_name': 'Ewald',
#    'last_name': 'Dupan',
#    'primary_email': 'ewalddupan@gmail.com',
#    'emails': ['ewalddupan@gmail.com']},
#   {'id': 175568335,
#    'type': 0,
#    'first_name': 'Nele',
#    'last_name': 'Coudron',
#    'primary_email': 'nele.coudron@gmail.com',
#    'emails': ['nele.coudron@gmail.com']},
#   {'id': 175568328,
#    'type': 0,
#    'first_name': 'Veronique',
#    'last_name': 'Bart',
#    'primary_email': 'vee.goffin@gmail.com',
#    'emails': ['vee.goffin@gmail.com']},
#   {'id': 175568322,
#    'type': 0,
#    'first_name': 'Bob',
#    'last_name': 'MacCallum',
#    'primary_email': 'uncoolbob@gmail.com',
#    'emails': ['uncoolbob@gmail.com']},
#   {'id': 175568282,
#    'type': 0,
#    'first_name': 'Willems',
#    'last_name': 'Hanne',
#    'primary_email': 'janwillems.gistel@gmail.com',
#    'emails': ['janwillems.gistel@gmail.com']},
#   {'id': 175568190,
#    'type': 0,
#    'first_name': 'Mitch',
#    'last_name': 'Ohriner',
#    'primary_email': 'mohriner@gmail.com',
#    'emails': ['mohriner@gmail.com']},
#   {'id': 175568175,
#    'type': 0,
#    'first_name': 'Martin',
#    'last_name': 'Gasser',
#    'primary_email': 'martin.gasser@gmail.com',
#    'emails': ['martin.gasser@gmail.com']},
#   {'id': 175568165,
#    'type': 0,
#    'first_name': 'The',
#    'last_name': 'Eelhouse',
#    'primary_email': 'eelhouse@gmail.com',
#    'emails': ['eelhouse@gmail.com']},
#   {'id': 175568159,
#    'type': 0,
#    'first_name': 'Jun',
#    'last_name': 'Wang',
#    'primary_email': 'junjunmin@gmail.com',
#    'emails': ['junjunmin@gmail.com']},
#   {'id': 175568147,
#    'type': 0,
#    'first_name': 'Ming',
#    'last_name': 'Li',
#    'primary_email': 'liming.ioa@gmail.com',
#    'emails': ['liming.ioa@gmail.com']},
#   {'id': 175568132,
#    'type': 0,
#    'first_name': 'Vanderheyden',
#    'last_name': 'Johan',
#    'primary_email': 'vdheyden.baele@gmail.com',
#    'emails': ['vdheyden.baele@gmail.com']},
#   {'id': 175568118,
#    'type': 0,
#    'first_name': 'Thomas',
#    'last_name': 'Kay',
#    'primary_email': 'thomas.kay@gmail.com',
#    'emails': ['thomas.kay@gmail.com']},
#   {'id': 175568117,
#    'type': 0,
#    'first_name': 'Leonardo',
#    'last_name': 'Vegas',
#    'primary_email': 'leonardo.vegas@gmail.com',
#    'emails': ['leonardo.vegas@gmail.com']},
#   {'id': 175568116,
#    'type': 0,
#    'first_name': 'Blu',
#    'last_name': 'Domenico',
#    'primary_email': 'notblu@gmail.com',
#    'emails': ['notblu@gmail.com']},
#   {'id': 175568114,
#    'type': 0,
#    'first_name': 'Robert',
#    'last_name': 'Howshall',
#    'primary_email': 'robert.howshall@gmail.com',
#    'emails': ['robert.howshall@gmail.com']},
#   {'id': 175568112,
#    'type': 0,
#    'first_name': 'Hostal',
#    'last_name': 'Lobos',
#    'primary_email': 'hostalpuntadelobos@gmail.com',
#    'emails': ['hostalpuntadelobos@gmail.com']},
#   {'id': 175568109,
#    'type': 0,
#    'first_name': 'Tomas',
#    'last_name': 'Kadgien',
#    'primary_email': 'oberstsurfboards@gmail.com',
#    'emails': ['oberstsurfboards@gmail.com']},
#   {'id': 175568104,
#    'type': 0,
#    'first_name': 'Agusddt',
#    'last_name': 'Tuesta',
#    'primary_email': 'agusddt@gmail.com',
#    'emails': ['agusddt@gmail.com']},
#   {'id': 175568095,
#    'type': 0,
#    'first_name': 'Hostal',
#    'last_name': 'Verde',
#    'primary_email': 'hostalcasaverde@gmail.com',
#    'emails': ['hostalcasaverde@gmail.com']},
#   {'id': 175568091,
#    'type': 0,
#    'first_name': 'Fabio',
#    'last_name': 'Baccaglioni',
#    'primary_email': 'fabiomb@gmail.com',
#    'emails': ['fabiomb@gmail.com']},
#   {'id': 175568090,
#    'type': 0,
#    'first_name': 'Emiliano',
#    'last_name': 'Penovi',
#    'primary_email': 'emilianopenovi@gmail.com',
#    'emails': ['emilianopenovi@gmail.com']},
#   {'id': 175568089,
#    'type': 0,
#    'first_name': 'Eduardo',
#    'last_name': 'Blasina',
#    'primary_email': 'eduardo.blasina@gmail.com',
#    'emails': ['eduardo.blasina@gmail.com']},
#   {'id': 175568076,
#    'type': 0,
#    'first_name': 'Ben',
#    'last_name': 'Sheppard',
#    'primary_email': 'sheppard.benedict@gmail.com',
#    'emails': ['sheppard.benedict@gmail.com']},
#   {'id': 175568074,
#    'type': 0,
#    'first_name': 'Douglas',
#    'last_name': 'Eck',
#    'primary_email': 'douglas.eck@gmail.com',
#    'emails': ['douglas.eck@gmail.com']},
#   {'id': 175568067,
#    'type': 0,
#    'first_name': 'Robert',
#    'last_name': 'Ferguson',
#    'primary_email': 'robert.ferguson@gmail.com',
#    'emails': ['robert.ferguson@gmail.com']},
#   {'id': 175568066,
#    'type': 0,
#    'first_name': 'Hyunwoo',
#    'last_name': 'Kim',
#    'primary_email': 'kimbellw@gmail.com',
#    'emails': ['kimbellw@gmail.com']},
#   {'id': 175568063,
#    'type': 0,
#    'first_name': 'Jean',
#    'last_name': 'Debaecker',
#    'primary_email': 'jean.debaecker@gmail.com',
#    'emails': ['jean.debaecker@gmail.com']},
#   {'id': 175568062,
#    'type': 0,
#    'first_name': 'Martín',
#    'last_name': 'Rocamora',
#    'primary_email': 'martinrocamora@gmail.com',
#    'emails': ['martinrocamora@gmail.com']},
#   {'id': 175568055,
#    'type': 0,
#    'first_name': 'Jeremy',
#    'last_name': 'Sawruk',
#    'primary_email': 'jeremy.sawruk@gmail.com',
#    'emails': ['jeremy.sawruk@gmail.com']},
#   {'id': 175568049,
#    'type': 0,
#    'first_name': 'Ader',
#    'last_name': 'Lee',
#    'primary_email': 'aderleee@gmail.com',
#    'emails': ['aderleee@gmail.com']},
#   {'id': 175568039,
#    'type': 0,
#    'first_name': 'Luis',
#    'last_name': 'Martins',
#    'primary_email': 'lgustavomartins@gmail.com',
#    'emails': ['lgustavomartins@gmail.com']},
#   {'id': 175567922,
#    'type': 0,
#    'first_name': 'Georgina',
#    'last_name': 'Tryfou',
#    'primary_email': 'tryfou@gmail.com',
#    'emails': ['tryfou@gmail.com']},
#   {'id': 175567780,
#    'type': 0,
#    'first_name': 'William',
#    'last_name': 'Noel',
#    'primary_email': 'wilbus@gmail.com',
#    'emails': ['wilbus@gmail.com']},
#   {'id': 175567775,
#    'type': 0,
#    'first_name': 'Virginia',
#    'last_name': 'Ballarin',
# ...
#    'last_name': 'Chiodetti',
#    'primary_email': 'luca85chd@gmail.com',
#    'emails': ['luca85chd@gmail.com']},
#   {'id': 175566779,
#    'type': 0,
#    'first_name': 'Marilyn',
#    'last_name': 'Niven',
#    'primary_email': 'marilynniv@gmail.com',
#    'emails': ['marilynniv@gmail.com']},
#   {'id': 175566774,
#    'type': 0,
#    'first_name': 'Margaret',
#    'last_name': 'Lam',
#    'primary_email': 'margaret.lam@gmail.com',
#    'emails': ['margaret.lam@gmail.com']},
#   {'id': 175566759,
#    'type': 0,
#    'first_name': 'Yajie',
#    'last_name': 'Hu',
#    'primary_email': 'huyajiecn@gmail.com',
#    'emails': ['huyajiecn@gmail.com']},
#   {'id': 175566753,
#    'type': 0,
#    'first_name': 'Bo',
#    'last_name': 'Xie',
#    'primary_email': 'zixu1986@gmail.com',
#    'emails': ['zixu1986@gmail.com']},
#   {'id': 175566735,
#    'type': 0,
#    'first_name': 'Matías',
#    'last_name': 'Lennie',
#    'primary_email': 'matias.lennie@gmail.com',
#    'emails': ['matias.lennie@gmail.com']},
#   {'id': 175566694,
#    'type': 0,
#    'first_name': 'Marius',
#    'last_name': 'Miron',
#    'primary_email': 'miron.marius@gmail.com',
#    'emails': ['miron.marius@gmail.com']},
#   {'id': 175566691,
#    'type': 0,
#    'first_name': 'Oscar',
#    'last_name': 'Celma',
#    'primary_email': 'ocelma@gmail.com',
#    'emails': ['ocelma@gmail.com', 'oscar.celma@upf.edu']},
#   {'id': 175566625,
#    'type': 0,
#    'first_name': 'Wenne',
#    'last_name': 'Dobbels',
#    'primary_email': 'wenne1d@gmail.com',
#    'emails': ['wenne1d@gmail.com']},
#   {'id': 175566618,
#    'type': 0,
#    'first_name': 'Pj',
#    'last_name': 'Beelaerts',
#    'primary_email': 'pieterjan.beelaerts@gmail.com',
#    'emails': ['pieterjan.beelaerts@gmail.com']},
#   {'id': 175566602,
#    'type': 0,
#    'first_name': 'Chinghua',
#    'last_name': 'Chuan',
#    'primary_email': 'chinghua@gmail.com',
#    'emails': ['chinghua@gmail.com']},
#   {'id': 175566587,
#    'type': 0,
#    'first_name': 'Trevor',
#    'last_name': 'Knight',
#    'primary_email': 'trevorknight@gmail.com',
#    'emails': ['trevorknight@gmail.com']},
#   {'id': 175566581,
#    'type': 0,
#    'first_name': 'Tom',
#    'last_name': 'Ghesquiere',
#    'primary_email': 'tomghe@gmail.com',
#    'emails': ['tomghe@gmail.com']},
#   {'id': 175566577,
#    'type': 0,
#    'first_name': 'Eric',
#    'last_name': 'Humphrey',
#    'primary_email': 'humphrey.eric@gmail.com',
#    'emails': ['humphrey.eric@gmail.com']},
#   {'id': 175566575,
#    'type': 0,
#    'first_name': 'Joakim',
#    'last_name': 'Andén',
#    'primary_email': 'joakim.anden@gmail.com',
#    'emails': ['joakim.anden@gmail.com']},
#   {'id': 175566570,
#    'type': 0,
#    'first_name': 'Vivek',
#    'last_name': 'Kumar',
#    'primary_email': 'vivek.steve@gmail.com',
#    'emails': ['vivek.steve@gmail.com']},
#   {'id': 175566565,
#    'type': 0,
#    'first_name': 'Amelie',
#    'last_name': 'Anglade',
#    'primary_email': 'amelie.anglade@gmail.com',
#    'emails': ['amelie.anglade@gmail.com']},
#   {'id': 175566560,
#    'type': 0,
#    'first_name': 'Andrew',
#    'last_name': 'Hankinson',
#    'primary_email': 'andrew.hankinson@gmail.com',
#    'emails': ['andrew.hankinson@gmail.com']},
#   {'id': 175566555,
#    'type': 0,
#    'first_name': 'Jean-Julien',
#    'last_name': 'Aucouturier',
#    'primary_email': 'aucouturier@gmail.com',
#    'emails': ['aucouturier@gmail.com']},
#   {'id': 175566548,
#    'type': 0,
#    'first_name': 'Mark',
#    'last_name': 'Anderson',
#    'primary_email': 'markmakingmusic@gmail.com',
#    'emails': ['markmakingmusic@gmail.com']},
#   {'id': 175566545,
#    'type': 0,
#    'first_name': 'Emmanuel',
#    'last_name': 'Deruty',
#    'primary_email': 'emmanuel.deruty@gmail.com',
#    'emails': ['emmanuel.deruty@gmail.com']},
#   {'id': 175566541,
#    'type': 0,
#    'first_name': 'Karin',
#    'last_name': 'Dressler',
#    'primary_email': 'kadressler@gmail.com',
#    'emails': ['kadressler@gmail.com']},
#   {'id': 175566532,
#    'type': 0,
#    'first_name': 'Sageev',
#    'last_name': 'Oore',
#    'primary_email': 'osageev@gmail.com',
#    'emails': ['osageev@gmail.com']},
#   {'id': 175566527,
#    'type': 0,
#    'first_name': 'Srikanth',
#    'last_name': 'Cherla',
#    'primary_email': 'cherla.srikanth@gmail.com',
#    'emails': ['cherla.srikanth@gmail.com']},
#   {'id': 175566522,
#    'type': 0,
#    'first_name': 'Joachim',
#    'last_name': 'Thiemann',
#    'primary_email': 'joachim.thiemann@gmail.com',
#    'emails': ['joachim.thiemann@gmail.com']},
#   {'id': 175566510,
#    'type': 0,
#    'first_name': 'Dag',
#    'last_name': 'Henriksen',
#    'primary_email': 'dagt.henriksen@gmail.com',
#    'emails': ['dagt.henriksen@gmail.com']},
#   {'id': 175566495,
#    'type': 0,
#    'first_name': 'Alessio',
#    'last_name': 'Degani',
#    'primary_email': 'alessio.degani@gmail.com',
#    'emails': ['alessio.degani@gmail.com']},
#   {'id': 175566485,
#    'type': 0,
#    'first_name': 'Keunwoo',
#    'last_name': 'Choi',
#    'primary_email': 'gnuchoi@gmail.com',
#    'emails': ['gnuchoi@gmail.com']},
#   {'id': 175566479,
#    'type': 0,
#    'first_name': 'Matthias',
#    'last_name': 'Röder',
#    'primary_email': 'mr1977@gmail.com',
#    'emails': ['mr1977@gmail.com']},
#   {'id': 175566460,
#    'type': 0,
#    'first_name': 'Agnes',
#    'last_name': 'Haesaert',
#    'primary_email': 'agnes.haesaert@gmail.com',
#    'emails': ['agnes.haesaert@gmail.com']},
#   {'id': 175566450,
#    'type': 0,
#    'first_name': 'Andre',
#    'last_name': 'Pires',
#    'primary_email': 'andrespires@gmail.com',
#    'emails': ['andrespires@gmail.com']},
#   {'id': 175566447,
#    'type': 0,
#    'first_name': 'Luke',
#    'last_name': 'Barrington',
#    'primary_email': 'lukeinusa@gmail.com',
#    'emails': ['lukeinusa@gmail.com']},
#   {'id': 175566439,
#    'type': 0,
#    'first_name': 'Cyril',
#    'last_name': 'Joder',
#    'primary_email': 'cyril.joder@gmail.com',
#    'emails': ['cyril.joder@gmail.com']},
#   {'id': 175566437,
#    'type': 0,
#    'first_name': 'Tina',
#    'last_name': 'Vandesteene',
#    'primary_email': 'tinavandesteene@gmail.com',
#    'emails': ['tinavandesteene@gmail.com']},
#   {'id': 175566433,
#    'type': 0,
#    'first_name': 'Mik',
#    'last_name': 'Torfs',
#    'primary_email': 'mik.torfs@gmail.com',
#    'emails': ['mik.torfs@gmail.com']},
#   {'id': 175566432,
#    'type': 0,
#    'first_name': 'Martin',
#    'last_name': 'Nica',
#    'primary_email': 'martin.no1@gmail.com',
#    'emails': ['martin.no1@gmail.com']},
#   {'id': 175566431,
#    'type': 0,
#    'first_name': 'Lies',
#    'last_name': 'Drieghe',
#    'primary_email': 'shangai.li@gmail.com',
#    'emails': ['shangai.li@gmail.com']},
#   {'id': 175566430,
#    'type': 0,
#    'first_name': 'Katalien',
#    'last_name': 'Spooren',
#    'primary_email': 'katalien.spooren@gmail.com',
#    'emails': ['katalien.spooren@gmail.com']},
#   {'id': 175566429,
#    'type': 0,
#    'first_name': 'Joachim',
#    'last_name': 'Geeraert',
#    'primary_email': 'geeraert@gmail.com',
#    'emails': ['geeraert@gmail.com']},
#   {'id': 175566426,
#    'type': 0,
#    'first_name': 'Hans',
#    'last_name': 'Van Boven',
#    'primary_email': 'hans.vanboven@gmail.com',
#    'emails': ['hans.vanboven@gmail.com']},
#   {'id': 175566424,
#    'type': 0,
#    'first_name': 'Arvid',
#    'last_name': 'Vanparys',
#    'primary_email': 'arvidvanparys@gmail.com',
#    'emails': ['arvidvanparys@gmail.com']},
#   {'id': 175566423,
#    'type': 0,
#    'first_name': 'Annelies',
#    'last_name': 'Van den Berghe',
#    'primary_email': 'lizavdb791@gmail.com',
#    'emails': ['lizavdb791@gmail.com']},
#   {'id': 175566418,
#    'type': 0,
#    'first_name': 'Olivier',
#    'last_name': 'Lartillot',
#    'primary_email': 'olartillot@gmail.com',
#    'emails': ['olartillot@gmail.com', 'olivier.lartillot@campus.jyu.fi']},
#   {'id': 175566417,
#    'type': 0,
#    'first_name': 'Qi',
#    'last_name': 'Tian',
#    'primary_email': 'wywqtian@gmail.com',
#    'emails': ['wywqtian@gmail.com']},
#   {'id': 175566412,
#    'type': 0,
#    'first_name': 'Matti',
#    'last_name': 'Ryynänen',
#    'primary_email': 'matti.p.ryynanen@gmail.com',
#    'emails': ['matti.p.ryynanen@gmail.com']},
#   {'id': 175566398,
#    'type': 0,
#    'first_name': 'Yi-Hsuan',
#    'last_name': 'Yang',
#    'primary_email': 'affige@gmail.com',
#    'emails': ['affige@gmail.com']},
#   {'id': 175566384,
#    'type': 0,
#    'first_name': 'Steven',
#    'last_name': 'Van Ryckeghem',
#    'primary_email': 'steven.vanryckeghem@gmail.com',
#    'emails': ['steven.vanryckeghem@gmail.com']},
#   {'id': 175566379,
#    'type': 0,
#    'first_name': 'Sofie',
#    'last_name': 'Deceuninck',
#    'primary_email': 'sofie.deceuninck@gmail.com',
#    'emails': ['sofie.deceuninck@gmail.com']},
#   {'id': 175566378,
#    'type': 0,
#    'first_name': 'Stijn',
#    'last_name': 'Depoorter',
#    'primary_email': 'stijndepoorter@gmail.com',
#    'emails': ['stijndepoorter@gmail.com']},
#   {'id': 175566375,
#    'type': 0,
#    'first_name': 'Nele',
#    'last_name': 'Pyfferoen',
#    'primary_email': 'nelidita27@gmail.com',
#    'emails': ['nelidita27@gmail.com']},
#   {'id': 175566373,
#    'type': 0,
#    'first_name': 'Nicolas',
#    'last_name': 'Vanhoucke',
#    'primary_email': 'nicolasvanhoucke@gmail.com',
#    'emails': ['nicolasvanhoucke@gmail.com']},
#   {'id': 175566369,
#    'type': 0,
#    'first_name': 'Leen',
#    'last_name': 'Verdonck',
#    'primary_email': 'helena.verdonck@gmail.com',
#    'emails': ['helena.verdonck@gmail.com']},
#   {'id': 175566367,
#    'type': 0,
#    'first_name': 'Kelly',
#    'last_name': 'Steenlandt',
#    'primary_email': 'kelly.steenlandt@gmail.com',
#    'emails': ['kelly.steenlandt@gmail.com']},
#   {'id': 175566360,
#    'type': 0,
#    'first_name': 'Frederik',
#    'last_name': 'Tampere',
#    'primary_email': 'frederiktampere@gmail.com',
#    'emails': ['frederiktampere@gmail.com']},
#   {'id': 175566355,
#    'type': 0,
#    'first_name': 'Daisy',
#    'last_name': 'Turck',
#    'primary_email': 'daisydeturck@gmail.com',
#    'emails': ['daisydeturck@gmail.com']},
#   {'id': 175566352,
#    'type': 0,
#    'first_name': 'Candice',
#    'last_name': 'Reijers',
#    'primary_email': 'candicereijers@gmail.com',
#    'emails': ['candicereijers@gmail.com']},
#   {'id': 175566347,
#    'type': 0,
#    'first_name': 'Mark',
#    'last_name': 'Cartwright',
#    'primary_email': 'mcartwright@gmail.com',
#    'emails': ['mcartwright@gmail.com']},
#   {'id': 175566339,
#    'type': 0,
#    'first_name': 'Gilles',
#    'last_name': 'Degottex',
#    'primary_email': 'gilles.degottex@gmail.com',
#    'emails': ['gilles.degottex@gmail.com']},
#   {'id': 175566335,
#    'type': 0,
#    'first_name': 'Steve',
#    'last_name': 'Tjoa',
#    'primary_email': 'stjoa@izotope.com',
#    'emails': ['stjoa@izotope.com', 'kiemyang@gmail.com']},
#   {'id': 175566331,
#    'type': 0,
#    'first_name': 'Xinyuan',
#    'last_name': 'Lai',
#    'primary_email': 'laixinyuan@gmail.com',
#    'emails': ['laixinyuan@gmail.com']},
#   {'id': 175566318,
#    'type': 0,
#    'first_name': 'Tom',
#    'last_name': 'Collins',
#    'primary_email': 'tomthecollins@gmail.com',
#    'emails': ['tomthecollins@gmail.com']},
#   {'id': 175566311,
#    'type': 0,
#    'first_name': 'Danilo',
#    'last_name': 'Bellini',
#    'primary_email': 'danilo.bellini@gmail.com',
#    'emails': ['danilo.bellini@gmail.com']},
#   {'id': 175566304,
#    'type': 0,
#    'first_name': 'Eric',
#    'last_name': 'Nichols',
#    'primary_email': 'epnichols@gmail.com',
#    'emails': ['epnichols@gmail.com']},
#   {'id': 175566303,
#    'type': 0,
#    'first_name': 'Gustavo',
#    'last_name': 'Reis',
#    'primary_email': 'gustavo.miguel.reis@gmail.com',
#    'emails': ['gustavo.miguel.reis@gmail.com']},
#   {'id': 175566302,
#    'type': 0,
#    'first_name': 'Rafael',
#    'last_name': 'Ferrer',
#    'primary_email': 'raferrerfl@gmail.com',
#    'emails': ['raferrerfl@gmail.com']},
#   {'id': 175566298,
#    'type': 0,
#    'first_name': 'Manuel',
#    'last_name': 'Díaz',
#    'primary_email': 'manueltizondiaz@gmail.com',
#    'emails': ['manueltizondiaz@gmail.com']},
#   {'id': 175566290,
#    'type': 0,
#    'first_name': 'Jinyu',
#    'last_name': 'Han',
#    'primary_email': 'jinyuhan@gmail.com',
#    'emails': ['jinyuhan@gmail.com',
#     'jhan@gracenote.com',
#     'jinyuhan2008@gmail.com']},
#   {'id': 175566285,
#    'type': 0,
#    'first_name': 'Marko',
#    'last_name': 'Tkalcic',
#    'primary_email': 'marko.tkalcic@gmail.com',
#    'emails': ['marko.tkalcic@gmail.com', 'marko.tkalcic@fe.uni-lj.si']},
#   {'id': 175566282,
#    'type': 0,
#    'first_name': 'Panagiotis',
#    'last_name': 'Tigas',
#    'primary_email': 'ptigas@gmail.com',
#    'emails': ['ptigas@gmail.com']},
#   {'id': 175566261,
#    'type': 0,
#    'first_name': 'Patricio',
#    'last_name': 'López-Serrano',
#    'primary_email': 'p.lopezserrano.e@gmail.com',
#    'emails': ['p.lopezserrano.e@gmail.com']},
#   {'id': 175566260,
#    'type': 0,
#    'first_name': 'Mark',
#    'last_name': 'Levy',
#    'primary_email': 'gamboviol@gmail.com',
#    'emails': ['gamboviol@gmail.com']},
#   {'id': 175566259,
#    'type': 0,
#    'first_name': 'Caro',
#    'last_name': 'Budde',
#    'primary_email': 'carobudde@gmail.com',
#    'emails': ['carobudde@gmail.com']},
#   {'id': 175565928,
#    'type': 0,
#    'first_name': 'Yu-Ching',
#    'last_name': 'Lin',
#    'primary_email': 'vagante@gmail.com',
#    'emails': ['vagante@gmail.com']},
#   {'id': 175565887,
#    'type': 0,
#    'first_name': 'Braja',
#    'last_name': 'Patra',
#    'primary_email': 'brajagopal.cse@gmail.com',
#    'emails': ['brajagopal.cse@gmail.com']},
#   {'id': 175565885,
#    'type': 0,
#    'first_name': 'Steve',
#    'last_name': 'Hargreaves',
#    'primary_email': 'steve.harg@gmail.com',
#    'emails': ['steve.harg@gmail.com']},
#   {'id': 175565881,
#    'type': 0,
#    'first_name': 'Jonathan',
#    'last_name': 'Marmor',
#    'primary_email': 'jmarmor@gmail.com',
#    'emails': ['jmarmor@gmail.com']},
#   {'id': 175565867,
#    'type': 0,
#    'first_name': 'Peter',
#    'last_name': 'Decoster',
#    'primary_email': 'decoster.peter@gmail.com',
#    'emails': ['decoster.peter@gmail.com']},
#   {'id': 175565852,
#    'type': 0,
#    'first_name': 'Yonatan',
#    'last_name': 'Vaizman',
#    'primary_email': 'yonatanv@gmail.com',
#    'emails': ['yonatanv@gmail.com']},
#   {'id': 175565845,
#    'type': 0,
#    'first_name': 'Sam',
#    'last_name': 'Ferguson',
#    'primary_email': 'samferguson.ml@gmail.com',
#    'emails': ['samferguson.ml@gmail.com']},
#   {'id': 175565842,
#    'type': 0,
#    'first_name': 'Dariush',
#    'last_name': 'Alimohammadi',
#    'primary_email': 'webliographer@gmail.com',
#    'emails': ['webliographer@gmail.com']},
#   {'id': 175565838,
#    'type': 0,
#    'first_name': 'Nikolay',
#    'last_name': 'Glazyrin',
#    'primary_email': 'nglazyrin@gmail.com',
#    'emails': ['nglazyrin@gmail.com']},
#   {'id': 175565836,
#    'type': 0,
#    'first_name': 'Bob',
#    'last_name': 'Sturm',
#    'primary_email': 'boblsturm@gmail.com',
#    'emails': ['boblsturm@gmail.com']},
#   {'id': 175565834,
#    'type': 0,
#    'first_name': 'Sajjad',
#    'last_name': 'Abdoli',
#    'primary_email': 'sa_mc110@yahoo.com',
#    'emails': ['sa_mc110@yahoo.com', 'saj.abdoli@gmail.com']},
#   {'id': 175565833,
#    'type': 0,
#    'first_name': 'Rafael',
#    'last_name': 'Ramirez',
#    'primary_email': 'rafamele@gmail.com',
#    'emails': ['rafamele@gmail.com']},
#   {'id': 175565812,
#    'type': 0,
#    'first_name': 'Elias',
#    'last_name': 'Pampalk',
#    'primary_email': 'elias.pampalk@gmail.com',
#    'emails': ['elias.pampalk@gmail.com']},
#   {'id': 175565808,
#    'type': 0,
#    'first_name': 'Sean',
#    'last_name': 'German',
#    'primary_email': 'seangerman@gmail.com',
#    'emails': ['seangerman@gmail.com']},
#   {'id': 175565794,
#    'type': 0,
#    'first_name': 'Gina',
#    'last_name': 'Collecchia',
#    'primary_email': 'ginacollecchia@gmail.com',
#    'emails': ['ginacollecchia@gmail.com']},
#   {'id': 175565792,
#    'type': 0,
#    'first_name': 'Diogo',
#    'last_name': 'Cocharro',
#    'primary_email': 'dcocharro@gmail.com',
#    'emails': ['dcocharro@gmail.com']},
#   {'id': 175565787,
#    'type': 0,
#    'first_name': 'Gert',
#    'last_name': 'Lanckriet',
#    'primary_email': 'gertito@gmail.com',
#    'emails': ['gertito@gmail.com', 'gert@ece.ucsd.edu']},
#   {'id': 175565781,
#    'type': 0,
#    'first_name': 'Yves',
#    'last_name': 'Raimond',
#    'primary_email': 'yves.raimond@bbc.co.uk',
#    'emails': ['yves.raimond@bbc.co.uk', 'yves.raimond@gmail.com']}],
#  'next_page_token': 'eyJwYXJhbXMiOnsidGVybSI6ImdtYWlsIn0sInBhZ2Vfc2l6ZSI6NTAwLCJvZmZzZXQiOjUwMH0'}

# %%
def create_organization(name, website_url):
    prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
    for prefix in prefixes:
        if website_url.startswith(prefix):
            website_url = website_url[len(prefix):]
            break

    url = "https://api.affinity.co/organizations"
    data = {'name': name, 'domain': website_url}

    response = requests.post(url, auth=HTTPBasicAuth('', api_key), json=data)
    organization = response.json()
    organization_id = organization.get('id')
    return organization_id

# %%
create_organization("NewTestCompany", "NewTestCompany.com")
# Out:
# {'id': 299266107,
#  'name': 'NewTestCompany',
#  'domain': 'newtestcompany.com',
#  'domains': ['newtestcompany.com'],
#  'crunchbase_uuid': None,
#  'global': False,
#  'person_ids': []}

# %%
website_url = "https://neo-mobility.be"

prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
for prefix in prefixes:
    if website_url.startswith(prefix):
        website_url = website_url[len(prefix):]
        break

# %%
url = f"https://api.affinity.co/field-values?organization_id={organization_id}"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
print(response.json())
organizations = response.json().get("organizations", [])
for organization in organizations:
    if organization.get('domain') == website_url:
        organisation_id = organization.get('id')
# Out:
# [{'id': 13567512466, 'field_id': 4768744, 'list_entry_id': 172098674, 'entity_type': 1, 'value_type': 7, 'entity_id': 299266107, 'created_at': '2024-10-22T09:04:09.250-07:00', 'updated_at': None, 'value': {'id': 16696433, 'text': 'New', 'rank': 1, 'color': 1}}]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 4
#       2 response = requests.get(url, auth=HTTPBasicAuth('', api_key))
#       3 print(response.json())
# ----> 4 organizations = response.json().get("organizations", [])
#       5 for organization in organizations:
#       6     if organization.get('domain') == website_url:
#
# AttributeError: 'list' object has no attribute 'get'

# %%
organisation_id = 1687144

# %%
def update_affinity_field(company_info):
    # Clean up the website URL by removing prefixes
    website_url = company_info.get("Website URL")
    prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
    for prefix in prefixes:
        if website_url.startswith(prefix):
            website_url = website_url[len(prefix):]
            break

    # Find the organization by domain
    url = f"https://api.affinity.co/organizations?term={website_url}"
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    organizations = response.json().get("organizations", [])
    organization_id = None
    for organization in organizations:
        if organization.get('domain') == website_url:
            organization_id = organization.get('id')
            break

    # Get the list fields
    url = f'https://api.affinity.co/lists/{list_id}'
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    list_fields = response.json().get("fields", [])

    url = f"https://api.affinity.co/lists/{list_id}/list-entries"
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    list_entries = response.json()
    list_entry_id = None
    for list_entry in list_entries:
        entity = list_entry.get('entity', {})
        entity_domain = entity.get('domain', '')
        if entity_domain == website_url:
            list_entry_id = list_entry.get('id')
            break

    # For each field in the list, update it with the corresponding value from company_info
    for list_field in list_fields:
        field_name = list_field.get("name")
        field_id = list_field.get("id")
        if field_name in company_info:
            new_value = company_info[field_name]
            dropdown_options = list_field.get('dropdown_options', [])
            if dropdown_options:
                dropdown_option_id = None
                for option in dropdown_options:
                    if option.get('text') == new_value:
                        new_value = option.get('id')
                        break

            # Get existing field values for the organization
            url = f"https://api.affinity.co/field-values?organization_id={organization_id}"
            response = requests.get(url, auth=HTTPBasicAuth('', api_key))
            organization_fields = response.json()
            field_value_id = None
            for field_value in organization_fields:
                if field_value.get("field_id") == field_id:
                    field_value_id = field_value.get("id")
                    break
            if field_value_id:
                # Update existing field value
                url = f"https://api.affinity.co/field-values/{field_value_id}"
                data = {'value': new_value}
                response = requests.put(url, auth=HTTPBasicAuth('', api_key), json=data)
            else:
                url = "https://api.affinity.co/field-values"
                data = {'field_id': field_id, 'value': new_value, 'entity_id': organization_id, 'list_entry_id': list_entry_id}
                response = requests.post(url, auth=HTTPBasicAuth('', api_key), json=data)

    return

# %%
company_info = {"Website URL": "psg.fr", "Test": "Ok boy", 'Status': "To be contacted"}
update_affinity_field(company_info)
# Out:
# 16696435 4768744
# Ok boy 4769046

# %%
import requests
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
api_key = os.getenv("AFFINITY_API_KEY")

list_id = 271745

def create_organization(name, website_url):
    # Remove all prefixes from website_url
    prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
    for prefix in prefixes:
        if website_url.startswith(prefix):
            website_url = website_url[len(prefix):]
            break

    url = "https://api.affinity.co/organizations"
    data = {
        'name': name,
        'domain': website_url
    }

    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    organization = response.json()
    organization_id = organization.get('id')
    return organization_id

def create_list_entry(organization_id):
    url = f"https://api.affinity.co/lists/{list_id}/list-entries"
    headers = {
        'Content-Type': 'application/json',
        'X-API-Key': api_key
    }
    data = {
        'entity_id': organization_id
    }

    response = requests.post(url, headers=headers, json=data)
    if response.status_code == 201:
        return
    else:
        print(f"Error adding organization to list: {response.text}")
        return

def update_status_field(organization_id):
    # Get the field ID for the "Status" field
    field_id = get_field_id("Status")
    if not field_id:
        print("Status field not found.")
        return

    url = "https://api.affinity.co/field-values"
    headers = {
        'Content-Type': 'application/json',
        'X-API-Key': api_key
    }
    data = {
        'field_id': field_id,
        'organization_id': organization_id,
        'value': 'To Screen'
    }

    response = requests.post(url, headers=headers, json=data)
    if response.status_code in [200, 201]:
        return
    else:
        print(f"Error updating status field: {response.text}")
        return

def get_field_id(field_name):
    url = "https://api.affinity.co/fields"
    headers = {
        'X-API-Key': api_key
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        fields = response.json()
        for field in fields:
            if field['name'] == field_name:
                return field['id']
    else:
        print(f"Error fetching fields: {response.text}")
    return None

def add_company_to_affinity(company_info):
    name = company_info.get("Name")
    website_url = company_info.get("Website URL")

    organization_id = create_organization(name, website_url)
    if organization_id:
        create_list_entry(organization_id)
        update_status_field(organization_id)
    return

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("AFFINITY_API_KEY") 

list_id = 271745

# %%
def create_organization(name, website_url):

    remove all https://, http://, http://www., https://www., www. from website_url
    
curl -X POST "https://api.affinity.co/organizations" \
   -u :$APIKEY \
   -H "Content-Type: application/json" \
   -d '{"name": name, "domain": website_url
    
    return organization_id

# %%
def create_list_entry(organization_id):

    curl -X POST “https://api.affinity.co/lists/{list_id}/list-entries” \
   -u :$APIKEY \
   -H "Content-Type: application/json" \
   -d '{"entity_id": organization_id}'
    
    return

# %%
def update_field(organization_id, list_id):

    url = f'https://api.affinity.co/fields?list_id={list_id}'
    all_list_fields = requests.get(url, auth=HTTPBasicAuth('', api_key))
    
    for field_name in company_info:
        field_id = all_list_fields.get("id", "") where all_list_fields.get("name", "") == field_name

    return

# %%
def find a name to say that I add a company to affinity but stay short(company_info)
    company_info.get("Name" and "Website URL")
    organization_id = create_organization(name, website_url)
    update_field(organization_id, list_id)
    return

# %%
def update_field(organization_id, list_id):

    url = f'https://api.affinity.co/fields?list_id={list_id}'
    all_list_fields = requests.get(url, auth=HTTPBasicAuth('', api_key))
    
    for field_name in company_info:
        field_id = all_list_fields.get("id", "") where all_list_fields.get("name", "") == field_name
    
    


        
        field_id = get_field_id(field_name, headers)
    if not field_id:
        return f"Field '{field_name}' not found."

    organization_id = company_info['organization_id']

    # Step 2: Check if a field value already exists for the organization
    existing_field_value = get_existing_field_value(organization_id, field_id, headers)

    if existing_field_value:
        # Step 3: Update the existing field value
        field_value_id = existing_field_value['id']
        url = f'https://api.affinity.co/field-values/{field_value_id}'
        data = {'value': 'To Screen'}
        response = requests.patch(url, headers=headers, json=data)
    else:
        # Step 4: Create a new field value
        url = 'https://api.affinity.co/field-values'
        data = {
            'field_id': field_id,
            'organization_id': organization_id,
            'value': 'To Screen'
        }
        response = requests.post(url, headers=headers, json=data)

    if response.status_code in [200, 201]:
        return "Affinity updated successfully"
    else:
        return f"Error updating Affinity: {response.text}"

def get_existing_field_value(organization_id, field_id, headers):
    url = f'https://api.affinity.co/organizations/{organization_id}/field-values'
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return None
    field_values = response.json()
    for fv in field_values:
        if fv['field']['id'] == field_id:
            return fv
    return None

# %%
url = 'https://api.affinity.co/fields'

# %%
url = f'https://api.affinity.co/organizations/{oragnization_id}'
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
person_ids = response.json().get("person_ids")
for person_id in person_ids:
    url = f'https://api.affinity.co/persons/{person_id}'
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    "FirstName" = response.json().get("first_name")
    "LastName" = response.json().get("last_name")
    "Email" = response.json().get("primary_email" if not emails[0])
# Out:
# {'id': 166524725, 'type': 0, 'first_name': 'Wim', 'last_name': 'Vernaeve', 'primary_email': 'wim.vernaeve@gmail.com', 'emails': ['wim.vernaeve@gmail.com', 'wim.vernaeve@greenparkinvest.com', 'wim.vernaeve@googlemail.com', 'wim@bragster.com', 'wim_vernaeve@hotmail.com', 'mlnamc17tpfh20u0vp25fsrmn4@group.calendar.google.com'], 'organization_ids': [1516330, 1687144, 163299958], 'list_entries': []}
# {'id': 168464200, 'type': 0, 'first_name': 'NoName', 'last_name': 'Inthepocket.mobi@allusers.d.calendar.google.com', 'primary_email': 'inthepocket.mobi@allusers.d.calendar.google.com', 'emails': ['inthepocket.mobi@allusers.d.calendar.google.com'], 'organization_ids': [1687144], 'list_entries': []}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 6
#       4 for person_id in person_ids:
#       5     url = f'https://api.affinity.co/persons/{person_id}'
# ----> 6     response = requests.get(url, auth=HTTPBasicAuth('', api_key))
#       7     print(response.json())
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#     730 response_conn = conn if not release_conn else None
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463             httplib_response = conn.getresponse()
#     464         except BaseException as e:
#     465             # Remove the TypeError from the exception chain in
#     466             # Python 3 (including for exceptions like SystemExit).
#     467             # Otherwise it looks like a bug in the code.
# --> 468             six.raise_from(e, None)
#     469 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     470     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:463, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 except TypeError:
#     461     # Python 3
#     462     try:
# --> 463         httplib_response = conn.getresponse()
#     464     except BaseException as e:
#     465         # Remove the TypeError from the exception chain in
#     466         # Python 3 (including for exceptions like SystemExit).
#     467         # Otherwise it looks like a bug in the code.
#     468         six.raise_from(e, None)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
person_ids = response.json().get("person_ids")
for person_id in person_ids:
    url = f'https://api.affinity.co/persons/{person_id}'
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    print(response.json())

# %%
url = f"{base_url}/lists/{list_id}/list-entries"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))

response.json()
# Out:
# [{'id': 171964735,
#   'list_id': 271745,
#   'creator_id': 185792297,
#   'entity_id': 224088093,
#   'entity_type': 1,
#   'created_at': '2024-10-21T06:10:54.842-07:00',
#   'entity': {'id': 224088093,
#    'name': 'Cytocast',
#    'domain': 'cytocast.com',
#    'domains': ['cytocast.com'],
#    'crunchbase_uuid': None,
#    'global': True}},
#  {'id': 171964736,
#   'list_id': 271745,
#   'creator_id': 185792297,
#   'entity_id': 299211990,
#   'entity_type': 1,
#   'created_at': '2024-10-21T06:10:54.842-07:00',
#   'entity': {'id': 299211990,
#    'name': 'Neo mobility',
#    'domain': 'neo-mobility.be',
#    'domains': ['neo-mobility.be'],
#    'crunchbase_uuid': None,
#    'global': False}},
#  {'id': 171705227,
#   'list_id': 271745,
#   'creator_id': 185792297,
#   'entity_id': 1687144,
#   'entity_type': 1,
#   'created_at': '2024-10-18T05:25:21.785-07:00',
#   'entity': {'id': 1687144,
#    'name': 'Google',
#    'domain': 'google.com',
#    'domains': ['google.com',
#     'greenparrotpictures.com',
#     'newsinitiative.withgoogle.com',
#     'infinitypocket.blogspot.in',
#     'midnightboom.blogspot.co.uk'],
#    'crunchbase_uuid': None,
#    'global': True}},
#  {'id': 171704891,
#   'list_id': 271745,
#   'creator_id': 185792297,
#   'entity_id': 294139876,
#   'entity_type': 1,
#   'created_at': '2024-10-18T05:12:46.467-07:00',
#   'entity': {'id': 294139876,
#    'name': 'Tekst.ai',
#    'domain': 'tekst.com',
#    'domains': ['tekst.com'],
#    'crunchbase_uuid': None,
#    'global': True}}]

# %%
url = f"{base_url}/field-values?organization_id=224088093"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
response.json()
# Out:
# [{'id': 13542527317,
#   'field_id': 4711807,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 7,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': {'id': 16671075, 'text': 'To Screen', 'rank': 7, 'color': 0}},
#  {'id': 13542527318,
#   'field_id': 4711827,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': 'Advanced simulation technology for drug discovery and personalized medicine using multi-omics data.'},
#  {'id': 13542527319,
#   'field_id': 4711828,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': 'TechBio'},
#  {'id': 13542527320,
#   'field_id': 4711829,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': '-'},
#  {'id': 13542527321,
#   'field_id': 4733935,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': 'B2B'},
#  {'id': 13542527322,
#   'field_id': 4733936,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': 'Subscription'},
#  {'id': 13542527323,
#   'field_id': 4761134,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': '{\'https://www.cytocast.com\': "H1: Home\\nH1: Imagine...a world where new therapies can be discovered and developed in a fraction of what it takes now.\\nH1: How can we help?\\nH1: People and Values\\nH1: How we do it\\nH1: 0\\nH1: 0\\nH1: 0\\nH1: 0\\nH1: News\\nH1: Blog\\nH1: Interested in a demo?\\nH2: Drug Discovery\\nH2: Precision medicine\\nH2: MAKE MEDICINE BETTER WITH ADVANCED CELL SIMULATION TECHNOLOGY\\nH2: Cytocast is using computer simulations to determine the most effective treatment for patients while minimazing potential side effects\\nH2: Proteins per simulation\\nH2: Protein-protein interactions\\nH2: Binding sites per simulation\\nH2: Nr. of cell types\\nH3: OUR VALUES\\nH3: THE TEAM\\nPARAGRAPH: Join our pilot study partnership to test Cytocast Simulated Cell!\\nPARAGRAPH: a world where new therapies can be discovered and developed in a fraction of what it takes now.\\nPARAGRAPH: Cytocast is an emerging TechBio startup based in Budapest that  specializes in data-driven medical technology. We leverage this data to  add value and achieve impactful results.\\nPARAGRAPH: We are proud to be a company with a curious mindset and a strong research orientation.  What sets us apart is the way we integrate multi-omics data, extensive scientific knowledge, expertise, high-performance computing, and cutting-edge data science methods to maximize insights into patient biology and accelerate the pace of drug discovery and development.  We also have the privilege of working with numerous collaborative partners.  We value these partnerships and recognize their importance in advancing our mission.\\nPARAGRAPH: At Cytocast, we believe in creative solutions and in the power of teamwork in a familiar atmosphere. Many of our team members have university affiliations continually exploring new possibilities.\\nPARAGRAPH: Last week, we had the pleasure of presenting Cytocast\'s cutting-edge technology at the 4th Digital Health Summit as the Best Solution in the Digital Therapy category winner.\\nPARAGRAPH: We are thrilled to announce that we have successfully secured our second investment round...\\nPARAGRAPH: Cytocast team recently participated in the Hungarian Molecular Life Science Conference held in Eger. The conference...\\nPARAGRAPH: Cytocast\\xa0 has made significant strides during the second quarter of 2024, advancing its cutting-edge technology in the field of digital twin simulations and predictive algorithms.\\nPARAGRAPH: Cytocast, at the forefront of innovation, utilizes AI in the Cytocast Simulated Cell to model drug-target interactions, predict efficacy, and identify potential side effects early in drug development. Our commitment extends to ethical considerations, ensuring responsible AI use in shaping the future of drug discovery.\\nPARAGRAPH: Get in touch today to see how the Cytocast platform works.", \'https://www.cytocast.com/cytocast-digital-twin/\': "H1: No Title\\nPARAGRAPH: Join our pilot study partnership to test Cytocast Simulated Cell!\\nH1: Transforming Patient CareEmbark on a groundbreaking journey towards personalized medicine with Cytocast Digital Twin. Our revolutionary technology combines multi-omics data and patient-specific clinical information to create an exact digital replica of each individual.\\nPARAGRAPH: Embark on a groundbreaking journey towards personalized medicine with Cytocast Digital Twin. Our revolutionary technology combines multi-omics data and patient-specific clinical information to create an exact digital replica of each individual.\\nH1: Cytocast™ Digital Twin\\nPARAGRAPH: We use data to add value and generate meaningful results thatdrive positive technological progress in precision medicine. Our aim with Cytocast™ Digital Twin is to significantly improve treatment efficacy and provide patients with effective therapeutic options.\\n**drive positive technological progress in precision medicine**\\nPARAGRAPH: Our latest breakthrough technology, the Cytocast™ Digital Twi ...
#  {'id': 13542527640,
#   'field_id': 3909160,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.221-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527645,
#   'field_id': 3909163,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.265-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527650,
#   'field_id': 3909164,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.305-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527668,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527666,
#   'field_id': 3909168,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 5,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.338-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527670,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527671,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527672,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527673,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527674,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527683,
#   'field_id': 3909169,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 4,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.418-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527693,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527694,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527695,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527709,
#   'field_id': 3909166,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.488-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527697,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527698,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527699,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527719,
#   'field_id': 3909165,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.525-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527724,
#   'field_id': 3909167,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.553-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527729,
#   'field_id': 3909177,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.595-07:00',
#   'updated_at': None,
#   'value': 2340900.0},
#  {'id': 13542527743,
#   'field_id': 3909178,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.638-07:00',
#   'updated_at': None,
#   'value': 1836000.0},
#  {'id': 13542527772,
#   'field_id': 3909175,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.827-07:00',
#   'updated_at': None,
#   'value': 15.0},
#  {'id': 13542527752,
#   'field_id': 3909174,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.696-07:00',
#   'updated_at': None,
#   'value': "Cytocast is a TechBio startup company pioneering the future of drug development with its revolutionary Cytocast Simulated Cell platform. We're transforming the landscape by enabling safer and smarter drug development, putting patient well-being at the forefront. By combining multi-omics data integration with advanced computational modeling, we're redefining drug development. Our platform allows us to predict how different drugs will affect cellular processes, making drug side effect predictions in the early phases of drug development a reality. Our focus extends to the future of personalized medicine. We're advancing beyond one-size-fits-all treatments, embracing tailored therapies powered by advanced technologies to revolutionize drug development."},
#  {'id': 13542527776,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Bioinformatics'},
#  {'id': 13542527777,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Biotechnology'},
#  {'id': 13542527778,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Computer'},
#  {'id': 13542527779,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Pharmaceutical'},
#  {'id': 13542527780,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Simulation'},
#  {'id': 13542527784,
#   'field_id': 3909176,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.865-07:00',
#   'updated_at': None,
#   'value': 2019.0},
#  {'id': 13542527788,
#   'field_id': 3909182,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.910-07:00',
#   'updated_at': None,
#   'value': 'https://linkedin.com/company/cytocast'},
#  {'id': 13542527793,
#   'field_id': 3909179,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 5,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.970-07:00',
#   'updated_at': None,
#   'value': {'street_address': None,
#    'city': 'Budapest',
#    'state': 'Budapest',
#    'country': 'Hungary',
#    'continent': None}},
#  {'id': 13542529074,
#   'field_id': 3909195,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.590-07:00',
#   'updated_at': None,
#   'value': 'SaaS'},
#  {'id': 13542529142,
#   'field_id': 3909190,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.778-07:00',
#   'updated_at': None,
#   'value': 'Venture Capital'},
#  {'id': 13542529145,
#   'field_id': 3909190,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.778-07:00',
#   'updated_at': None,
#   'value': 'accelerator'},
#  {'id': 13542529159,
#   'field_id': 3909197,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.821-07:00',
#   'updated_at': None,
#   'value': 2040000.0},
#  {'id': 13542529081,
#   'field_id': 3909194,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.611-07:00',
#   'updated_at': None,
#   'value': 'b2b'},
#  {'id': 13542529140,
#   'field_id': 3909201,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 5,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.770-07:00',
#   'updated_at': None,
#   'value': {'street_address': None,
#    'city': 'Budapest',
#    'state': 'Budapest',
#    'country': 'Hungary',
#    'continent': None}},
#  {'id': 13542529116,
#   'field_id': 3909191,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.678-07:00',
#   'updated_at': None,
#   'value': 'Subscription'},
#  {'id': 13542529153,
#   'field_id': 3909188,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.803-07:00',
#   'updated_at': None,
#   'value': 'Artificial Intelligence'},
#  {'id': 13542529154,
#   'field_id': 3909188,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.803-07:00',
#   'updated_at': None,
#   'value': 'Big Data'},
#  {'id': 13542529176,
#   'field_id': 3909186,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.862-07:00',
#   'updated_at': None,
#   'value': 97.0},
#  {'id': 13542529091,
#   'field_id': 3909199,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.646-07:00',
#   'updated_at': None,
#   'value': 'Simulated cells to shape the future of medicine'},
#  {'id': 13542529102,
#   'field_id': 3909192,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.667-07:00',
#   'updated_at': None,
#   'value': '11-50'},
#  {'id': 13542529120,
#   'field_id': 3909200,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.710-07:00',
#   'updated_at': None,
#   'value': 'Health'},
#  {'id': 13542529121,
#   'field_id': 3909200,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.710-07:00',
#   'updated_at': None,
#   'value': 'Pharmaceutical'},
#  {'id': 13542529122,
#   'field_id': 3909200,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.710-07:00',
#   'updated_at': None,
#   'value': 'BioTechnology'},
#  {'id': 13542529136,
#   'field_id': 3909196,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.749-07:00',
#   'updated_at': None,
#   'value': 1600000.0},
#  {'id': 13542529165,
#   'field_id': 3909187,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.832-07:00',
#   'updated_at': None,
#   'value': 57.0},
#  {'id': 13542529183,
#   'field_id': 3909185,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.886-07:00',
#   'updated_at': None,
#   'value': 1.0},
#  {'id': 13542529197,
#   'field_id': 3909184,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.916-07:00',
#   'updated_at': None,
#   'value': 53.0},
#  {'id': 13542529200,
#   'field_id': 3909183,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.929-07:00',
#   'updated_at': None,
#   'value': 'https://app.dealroom.co/companies/cytocast'},
#  {'id': 13542529212,
#   'field_id': 3909198,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.962-07:00',
#   'updated_at': None,
#   'value': 2019.0}]

# %%
field_value_id = 13542527317  # The field value ID you're trying to update
value = 16696434  # The dropdown ID for 'To Screen'

# Update URL
url = f"{base_url}/field-values/{field_value_id}"

# Correct payload: just send the integer value (dropdown option ID)
payload = {
    "value": {"id": (value)}  # Use the ID of the dropdown option as the value
}

# Make the PUT request to update the field value
response = requests.put(url, json=payload, auth=HTTPBasicAuth('', api_key))

# Check the response
print(response.status_code)
print(response.json())
# Out:
# 422
# ["Field value: Record doesn't have field entity_attribute_id set to 4711807 (Affinity::Validator::HasFieldError)"]

# %%
response.json()
# Out:
# ["Field value: Record doesn't have field entity_attribute_id set to 4711807 (Affinity::Validator::HasFieldError)"]

# %%
Hello,

I have a problem to update the Status field via an API request here is a simple python example:

from the list ID "271745" I want to modify the entity Cytocast here is it's dictionnary:
{'id': 171964735,
  'list_id': 271745,
  'creator_id': 185792297,
  'entity_id': 224088093,
  'entity_type': 1,
  'created_at': '2024-10-21T06:10:54.842-07:00',
  'entity': {'id': 224088093,
   'name': 'Cytocast',
   'domain': 'cytocast.com',
   'domains': ['cytocast.com'],
   'crunchbase_uuid': None,
   'global': True}}

from the Status filed in the API-test list here is it's dictionnary of the field:
[{'id': 13542527317,
  'field_id': 4711807,
  'list_entry_id': 171673564,
  'entity_type': 1,
  'value_type': 7,
  'entity_id': 224088093,
  'created_at': '2024-10-18T01:35:15.900-07:00',
  'updated_at': None,
  'value': {'id': 16671075, 'text': 'To Screen', 'rank': 7, 'color': 0}},

 the field value id is this:
[{'id': 13542527317,
  'field_id': 4711807,
  'list_entry_id': 171673564,
  'entity_type': 1,
  'value_type': 7,
  'entity_id': 224088093,
  'created_at': '2024-10-18T01:35:15.900-07:00',
  'updated_at': None,
  'value': {'id': 16671075, 'text': 'To Screen', 'rank': 7, 'color': 0}},

 But when I try:
    
field_value_id = 13542527317
value = 16696434

# Update URL
url = f"{base_url}/field-values/{field_value_id}"

# Correct payload: just send the integer value (dropdown option ID)
payload = {
    "value": str(value)  # Use the ID of the dropdown option as the value
}

# Make the PUT request to update the field value
response = requests.put(url, json=payload, auth=HTTPBasicAuth('', api_key))

I get:
["Field value: Record doesn't have field entity_attribute_id set to 4711807 (Affinity::Validator::HasFieldError)"]
# Out:
#   Cell In[48], line 5
#     from the list ID "271745" I want to modify the entity Cytocast here is it's dictionnary:
#                                                                              ^
# SyntaxError: unterminated string literal (detected at line 5)
