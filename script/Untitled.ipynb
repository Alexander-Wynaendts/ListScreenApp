# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("AFFINITY_API_KEY") 

list_id = 271745

# %%
organization_id = 299266107

# %%
email = "gmail"

# %%
url = "https://api.affinity.co/notes"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
notes = response.json().get("notes", [])
for note in notes:
    find all where organization_id is in note.get("organization_ids", []):
    if any existe:
        note_id = note.get("id", "")
        update_url = f"https://api.affinity.co/notes/{note_id}"
        data = {'content': note_content}
        update_response = requests.put(update_url, auth=HTTPBasicAuth('', api_key), json=data)
    if no exist:
        create_url = "https://api.affinity.co/notes"
        data = {'content': note_content, 'type': 2, organization_ids[organization_id]}
        update_response = requests.put(update_url, auth=HTTPBasicAuth('', api_key), json=data)
# Out:
# {'notes': [{'id': 21515873,
#    'creator_id': 166190803,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [291720631],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': "**Meeting Lexroom <> Evert & Tibe, 30/08/2024**\n\n\n\n\n\n* Paolo: Engineering and Finance background (studies). Started building startups 5 years ago. Ups and downs. Last startup: from 0 to 7M ARR. Focus: product and hiring, fundraising. Limited sales\n\n* 3rd co-founder: Andrea: AI engineer. 9 years experience building AI software. wrote a book about deep learning.\xa0\n\n* Martina: Legal background. Double degree in Bologna and London. Also community builder on social media. Joined/started a startup which than failed.\n\n* Met in venture builder?\n\n* working on Lexroom for 1 year\n\n* Saw a big opportunity in the Legal tech space. Saw we invested in Henchman\n\n* Decided to start from one most low value adding activity: legal research. 1/3 of the time of legal professional. old school this is done via keyword search, a lot of out of context results\n\n* key value prop: provide reliability, when using AI\n\n* drafts of legal opinions\n\n* co-desgined\xa0it with 3rd law firm in Italy\n\n* first version of product in Sept 2023; gave 37\\% savings (of time spent)\n\n* had a lot of inbound leads coming\n\n* 250,000 lawyers in Italy. had a lot of requests from single profssionals. quickly adopted their GTM strategy to also cover smaller customers\n\n* have 120 customers. 160K ARR\n\n* ICP: initially idea was to bring theproduct\xa0to law firms with 50 or more layers => these were slow. Then started working on the product to allow large part of market to use it. single lawyers and law firms up to 5 partners\n\n* Revenue split: 80\\% individual lawyers; revenue split 60\\% individual lawyers\n\n* CAC is low: 2 euro on google, 10 euro on LinkedIn\n\n* ACV is low; on average below 1K. 1 person can easily do 20-30 contracts per month\n\n* ENT: 90 days\n\n* legal market is not very concentrated in Italy. top 50 law firms make up for 15\\%, so very fragmented\n\n* Also interesting in Spain, France (Doctrine)\n\n* See expansion in 2 different directions in parallel: ent\xa0+ mass market customers with two different sales motions\n\n* signed 10 biggest law firm with partnership. signed as a customer. they will help with the product\n\n* Product\n  \n  * allows\xa0lawyers\xa0to do legal opinion and drafting\n  \n  * flexible AI stack\n\n* Competition\n  \n  * In Italy: competitors are smaller\n  \n  * for ENT: Harvey, Leya, LegalFly => the big competitors. see this in big law firms\n  \n  * legal sources that Lexroom has are better\n  \n  * mass market strategy is differentiation\n\n* Traction\n  \n  * 163K ARR; 130 customers\n  \n  * closing 20-30 customers per month\n  \n  * sept 200K ARR\n  \n  * end of 2024: 350 - 400K ARR\n  \n  * 2025: aug: 1M ARR; end of year 1.3M ARR\n\n* Funding round\n  \n  * We raised in Dec\\'2023: 500K with convertible note, 2 Italian VCs and bus angels (ex legal counsel of AirBnB)\n  \n  * Now plan on new round, starting mid-Sept\n  \n  * 3 - 5M euro to scale in Italy, conquer Italy in next 12 months, every lawyer in Italy need to have said yes or no, and scale to other countries\n  \n  * are very cash efficient. took 100K in cash to get to today\n\n* Next step: finalizing the deck",
#    'type': 2,
#    'created_at': '2024-10-22T12:05:10.670-07:00',
#    'updated_at': None},
#   {'id': 21512305,
#    'creator_id': 166190803,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [294505464],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': '**Morgan (Nesti) <> Evert call, 22/10/2024**\n\n\n\n\n\nIntroduction and Company Overview\n\n* Morgan Edmondson: Co-founder of Nesty, founded 8 months ago\n\n* Nesti creates AI replicas for personalized video communications\n\n* Current ARR: 75k across 7 customers\n\n* Pipeline sitting at around 1.5 million\n\n* Diverse customer base including NHS, private schools, hospitals, B2B SaaS companies\n\nCommercial Traction and Team Structure\n\n* Target ARR by end of year: GBP 200-250k\n\n* End of next year target: GBP 1.4 - 1.5 million ARR\n\n* Current usage: 5000+ videos created in one month\n\n* Team: 3 co-founders (Morgan, Luke, Will) + 2 part-time developers\n\n* Developers based in India/New York\n\n* Will (CPO) handles product development, management, and customer success\n\n* Luke (CRO) handles go-to-market activities\n\n* Morgan (CEO) leads fundraising and overall strategy\n\nProduct Differentiation and Future Plans\n\n* Nesti aims to transform business communications across marketing, sales, and customer support\n\n* Differentiation: Deep integration with customer data for truly personalized videos\n\n* Targeting multi-industry, multi-department functionality\n\n* Fundraising goal: 1.5-2 million\n\n* Valuation target: Around 50 million post-money\n\n* Plans to expand to US market next year\n\n* Currently in pipe are some US companies like HubSpot, Zoominfo, Sage\n\n* Aiming to close funding round by March next year at the latest, open to do this earlier\n\n\n\nAction items:\n\nMorgan Edmondson\n\n* Send pitch deck and data room to Evert by end of the week (30:45)\n\n\nEvert Beeckman\n\n* Review pitch deck and follow up with additional questions (29:15)',
#    'type': 2,
#    'created_at': '2024-10-22T08:47:38.314-07:00',
#    'updated_at': None},
#   {'id': 21511415,
#    'creator_id': 166190803,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [166190605],
#    'organization_ids': [298834927],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': '**Expert call with Pieter Wijnant <> Evert on 21/10/2024**\n\n\n\n* Pieter is a recruiter at the exec search firm Schelstraete-Delacourt, based in Ghent\n  \n  * Previously worked at Hudson, one of the larger recruiters in Belgium for the mid-senior segment\n  \n  * Before that worked at Harvey Nash, recruiter for ICT profiles, typically providing contractor mgmt\n\n* Tech setup at Schelstraete:\n  \n  * Use an ATS solution that has been created in house based on FileMaker\n    \n    * They recently refreshed their FileMaker based system\n    \n    * Are now working with a company from the Cronos group to add an AI layer to it\n    \n    * Recently acquired an exec search firm in the Netherlands who was using Bullhorn.\n      \n      * They evaluated their solution against the Schelstraete solution, and concluded the Schelstraete solution is better\n      \n      * They had to pay Bullhorn to get their own data of the tool, it was expensive. Will never go back to Bullhorn\n      \n      * \\[ note: there could be an opportunity to win business with \\"own your data\\", but downside is that it\\\'s not easy/cheap to migrate away from Bullhorn\\]\n\n* Tech setup at Hudson\n  \n  * Moved to MS Dynamics a couple of years ago.\n  \n  * Primarily a CRM solution; used an ATS solution integrated in their Dynamics setup but with a very based UX/UI\n\n* Tech setup at Harvey Nash\n  \n  * Moved from in house tooling to a SaaS ATS (unclear which one), not impressed by the capabilities\n  \n  \n* Overall comment: has never seen a setup with a good CRM as well as ATS. Recognizes the potential if a company can offer this\n\n* Tech requirement between the CRM and ATS: if you acquire a new customer, you cannot recruit from that company anymore. Many tools struggle with this.\n\n* Specifically for Schelstraete: doesn\\\'t think they would move to a new solution short term given the recent investment in their FileMaker setup.\n  \n  * \\[Note: potentially they could start using some of the Spott components\\]\n  \n  \n\n\n\n\n@Pieterjan Bouten',
#    'type': 2,
#    'created_at': '2024-10-22T07:59:09.405-07:00',
#    'updated_at': None},
#   {'id': 21510740,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [298791791],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Suggested rejection: hardware component\n\n\n\n**Summary**\n\n**Founders**\n\n* *Faouzane Batiga*: CEO with a background in computer science and tech, previously ran a development agency.\n\n* *Kevin*: Sales and team management experience, previously worked at Willink, a startup in the legal tech space.\n\n\n\n**One-line description** Yalt is a B2B platform that helps small and medium-sized businesses easily deploy and manage loyalty programs using AI-driven personalized campaigns.\n\n\n\n\n\n**Traction**\n\n* 25 paying clients.\n\n* €250 average revenue per client per month, primarily charging €49.90 per location.\n\n* €3,000 MRR.\n\n\n\n**Why them?** Faouzane Batiga brings tech experience and entrepreneurial drive from his development agency, transitioning from building products to managing and scaling them. Kevin has relevant sales and management expertise from his time at Willink. Together, they seem well-suited to address the problem of loyalty program management for small businesses.\n\n\n\n**Why now?** The increasing demand for personalized customer experiences, coupled with the accessibility of AI, makes it the right time to offer affordable, easy-to-deploy loyalty programs to smaller businesses.\n\n\n\n**Too hyped?** The loyalty tech sector is growing, but the company’s focus on smaller businesses helps them avoid competing in an overly saturated segment dominated by large enterprise solutions.\n\n\n\n**Too greedy?** The founders are not overly ambitious in their fundraising plans, aiming for realistic growth with a modest MRR. Their fundraising goal of €500k to €1 million appears in line with their current traction and expansion plans.\n\n\n\n**In depth part:**\n\n**ICP**\n\n* Small to medium-sized businesses.\n\n* Primary geography: Europe, with clients already in Spain, Portugal, France, UK, and Italy.\n\n* Contract size: ~€250 per month for smaller clients.\n\n\n\n**Addressed problem** Yalt helps small and medium-sized businesses create and manage loyalty programs, filling a gap for businesses that lack the resources or expertise to build these programs in-house. The problem is significant but focused on a niche segment with scalable potential.\n\n\n\n**Team**\n\n* *Faouzane Batiga*: Experienced in software development and business management from his agency background.\n\n* *Kevin*: Expertise in sales and scaling teams, previously at Willink, a legal tech startup.\n\n\n\n**Market** Yalt targets the B2B loyalty program market, specifically catering to small and medium-sized businesses that need affordable and easy-to-use solutions. Their market spans Europe, with plans to expand further.\n\n\n\n**Sales** They have 25 paying clients with a monthly recurring revenue (MRR) of €3,000.\n\n\n\n**Product** Yalt offers a B2B loyalty platform that helps businesses deploy loyalty programs, including features such as AI-driven personalized campaigns, integration with cashier machines, and communication tools (SMS, email, push notifications). They also offer NFC-enabled devices to facilitate loyalty interactions.\n\n\n\n**Competition** Their main competitor is Untavo, which targets larger enterprises with a higher price point. Yalt differentiates by offering a lower entry price and focusing on small and medium-sized businesses.\n\n\n\n**Problems?** No IP or cap table issues mentioned.\n\n\n\n**Current funding situation** The company has bootstrapped so far with personal investments from the founders. They have received an influx of €60k from interested investors but have not raised a formal round yet.\n\n\n\n**Raising funding** They are looking to raise €500k to €1 million to expand into other European markets, particularly targeting medium-sized businesses that need localized support.\n\n\n\n**Q&A**\n\n* **Q**: \\"How would you describe your current traction?\\"\n  \n  * **A**: \\"We currently have 25 paying clients and €3k MRR.\\"\n  \n  \n* **Q**: \\"What are your growth plans?\\"\n  \n  * **A**: \\"We are c ...
#    'type': 2,
#    'created_at': '2024-10-22T07:19:55.673-07:00',
#    'updated_at': '2024-10-22T07:57:31.254-07:00'},
#   {'id': 21510077,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [290977283],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Are going to confirm that they are going to raise at end of the month. Proposed to then go further into the fundraising process (send slides etc.) -> so currently nurture till end of the month\n\n\n\n**Summary**\n\n**Founders**\n\n* **Jim Ralley**: Founder with 12 years of experience as a consultant in corporate learning and development, has worked with major global companies, charities, and governments.\n\n* **Matt**: Responsible for product design and UX/UI, has enterprise SaaS experience, previously worked at fintechs.\n\n* **Steve Jordan**: CTO, with a focus on enterprise SaaS, also from fintech background, joined 6 months ago.\n\n\n\n**One-line description**  \nThe startup provides an analytics tool for corporate learning and development (L&D) professionals to help manage, analyze, and extract insights from learning data.\n\n\n\n**Traction**\n\n* Two paid clients:\n  \n  1.  IKEA, on an extended paid pilot for a program that runs several times per year.\n  \n  2.  Accenture, paying €1,500 per month as a monthly recurring license, with potential to scale across six programs.\n\n* Six more companies are in the pipeline for qualification and demos.\n\n\n\n**Why them?**  \nThe founders are well-matched for this product, with Jim bringing industry expertise from corporate learning, while Matt and Steve bring relevant experience in building enterprise SaaS products.\n\n\n\n**Why now?**  \nThe shift to online learning post-COVID has increased the need for L&D teams to prove the impact of their programs, which aligns with the current trend of organizations needing data-driven insights. Additionally, AI advancements make it feasible to automate data analysis and insight extraction.\n\n\n\n**Too hyped?**  \nThe L&D data analytics sector does not appear overhyped, as most competition is limited to manual methods (Excel, PowerPoint) or complex tools like Power BI, which require technical expertise L&D professionals often lack. The funding expectations seem aligned with realistic growth.\n\n\n\n**Too greedy?**  \nThe founders are not overly ambitious with their goals and are cautious about fundraising. They prefer to continue bootstrapping unless traction proves the need to raise capital. Their growth plan focuses on obtaining about 20 customers to justify further expansion.\n\n\n\n**In-depth part:**\n\n**ICP**  \nIdeal Customer Profile includes companies with over 500 employees that have a large L&D team dealing with fragmented and unstructured data. Primarily targeting corporate environments like IKEA and Accenture, which have significant learning data to manage.\n\n\n\n**Addressed problem**  \nThe startup addresses the challenge of managing large volumes of fragmented L&D data across various platforms and systems. L&D teams struggle to derive meaningful insights from this data, which is often scattered across spreadsheets and different tools.\n\n\n\n**Team**\n\n* **unnamed person** working on the frontend\n\n\n\n\n**Market**  \nThe company targets the global L&D market, which is worth approximately $419 billion. Their serviceable obtainable market (SOM) for the UK and USA is estimated at $174 million, based on capturing 1\\% of the L&D spend from large organizations.\n\n\n\n**Sales**  \nCurrent pipeline includes demos and discussions with six companies, following paid engagements with IKEA and Accenture. The goal is to expand within these organizations and convert more leads into paying clients.\n\n\n\n**Product**  \nThe product is an analytics tool that ingests and organizes L&D data from multiple sources, generating reports and insights that help organizations evaluate the effectiveness of their learning programs. It leverages AI to automate data sorting and qualitative analysis.\n\n\n\n**Competition**  \nMain competition includes manual methods (Excel, PowerPoint) and more complex, technical tools like Tableau and Power BI, which require significant data expertise that most L&D professionals lack. Fathom’s differe ...
#    'type': 2,
#    'created_at': '2024-10-22T06:31:15.801-07:00',
#    'updated_at': None},
#   {'id': 21509799,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [292867222],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': '**Summary**\n\n**Founders:**\n\n* **Callum Rimmer (Founder)**: 20 years of experience in finance and tech. Co-founder of By Miles, a car insurer sold to Direct Line Group.\n\n**One-line description:** Swallow offers an AI-driven, no-code platform that accelerates insurance product development by enabling insurers to quickly create and modify complex models.\n\n\n\n**Traction:**\n\n* ARR: $120K, with a potential to reach $1 million ARR by end of 2024.\n\n* 4 signed clients, 30+ hosted insurance models.\n\n* Pipeline: 150+ companies on the waiting list.\n\n* Scalable revenue model starting at $40K ACV.\n\n\n\n**Why them?** The founder and team have deep experience in insurtech and fintech. Callum’s success with By Miles shows strong founder-product fit, especially in the insurance sector, which Swallow directly targets.\n\n\n\n**Why now?** The insurance industry is slow to adopt new technologies, but AI, generative models, and regulatory changes are creating an opportunity for early adopters. Swallow offers significant operational savings, making the timing ripe for disruption.\n\n\n\n**Too hyped?** The insurance tech space, particularly non-commoditized products, is growing but not overhyped. The $4M seed raise, while ambitious, seems reasonable given their ARR growth target and scalability plan.\n\n\n\n**Too greedy?** The projected ARR and customer pipeline suggest ambitious but realistic growth. The 20\\% dilution at around a $16M pre-money valuation is reasonable within the current market.\n\n\n\n**In-depth part:**\n\n**ICP:**\n\n* **Size**: Property & Casualty insurers with <100 employees, < $100M in GWP (gross written premium).\n\n* **Geography**: Primarily focused on smaller geographies.\n\n* **Contracts**: Smaller insurers and brokers, excess and surplus lines.\n\n\n\n**Addressed problem:** Insurers struggle with slow and costly product pipelines. Creating new products can take months and cost upwards of $100K. Swallow reduces this process to a week at ~$3K, significantly cutting costs and time.\n\n\n\n**Team:**\n\n* **Callum Rimmer**: Founder with 20 years in finance and tech, scaled By Miles to over 100K policyholders.\n\n* **Matt Tortolani**: 10 years of experience in fintech, focusing on engineering.\n\n* **Sam Clifton**: 10 years in product and design, specializing in fintech solutions.\n\n* **Josh Overton**: Manages growth with a background in fintech.\n\n\n\n**Market:**\n\n* Focused on non-commoditized insurance products, particularly in P&C insurance, which constitutes around 15\\% of the market.\n\n* The targeted segment is growing at 12\\% annually, with a $5B tech spend.\n\n\n\n**Sales:**\n\n* 150 companies on the waiting list.\n\n* 4 signed clients, with several insurance propositions built and in operation.\n\n\n\n**Product:** Swallow’s platform uses AI to transform complex insurance models into deployable products rapidly. It integrates no-code workflows, allowing actuaries to build and modify models without tech teams.\n\n\n\n**Competition:** The pitch mentions off-the-shelf insurance platforms for commoditized insurance (like home and auto insurance). Swallow differentiates by targeting non-commoditized products where custom code is usually needed, offering a faster, cheaper alternative.\n\n\n\n**Problems?** No IP, cap table, or other major issues were mentioned.\n\n\n\n**Current funding situation:**\n\n* Raised $1 million pre-seed in Q2 2023.\n\n\n\n\n**Raising funding:**\n\n* Raising $4 million at around a 20\\% dilution but indicated that a lower price is possible (approx. $16M pre-money valuation).\n\n* No fixed timeline to close, but targeting end of Q4 2024.\n\n* Cash runway until Q2 2025.\n\n\n\n**Q&A:**\n\n* **Timeline for funding?**: No immediate rush, as they have runway until Q2 2025, but aiming to close by end of December 2024.\n\n* **Market readiness?**: Initial focus on non-commoditized insurance segments, where AI has the biggest impact.\n\n* **Product-led growth?**: Shifting ...
#    'type': 2,
#    'created_at': '2024-10-22T06:11:17.356-07:00',
#    'updated_at': None},
#   {'id': 21508384,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [205518143],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'a',
#    'type': 2,
#    'created_at': '2024-10-22T05:23:22.420-07:00',
#    'updated_at': None},
#   {'id': 21508007,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [299261665],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'better understanding the shopify space',
#    'type': 2,
#    'created_at': '2024-10-22T04:36:50.198-07:00',
#    'updated_at': None},
#   {'id': 21506222,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [299260291],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'contacted through **mstigmz@gmail.com**.',
#    'type': 2,
#    'created_at': '2024-10-22T02:54:08.825-07:00',
#    'updated_at': None},
#   {'id': 21503746,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [299258960],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': '1 month in so to early look at it in a bit',
#    'type': 2,
#    'created_at': '2024-10-21T23:47:47.163-07:00',
#    'updated_at': None},
#   {'id': 21500368,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [90422877],
#    'parent_id': None,
#    'content': 'Heeft interesse in 2e close',
#    'type': 2,
#    'created_at': '2024-10-21T13:03:04.789-07:00',
#    'updated_at': None},
#   {'id': 21492862,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [298703971],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Not extremely convincing founder. but interesting space so worth to look into further when they launch their product.\n\n\n\n**Summary**\n\n**Founders**\n\n* **Anthony Gale (CEO)**: Serial entrepreneur with experience in digital strategy, building eCommerce platforms, and working with big brands (e.g., Samsung, MTV). Founded Shoprocket (API-led headless commerce) and has a background in helping startups with tech, strategy, and fundraising.\n\n* **Simon Hall (Co-founder, Product)**: eCommerce expert with a background in digital marketing. Worked at Virgin Games, La Perla, and Secret Sales, and has experience with product exits.\n\n* **Milan (CTO)**: Technical lead, responsible for overseeing the product development.\n\n* **Race (Commercial)**: Focused on sales, bringing experience in commercial operations.\n\n\n\n**One-line description** PromoLens provides an AI-powered tool to analyze and optimize the effectiveness of promotions for eCommerce businesses.\n\n\n\n**Traction**\n\n* **Pre-revenue**\n\n* **4 pilot projects** with diverse companies, including a bitumen company, fashion brands, and an online electronics retailer.\n\n\n\n**Why them?** The founders bring relevant experience in eCommerce, tech, and AI, making them well-equipped to tackle the data challenges their product addresses. Anthony’s experience with building API-driven products, alongside Simon’s background in eCommerce, is a strong fit for their focus.\n\n\n\n**Why now?** As the use of AI grows in analyzing business data, PromoLens offers a timely solution for eCommerce companies to optimize promotions, a task historically difficult and resource-intensive.\n\n\n\n**Too hyped?** The product fits into a growing but competitive AI and analytics market, but PromoLens focuses on a niche problem (promotion optimization) that is not oversaturated.\n\n\n\n**Too greedy?** Their current growth plan seems measured, focusing on building the self-serve SaaS platform, acquiring a solid base of clients, and raising additional funds when needed for further scaling.\n\n\n\n**In-depth part:**\n\n**ICP**\n\n* **Target customer**: Mid-size eCommerce companies with a turnover between £20M and £150M. They can go down to £2M or higher with customizations but aim for companies capable of paying for the SaaS solution.\n\n* **Geography**: Not explicitly mentioned, but likely UK and European markets given their experience and connections.\n\n\n\n**Addressed problem** PromoLens solves the complex problem of optimizing the effectiveness of eCommerce promotions. The tool analyzes historical promotional data to help businesses avoid common pitfalls like unnecessary discounts or improper promotion timing, which can hurt profitability.\n\n\n\n**Team**\n\n* **Anthony Gale**: Founder with deep experience in eCommerce, digital strategy, and product development.\n\n* **Simon Hall**: Product and eCommerce expert, bringing years of experience from working with major brands.\n\n* **Milan**: Technical leader focused on the product’s AI and machine learning capabilities.\n\n* **Race**: Responsible for commercial operations and sales strategy.\n\n\n\n**Market** They are targeting the eCommerce analytics and AI-driven promotion optimization market. No explicit market size was mentioned, but their focus on mid-sized companies indicates a substantial opportunity.\n\n\n\n**Sales** They have a pipeline of customers, particularly focused on Shopify and online retail platforms, leveraging Simon’s and Anthony’s network within the industry.\n\n\n\n**Product** PromoLens is an AI-powered promotion analytics tool that connects with eCommerce platforms like Shopify. It analyzes historical data to assess the success of past promotions and provides insights on optimizing future ones. The platform is currently being built into a self-serve SaaS model.\n\n\n\n**Competition** Their main competition comes from large consulting firms like PwC and Nielsen, which offer enterprise-level services. PromoLens dif ...
#    'type': 2,
#    'created_at': '2024-10-21T04:37:39.535-07:00',
#    'updated_at': None},
#   {'id': 21491497,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [299169568],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': '**Summary**\n\n**Founders**\n\n* **Tocha** - Founder, has over 15 years of experience investing in companies, including managing accounting and legal departments.\n\n* **Juan** - Co-founder, described as a \\"technical genius\\" with significant technology expertise. He previously worked for a large corporation after his company was acquired and has collaborated with Tocha on multiple projects.\n\n\n\n**One-line description** An AI-powered business operating system that autonomously manages bureaucracy, financials, and legal tasks for small businesses.\n\n\n\n**Traction**\n\n* No paying users yet, but one customer is committed to start paying in January 2025.\n\n* Currently working closely with three companies to tailor the product.\n\n* By mid-2026, the target is to have 1,000 companies using the product, generating approximately $2.4 million ARR.\n\n\n\n**Why them?** Tocha and Juan have a long history of collaboration and complementary skills (business and technical). They’ve worked together in various ventures, and the product aligns with their expertise in automating bureaucratic tasks.\n\n\n\n**Why now?** The founders believe AI is at the right point to handle tasks like bureaucracy and financials. They’ve also noticed a significant market gap for small businesses needing automation in these areas. They emphasize that 2024 should not require humans to handle mundane tasks that AI can address.\n\n\n\n**Too hyped?** The sector (AI) is highly competitive and crowded, but the founders argue that their niche (targeting small businesses with fewer than 10 employees) differentiates them. However, timing is critical to outpace competition.\n\n\n\n**Too greedy?** No indications of greed; their growth targets are ambitious but grounded (1,000 companies by mid-2026). They have a unique equity structure that aligns incentives among the founding team, aiming to keep 50\\% of founder equity for the team.\n\n\n\n**In-depth Part**\n\n**ICP (Ideal Customer Profile)**\n\n* Small businesses with fewer than 10 employees.\n\n* Initially focusing on Portugal, particularly digital services and software companies.\n\n* Plan to expand beyond Portugal after proving their model.\n\n\n\n**Addressed problem** Managing bureaucracy, financials, and legal tasks is a time-consuming burden for small businesses. Their solution automates this, enabling business owners to focus on growth rather than administrative tasks.\n\n\n\n**Team**\n\n* **Tocha** has over 15 years of experience in investing and managing company operations.\n\n* **Juan** is a seasoned technologist with prior experience building successful companies and working in a corporate environment after an acquisition.\n\n\n\n**Market**\n\n* The initial focus is on Portugal, which has 1.4 million companies with fewer than 10 employees.\n\n* The goal is to capture a significant portion of this market before scaling internationally. Targeting 2.4 million ARR by mid-2026 with 1,000 clients.\n\n\n\n**Sales**\n\n* No paying clients yet; first paying customer expected in January 2025.\n\n* Long-term strategy involves using a podcast and business certification tests to build a user base.\n\n* They aim to reach 200 companies by summer 2025.\n\n\n\n**Product** An AI-powered business operating system for small companies that manages all bureaucratic, financial, and legal processes. The product is designed to integrate seamlessly with existing systems to automate tasks like paying taxes, salaries, and managing cash flow predictions.\n\n\n\n**Competition** The main challenge lies in the complexity of developing AI that works seamlessly with local legal and bureaucratic frameworks. No direct competitors were named, but the founder acknowledges they are building something that seems \\"like magic,\\" aiming for a highly differentiated product.\n\n\n\n**Problems?**\n\n* **Hardware limitations**: Their AI requires high-performance hardware (A100s, H100s) for training models, and their current capaci ...
#    'type': 2,
#    'created_at': '2024-10-21T02:09:06.013-07:00',
#    'updated_at': None},
#   {'id': 21491327,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [298702710],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Initially contacted email adres now bounces -> so feedback email of rejection was not received',
#    'type': 2,
#    'created_at': '2024-10-21T01:54:50.567-07:00',
#    'updated_at': None},
#   {'id': 21491268,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [298489139],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'China based',
#    'type': 2,
#    'created_at': '2024-10-21T01:46:45.649-07:00',
#    'updated_at': None},
#   {'id': 21490852,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [298221293],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Focus on Middle east',
#    'type': 2,
#    'created_at': '2024-10-21T01:09:06.842-07:00',
#    'updated_at': None},
#   {'id': 21490827,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [298656398],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Not active anymore -> now focusing on Armslength ai',
#    'type': 2,
#    'created_at': '2024-10-21T01:05:39.730-07:00',
#    'updated_at': None},
#   {'id': 21490520,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [297556053],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Raised 2.5m, so next round is going to be out of scope for us',
#    'type': 2,
#    'created_at': '2024-10-21T00:09:54.281-07:00',
#    'updated_at': None},
#   {'id': 21490515,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [293609961],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Booked a meeting but ignored all emails',
#    'type': 2,
#    'created_at': '2024-10-21T00:08:53.405-07:00',
#    'updated_at': None},
#   {'id': 21490509,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [289135890],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'First meeting got cancled/rescheduled and a bit lost, but rescheduled a meeting in October',
#    'type': 2,
#    'created_at': '2024-10-21T00:06:55.215-07:00',
#    'updated_at': None},
#   {'id': 21490500,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [292867222],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Had a planned meeting but was rescheduled and then canceled (asking for a reschedule but never actually rescheduled)',
#    'type': 2,
#    'created_at': '2024-10-21T00:04:02.304-07:00',
#    'updated_at': None},
#   {'id': 21490427,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [299169568],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Raising twice before traction, buying hardware with money',
#    'type': 2,
#    'created_at': '2024-10-20T23:38:51.886-07:00',
#    'updated_at': None},
#   {'id': 21490379,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [293021147],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'As mentioned in the call, too early stage and stay in touch.',
#    'type': 2,
#    'created_at': '2024-10-20T23:26:11.413-07:00',
#    'updated_at': None},
#   {'id': 21490358,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [297369999],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Mentioned during meeting that they only want to raise went they have more traction. Mentioned in the meeting that we should stay in touch.',
#    'type': 2,
#    'created_at': '2024-10-20T23:20:46.012-07:00',
#    'updated_at': None},
#   {'id': 21490013,
#    'creator_id': 185792297,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [291956609],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'inbound',
#    'type': 2,
#    'created_at': '2024-10-20T22:52:32.568-07:00',
#    'updated_at': None},
#   {'id': 21486215,
#    'creator_id': 166190803,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [94282187],
#    'parent_id': None,
#    'content': 'Indicated after 1st close he was interested to invest with family office',
#    'type': 2,
#    'created_at': '2024-10-20T11:46:31.908-07:00',
#    'updated_at': None},
#   {'id': 21486211,
#    'creator_id': 166190803,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [94282185],
#    'parent_id': None,
#    'content': 'Indicated after 1st close he was interested to invest with family office',
#    'type': 2,
#    'created_at': '2024-10-20T11:42:44.543-07:00',
#    'updated_at': None},
#   {'id': 21485929,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [94282081],
#    'parent_id': None,
#    'content': 'Introductie Sofie Vandermarliere',
#    'type': 2,
#    'created_at': '2024-10-20T08:46:11.642-07:00',
#    'updated_at': None},
#   {'id': 21485898,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [94282037],
#    'parent_id': None,
#    'content': 'Voorlopig niet contacteren',
#    'type': 2,
#    'created_at': '2024-10-20T08:21:05.010-07:00',
#    'updated_at': None},
#   {'id': 21485778,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [94281999],
#    'parent_id': None,
#    'content': 'Likeley a smaller ticket 25K - 50K',
#    'type': 2,
#    'created_at': '2024-10-20T06:32:50.800-07:00',
#    'updated_at': None},
#   {'id': 21485765,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [90419048],
#    'parent_id': None,
#    'content': 'Passed on 1st close.',
#    'type': 2,
#    'created_at': '2024-10-20T06:23:05.145-07:00',
#    'updated_at': None},
#   {'id': 21485760,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [94281997],
#    'parent_id': None,
#    'content': 'Indicated after 1st close he was interested in 2nd close.',
#    'type': 2,
#    'created_at': '2024-10-20T06:17:09.411-07:00',
#    'updated_at': None},
#   {'id': 21485757,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [90418825],
#    'parent_id': None,
#    'content': 'Reviewing materials 2nd close. No indication of any additional commitment.',
#    'type': 2,
#    'created_at': '2024-10-20T06:06:16.626-07:00',
#    'updated_at': None},
#   {'id': 21485755,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [90419293],
#    'parent_id': None,
#    'content': 'Showed interest in also participating in 2nd close',
#    'type': 2,
#    'created_at': '2024-10-20T06:05:47.134-07:00',
#    'updated_at': None},
#   {'id': 21485753,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [90419170],
#    'parent_id': None,
#    'content': 'Has his own fund (Bluegrass) which is an LP in Picus Capital. We did not contact him at 1st close.',
#    'type': 2,
#    'created_at': '2024-10-20T06:04:21.314-07:00',
#    'updated_at': None},
#   {'id': 21485742,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [90755976],
#    'parent_id': None,
#    'content': 'Shows interest in 2nd close. Will review the materials.',
#    'type': 2,
#    'created_at': '2024-10-20T06:03:00.565-07:00',
#    'updated_at': None},
#   {'id': 21485740,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [94281996],
#    'parent_id': None,
#    'content': 'Vader heeft mogelijk interesse',
#    'type': 2,
#    'created_at': '2024-10-20T06:01:47.682-07:00',
#    'updated_at': None},
#   {'id': 21485650,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [90431432],
#    'parent_id': None,
#    'content': 'Passed on 1st and 2nd close.\n\n\n\nHowever, following internal discussions, we have decided to pass. We would like to be transparent with you and provide you with our key reasons not to invest:\n\n* Fund size of €20m with maximum commitments of €1m. This is at the lower end of our investment focus and would not justify constant monitoring/an involvement.\n\n* High reliance on you – in both Capital and Studio. We believe that the strategy of building 3-5 companies and invest in 12 companies might lead to some conflict in prioritisation and be a stretch.\n\n* First time fund with no previous experience or track record as a fund manager.\n\n* Potential conflict between Studio and Capital, despite the Supervisory Committee (even if we were part of it).',
#    'type': 2,
#    'created_at': '2024-10-20T04:40:50.628-07:00',
#    'updated_at': None},
#   {'id': 21485647,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [90754577],
#    'parent_id': None,
#    'content': 'Contacted him for 2nd close',
#    'type': 2,
#    'created_at': '2024-10-20T04:38:50.475-07:00',
#    'updated_at': None},
#   {'id': 21485646,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [90755976],
#    'parent_id': None,
#    'content': 'Passed on 1st close.',
#    'type': 2,
#    'created_at': '2024-10-20T04:38:17.260-07:00',
#    'updated_at': None},
#   {'id': 21485643,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [90809097],
#    'parent_id': None,
#    'content': 'Did a follow up after they declined on 1st close.',
#    'type': 2,
#    'created_at': '2024-10-20T04:34:01.668-07:00',
#    'updated_at': None},
#   {'id': 21485640,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [90995270],
#    'parent_id': None,
#    'content': 'Sun also has a startup in health tech.',
#    'type': 2,
#    'created_at': '2024-10-20T04:27:53.277-07:00',
#    'updated_at': None},
#   {'id': 21485639,
#    'creator_id': 166190605,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [],
#    'opportunity_ids': [90418870],
#    'parent_id': None,
#    'content': 'Indicated he cannot do 250K but likely smaller ticket. Maybe together with Roeland',
#    'type': 2,
#    'created_at': '2024-10-20T04:26:38.149-07:00',
# ...
#    'updated_at': None},
#   {'id': 20528532,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [293164106],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 16/08/2024',
#    'type': 2,
#    'created_at': '2024-08-16T05:46:30.497-07:00',
#    'updated_at': None},
#   {'id': 20528530,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [285800630],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 16/08/2024',
#    'type': 2,
#    'created_at': '2024-08-16T05:46:26.378-07:00',
#    'updated_at': None},
#   {'id': 20528428,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [294624335],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 16/08/2024',
#    'type': 2,
#    'created_at': '2024-08-16T05:37:18.143-07:00',
#    'updated_at': None},
#   {'id': 20528397,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [289544860],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 16/08/2024',
#    'type': 2,
#    'created_at': '2024-08-16T05:33:06.696-07:00',
#    'updated_at': None},
#   {'id': 20528365,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [291720631],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 16/08/2024',
#    'type': 2,
#    'created_at': '2024-08-16T05:24:33.036-07:00',
#    'updated_at': None},
#   {'id': 20528353,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [295326980],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 16/08/2024',
#    'type': 2,
#    'created_at': '2024-08-16T05:21:57.247-07:00',
#    'updated_at': None},
#   {'id': 20528333,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [290901012],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 16/08/2024',
#    'type': 2,
#    'created_at': '2024-08-16T05:16:31.695-07:00',
#    'updated_at': None},
#   {'id': 20528313,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [296557642],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Check reminder',
#    'type': 2,
#    'created_at': '2024-08-16T05:12:05.221-07:00',
#    'updated_at': None},
#   {'id': 20528303,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [293412133],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 16/08/2024',
#    'type': 2,
#    'created_at': '2024-08-16T05:08:58.022-07:00',
#    'updated_at': None},
#   {'id': 20528297,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [287122474],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'check reminder',
#    'type': 2,
#    'created_at': '2024-08-16T05:05:54.033-07:00',
#    'updated_at': None},
#   {'id': 20528296,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [296474629],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Check the reminder',
#    'type': 2,
#    'created_at': '2024-08-16T05:05:09.247-07:00',
#    'updated_at': None},
#   {'id': 20528293,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [293278520],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Check the reminder',
#    'type': 2,
#    'created_at': '2024-08-16T05:04:27.008-07:00',
#    'updated_at': None},
#   {'id': 20528291,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [282404332],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 16/08/2024',
#    'type': 2,
#    'created_at': '2024-08-16T05:03:57.975-07:00',
#    'updated_at': None},
#   {'id': 20528267,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [297834819],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'To contact in Q1 2025',
#    'type': 2,
#    'created_at': '2024-08-16T04:57:15.854-07:00',
#    'updated_at': None},
#   {'id': 20528236,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [294378911],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': "Founders\n\n* **Boran Cakir** - Co-Founder and CEO\n\n* **Anatoly \\[Last Name Not Provided\\]** - Co-Founder and CTO\n\nFounder USP\n\nBoran brings extensive experience in retail operations, having worked with companies like Aldi and Gopuff. His deep understanding of the challenges in retail operations, combined with Anatoly\\'s technical expertise in full-stack development, positions them to tackle inefficiencies in the retail sector effectively.\n\nFounding Story\n\nFrnt was founded after Boran and Anatoly connected through the Antler program in October 2023. Having recognized the inefficiencies in retail operations during his career, Boran teamed up with Anatoly to build a solution that could streamline these processes. They validated the problem through extensive customer interviews and started working full-time on the product in January 2024.\n\nShort Background of the Company\n\nFrnt is a B2B SaaS platform that focuses on improving operational efficiency in retail. The platform integrates various retail systems into a unified data layer, generating actionable insights and automating workflows. The company started full-time operations in January 2024 after securing initial funding from Antler. Frnt has already integrated with twelve solutions and is currently running pilot programs with three companies, with plans to convert these pilots into revenue-generating contracts by October 2024.\n\nProblem\n\n**Problem They\\'re Addressing** Frnt addresses the inefficiencies in retail operations caused by disjointed systems and manual processes. Retailers often use multiple platforms to manage operations, leading to wasted time and resources. Frnt’s platform unifies these systems, automates workflows, and generates insights, helping retailers improve operational efficiency and reduce costs.\n\n**ARR**\n\n* **End of Last Year**: The company was in the early development phase with no ARR.\n\n* **Target for This Year**: Frnt aims to start generating revenue by October 2024, with an initial MRR target of £1.3k, increasing to £2k by the end of the year\u200b.\n\n* **Target for Next Year**: The goal is to raise ARR significantly as the company transitions pilots into paying customers and expands its customer base\u200b.\n\n**Churn** As the company is in the early stages, churn data is not yet available.\n\nProduct\n\n**Product 1-Liner** Frnt is a retail operations platform that unifies systems, automates workflows, and generates actionable insights to improve efficiency and reduce operational costs.\n\n**How is Product Adoption?** Frnt is currently running pilot programs with three companies and is in discussions to close a fourth. The company expects to start generating revenue from these pilots by October 2024. Additionally, Frnt has integrated with twelve retail solutions, making the platform more attractive to potential customers\u200b.\n\nMarket\n\n**What Space is the Company In?** Frnt operates in the retail technology space, focusing on operational efficiency and data management for medium to large retailers.\n\n**Market Size?** The market for retail operations technology is significant, particularly as retailers seek to improve efficiency and reduce costs in a highly competitive industry. Frnt’s focus on medium-sized retailers initially provides a quicker sales cycle, with plans to target larger enterprises as the product matures\u200b.\n\nIP\n\n**Do They Have Meaningful IP?** Frnt’s IP includes its proprietary data management and workflow automation technology, which integrates various retail systems into a unified platform.\n\n**Who Owns the IP?** The IP is owned by Frnt, with development led by Anatoly and the technical team\u200b.\n\nWhy You?\n\n**Why is this company well-suited for the founders?** Boran’s extensive experience in retail operations, combined with Anatoly’s technical expertise, makes them well-suited to address the inefficiencies in retail. Their complementary skills ensure that both the busin ...
#    'type': 2,
#    'created_at': '2024-08-16T04:48:13.533-07:00',
#    'updated_at': '2024-08-31T13:31:57.757-07:00'},
#   {'id': 20526756,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [225207638],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Close to Henchman, can go?',
#    'type': 2,
#    'created_at': '2024-08-16T01:24:20.876-07:00',
#    'updated_at': None},
#   {'id': 20499740,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [290953074],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 14/08/2024',
#    'type': 2,
#    'created_at': '2024-08-14T10:35:09.781-07:00',
#    'updated_at': None},
#   {'id': 20499705,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [290321406],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 14/08/2024',
#    'type': 2,
#    'created_at': '2024-08-14T10:32:00.929-07:00',
#    'updated_at': None},
#   {'id': 20499525,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [292867222],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 14/08/2024',
#    'type': 2,
#    'created_at': '2024-08-14T10:15:04.712-07:00',
#    'updated_at': None},
#   {'id': 20499369,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [265118957],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 12/08/2024',
#    'type': 2,
#    'created_at': '2024-08-14T10:01:13.250-07:00',
#    'updated_at': None},
#   {'id': 20499368,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [295223170],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 12/08/2024',
#    'type': 2,
#    'created_at': '2024-08-14T10:01:08.268-07:00',
#    'updated_at': None},
#   {'id': 20499364,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [290247586],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 12/08/2024',
#    'type': 2,
#    'created_at': '2024-08-14T10:00:45.160-07:00',
#    'updated_at': None},
#   {'id': 20499361,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [284874004],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 12/08/2024',
#    'type': 2,
#    'created_at': '2024-08-14T10:00:38.022-07:00',
#    'updated_at': None},
#   {'id': 20499357,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [291182156],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'Contacted on 14/08/2024',
#    'type': 2,
#    'created_at': '2024-08-14T10:00:16.641-07:00',
#    'updated_at': None},
#   {'id': 20499255,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [287970424],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'waiting for a reply / Contacted on 31/07/2024',
#    'type': 2,
#    'created_at': '2024-08-14T09:53:59.085-07:00',
#    'updated_at': None},
#   {'id': 20499243,
#    'creator_id': 187372706,
#    'person_ids': [],
#    'associated_person_ids': [],
#    'interaction_person_ids': [],
#    'interaction_id': None,
#    'interaction_type': None,
#    'is_meeting': False,
#    'mentioned_person_ids': [],
#    'organization_ids': [289345649],
#    'opportunity_ids': [],
#    'parent_id': None,
#    'content': 'waiting for a reply / Contacted on 31/07/2024',
#    'type': 2,
#    'created_at': '2024-08-14T09:53:26.775-07:00',
#    'updated_at': None}],
#  'next_page_token': 'eyJwYXJhbXMiOnt9LCJwYWdlX3NpemUiOjUwMCwib2Zmc2V0Ijo1MDB9'}

# %%
url = f"https://api.affinity.co/organizations/fields"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
fields = response.json()
for field in fields:
    if field.get("name", "") == "Tag":
        field_id = field.get("id", "")

curl -X POST "https://api.affinity.co/organizations" \
   -u :$APIKEY \
   -H "Content-Type: application/json" \
   -d '{"name": "Acme Corporation", "domain": "acme.co", "person_ids": [38706]}'
Example Response

{
  "id": 120611418,
  "name": "Acme Corporation",
  "domain": "acme.co",
  "domains": ["acme.co"],
  "global": false,
  "person_ids": [38706]
}

global with field_id = New tag
# Out:
# {'id': 4696722, 'name': 'Tag', 'list_id': None, 'enrichment_source': 'none', 'value_type': 2, 'allows_multiple': True, 'track_changes': False, 'dropdown_options': [{'id': 16673587, 'text': 'CBE Oktober', 'rank': 0, 'color': 0}, {'id': 16650877, 'text': 'Cbe_screen (2) F', 'rank': 0, 'color': 0}, {'id': 16652444, 'text': 'Combined_startups_urls', 'rank': 0, 'color': 0}, {'id': 15091553, 'text': 'Erwan Shared Dealflow', 'rank': 0, 'color': 0}, {'id': 15290235, 'text': 'Evert VC share 26/09', 'rank': 0, 'color': 0}, {'id': 16691204, 'text': "Ghent Slush'D 2024", 'rank': 0, 'color': 0}, {'id': 16690887, 'text': 'Health_Tech_101824_One_Pager_18-10-2024', 'rank': 0, 'color': 0}, {'id': 16544171, 'text': 'HF0', 'rank': 0, 'color': 0}, {'id': 16416172, 'text': 'Miles Ahead', 'rank': 0, 'color': 0}, {'id': 16696612, 'text': 'Ping Evert', 'rank': 0, 'color': 0}, {'id': 16696623, 'text': 'Ping Tibe', 'rank': 0, 'color': 0}, {'id': 16514649, 'text': 'Pipeline review', 'rank': 0, 'color': 0}, {'id': 16671074, 'text': 'Plug & Play University Of Oxford 10 16 2024', 'rank': 0, 'color': 0}, {'id': 16697795, 'text': 'To Screen', 'rank': 0, 'color': 0}, {'id': 15023041, 'text': 'Wintercircus Campus', 'rank': 0, 'color': 0}, {'id': 16697132, 'text': 'YAYAYA', 'rank': 0, 'color': 0}]}

# %%
def create_organization(name, website_url):
    prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
    for prefix in prefixes:
        if website_url.startswith(prefix):
            website_url = website_url[len(prefix):]
            break

    url = "https://api.affinity.co/organizations"
    data = {'name': name, 'domain': website_url}

    response = requests.post(url, auth=HTTPBasicAuth('', api_key), json=data)
    organization = response.json()
    organization_id = organization.get('id')
    return organization_id

# %%
create_organization("NewTestCompany", "NewTestCompany.com")
# Out:
# {'id': 299266107,
#  'name': 'NewTestCompany',
#  'domain': 'newtestcompany.com',
#  'domains': ['newtestcompany.com'],
#  'crunchbase_uuid': None,
#  'global': False,
#  'person_ids': []}

# %%
website_url = "https://neo-mobility.be"

prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
for prefix in prefixes:
    if website_url.startswith(prefix):
        website_url = website_url[len(prefix):]
        break

# %%
url = f"https://api.affinity.co/field-values?organization_id={organization_id}"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
print(response.json())
organizations = response.json().get("organizations", [])
for organization in organizations:
    if organization.get('domain') == website_url:
        organisation_id = organization.get('id')
# Out:
# [{'id': 13567512466, 'field_id': 4768744, 'list_entry_id': 172098674, 'entity_type': 1, 'value_type': 7, 'entity_id': 299266107, 'created_at': '2024-10-22T09:04:09.250-07:00', 'updated_at': None, 'value': {'id': 16696433, 'text': 'New', 'rank': 1, 'color': 1}}]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 4
#       2 response = requests.get(url, auth=HTTPBasicAuth('', api_key))
#       3 print(response.json())
# ----> 4 organizations = response.json().get("organizations", [])
#       5 for organization in organizations:
#       6     if organization.get('domain') == website_url:
#
# AttributeError: 'list' object has no attribute 'get'

# %%
organisation_id = 1687144

# %%
def update_affinity_field(company_info):
    # Clean up the website URL by removing prefixes
    website_url = company_info.get("Website URL")
    prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
    for prefix in prefixes:
        if website_url.startswith(prefix):
            website_url = website_url[len(prefix):]
            break

    # Find the organization by domain
    url = f"https://api.affinity.co/organizations?term={website_url}"
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    organizations = response.json().get("organizations", [])
    organization_id = None
    for organization in organizations:
        if organization.get('domain') == website_url:
            organization_id = organization.get('id')
            break

    # Get the list fields
    url = f'https://api.affinity.co/lists/{list_id}'
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    list_fields = response.json().get("fields", [])

    url = f"https://api.affinity.co/lists/{list_id}/list-entries"
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    list_entries = response.json()
    list_entry_id = None
    for list_entry in list_entries:
        entity = list_entry.get('entity', {})
        entity_domain = entity.get('domain', '')
        if entity_domain == website_url:
            list_entry_id = list_entry.get('id')
            break

    # For each field in the list, update it with the corresponding value from company_info
    for list_field in list_fields:
        field_name = list_field.get("name")
        field_id = list_field.get("id")
        if field_name in company_info:
            new_value = company_info[field_name]
            dropdown_options = list_field.get('dropdown_options', [])
            if dropdown_options:
                dropdown_option_id = None
                for option in dropdown_options:
                    if option.get('text') == new_value:
                        new_value = option.get('id')
                        break

            # Get existing field values for the organization
            url = f"https://api.affinity.co/field-values?organization_id={organization_id}"
            response = requests.get(url, auth=HTTPBasicAuth('', api_key))
            organization_fields = response.json()
            field_value_id = None
            for field_value in organization_fields:
                if field_value.get("field_id") == field_id:
                    field_value_id = field_value.get("id")
                    break
            if field_value_id:
                # Update existing field value
                url = f"https://api.affinity.co/field-values/{field_value_id}"
                data = {'value': new_value}
                response = requests.put(url, auth=HTTPBasicAuth('', api_key), json=data)
            else:
                url = "https://api.affinity.co/field-values"
                data = {'field_id': field_id, 'value': new_value, 'entity_id': organization_id, 'list_entry_id': list_entry_id}
                response = requests.post(url, auth=HTTPBasicAuth('', api_key), json=data)

    return

# %%
company_info = {"Website URL": "psg.fr", "Test": "Ok boy", 'Status': "To be contacted"}
update_affinity_field(company_info)
# Out:
# 16696435 4768744
# Ok boy 4769046

# %%
import requests
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
api_key = os.getenv("AFFINITY_API_KEY")

list_id = 271745

def create_organization(name, website_url):
    # Remove all prefixes from website_url
    prefixes = ['https://', 'http://', 'https://www.', 'http://www.', 'www.']
    for prefix in prefixes:
        if website_url.startswith(prefix):
            website_url = website_url[len(prefix):]
            break

    url = "https://api.affinity.co/organizations"
    data = {
        'name': name,
        'domain': website_url
    }

    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    organization = response.json()
    organization_id = organization.get('id')
    return organization_id

def create_list_entry(organization_id):
    url = f"https://api.affinity.co/lists/{list_id}/list-entries"
    headers = {
        'Content-Type': 'application/json',
        'X-API-Key': api_key
    }
    data = {
        'entity_id': organization_id
    }

    response = requests.post(url, headers=headers, json=data)
    if response.status_code == 201:
        return
    else:
        print(f"Error adding organization to list: {response.text}")
        return

def update_status_field(organization_id):
    # Get the field ID for the "Status" field
    field_id = get_field_id("Status")
    if not field_id:
        print("Status field not found.")
        return

    url = "https://api.affinity.co/field-values"
    headers = {
        'Content-Type': 'application/json',
        'X-API-Key': api_key
    }
    data = {
        'field_id': field_id,
        'organization_id': organization_id,
        'value': 'To Screen'
    }

    response = requests.post(url, headers=headers, json=data)
    if response.status_code in [200, 201]:
        return
    else:
        print(f"Error updating status field: {response.text}")
        return

def get_field_id(field_name):
    url = "https://api.affinity.co/fields"
    headers = {
        'X-API-Key': api_key
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        fields = response.json()
        for field in fields:
            if field['name'] == field_name:
                return field['id']
    else:
        print(f"Error fetching fields: {response.text}")
    return None

def add_company_to_affinity(company_info):
    name = company_info.get("Name")
    website_url = company_info.get("Website URL")

    organization_id = create_organization(name, website_url)
    if organization_id:
        create_list_entry(organization_id)
        update_status_field(organization_id)
    return

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("AFFINITY_API_KEY") 

list_id = 271745

# %%
def create_organization(name, website_url):

    remove all https://, http://, http://www., https://www., www. from website_url
    
curl -X POST "https://api.affinity.co/organizations" \
   -u :$APIKEY \
   -H "Content-Type: application/json" \
   -d '{"name": name, "domain": website_url
    
    return organization_id

# %%
def create_list_entry(organization_id):

    curl -X POST “https://api.affinity.co/lists/{list_id}/list-entries” \
   -u :$APIKEY \
   -H "Content-Type: application/json" \
   -d '{"entity_id": organization_id}'
    
    return

# %%
def update_field(organization_id, list_id):

    url = f'https://api.affinity.co/fields?list_id={list_id}'
    all_list_fields = requests.get(url, auth=HTTPBasicAuth('', api_key))
    
    for field_name in company_info:
        field_id = all_list_fields.get("id", "") where all_list_fields.get("name", "") == field_name

    return

# %%
def find a name to say that I add a company to affinity but stay short(company_info)
    company_info.get("Name" and "Website URL")
    organization_id = create_organization(name, website_url)
    update_field(organization_id, list_id)
    return

# %%
def update_field(organization_id, list_id):

    url = f'https://api.affinity.co/fields?list_id={list_id}'
    all_list_fields = requests.get(url, auth=HTTPBasicAuth('', api_key))
    
    for field_name in company_info:
        field_id = all_list_fields.get("id", "") where all_list_fields.get("name", "") == field_name
    
    


        
        field_id = get_field_id(field_name, headers)
    if not field_id:
        return f"Field '{field_name}' not found."

    organization_id = company_info['organization_id']

    # Step 2: Check if a field value already exists for the organization
    existing_field_value = get_existing_field_value(organization_id, field_id, headers)

    if existing_field_value:
        # Step 3: Update the existing field value
        field_value_id = existing_field_value['id']
        url = f'https://api.affinity.co/field-values/{field_value_id}'
        data = {'value': 'To Screen'}
        response = requests.patch(url, headers=headers, json=data)
    else:
        # Step 4: Create a new field value
        url = 'https://api.affinity.co/field-values'
        data = {
            'field_id': field_id,
            'organization_id': organization_id,
            'value': 'To Screen'
        }
        response = requests.post(url, headers=headers, json=data)

    if response.status_code in [200, 201]:
        return "Affinity updated successfully"
    else:
        return f"Error updating Affinity: {response.text}"

def get_existing_field_value(organization_id, field_id, headers):
    url = f'https://api.affinity.co/organizations/{organization_id}/field-values'
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return None
    field_values = response.json()
    for fv in field_values:
        if fv['field']['id'] == field_id:
            return fv
    return None

# %%
url = 'https://api.affinity.co/fields'

# %%
url = f'https://api.affinity.co/organizations/{oragnization_id}'
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
person_ids = response.json().get("person_ids")
for person_id in person_ids:
    url = f'https://api.affinity.co/persons/{person_id}'
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    "FirstName" = response.json().get("first_name")
    "LastName" = response.json().get("last_name")
    "Email" = response.json().get("primary_email" if not emails[0])
# Out:
# {'id': 166524725, 'type': 0, 'first_name': 'Wim', 'last_name': 'Vernaeve', 'primary_email': 'wim.vernaeve@gmail.com', 'emails': ['wim.vernaeve@gmail.com', 'wim.vernaeve@greenparkinvest.com', 'wim.vernaeve@googlemail.com', 'wim@bragster.com', 'wim_vernaeve@hotmail.com', 'mlnamc17tpfh20u0vp25fsrmn4@group.calendar.google.com'], 'organization_ids': [1516330, 1687144, 163299958], 'list_entries': []}
# {'id': 168464200, 'type': 0, 'first_name': 'NoName', 'last_name': 'Inthepocket.mobi@allusers.d.calendar.google.com', 'primary_email': 'inthepocket.mobi@allusers.d.calendar.google.com', 'emails': ['inthepocket.mobi@allusers.d.calendar.google.com'], 'organization_ids': [1687144], 'list_entries': []}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 6
#       4 for person_id in person_ids:
#       5     url = f'https://api.affinity.co/persons/{person_id}'
# ----> 6     response = requests.get(url, auth=HTTPBasicAuth('', api_key))
#       7     print(response.json())
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#     730 response_conn = conn if not release_conn else None
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463             httplib_response = conn.getresponse()
#     464         except BaseException as e:
#     465             # Remove the TypeError from the exception chain in
#     466             # Python 3 (including for exceptions like SystemExit).
#     467             # Otherwise it looks like a bug in the code.
# --> 468             six.raise_from(e, None)
#     469 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     470     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:463, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 except TypeError:
#     461     # Python 3
#     462     try:
# --> 463         httplib_response = conn.getresponse()
#     464     except BaseException as e:
#     465         # Remove the TypeError from the exception chain in
#     466         # Python 3 (including for exceptions like SystemExit).
#     467         # Otherwise it looks like a bug in the code.
#     468         six.raise_from(e, None)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.6/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
person_ids = response.json().get("person_ids")
for person_id in person_ids:
    url = f'https://api.affinity.co/persons/{person_id}'
    response = requests.get(url, auth=HTTPBasicAuth('', api_key))
    print(response.json())

# %%
url = f"{base_url}/lists/{list_id}/list-entries"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))

response.json()
# Out:
# [{'id': 171964735,
#   'list_id': 271745,
#   'creator_id': 185792297,
#   'entity_id': 224088093,
#   'entity_type': 1,
#   'created_at': '2024-10-21T06:10:54.842-07:00',
#   'entity': {'id': 224088093,
#    'name': 'Cytocast',
#    'domain': 'cytocast.com',
#    'domains': ['cytocast.com'],
#    'crunchbase_uuid': None,
#    'global': True}},
#  {'id': 171964736,
#   'list_id': 271745,
#   'creator_id': 185792297,
#   'entity_id': 299211990,
#   'entity_type': 1,
#   'created_at': '2024-10-21T06:10:54.842-07:00',
#   'entity': {'id': 299211990,
#    'name': 'Neo mobility',
#    'domain': 'neo-mobility.be',
#    'domains': ['neo-mobility.be'],
#    'crunchbase_uuid': None,
#    'global': False}},
#  {'id': 171705227,
#   'list_id': 271745,
#   'creator_id': 185792297,
#   'entity_id': 1687144,
#   'entity_type': 1,
#   'created_at': '2024-10-18T05:25:21.785-07:00',
#   'entity': {'id': 1687144,
#    'name': 'Google',
#    'domain': 'google.com',
#    'domains': ['google.com',
#     'greenparrotpictures.com',
#     'newsinitiative.withgoogle.com',
#     'infinitypocket.blogspot.in',
#     'midnightboom.blogspot.co.uk'],
#    'crunchbase_uuid': None,
#    'global': True}},
#  {'id': 171704891,
#   'list_id': 271745,
#   'creator_id': 185792297,
#   'entity_id': 294139876,
#   'entity_type': 1,
#   'created_at': '2024-10-18T05:12:46.467-07:00',
#   'entity': {'id': 294139876,
#    'name': 'Tekst.ai',
#    'domain': 'tekst.com',
#    'domains': ['tekst.com'],
#    'crunchbase_uuid': None,
#    'global': True}}]

# %%
url = f"{base_url}/field-values?organization_id=224088093"
response = requests.get(url, auth=HTTPBasicAuth('', api_key))
response.json()
# Out:
# [{'id': 13542527317,
#   'field_id': 4711807,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 7,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': {'id': 16671075, 'text': 'To Screen', 'rank': 7, 'color': 0}},
#  {'id': 13542527318,
#   'field_id': 4711827,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': 'Advanced simulation technology for drug discovery and personalized medicine using multi-omics data.'},
#  {'id': 13542527319,
#   'field_id': 4711828,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': 'TechBio'},
#  {'id': 13542527320,
#   'field_id': 4711829,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': '-'},
#  {'id': 13542527321,
#   'field_id': 4733935,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': 'B2B'},
#  {'id': 13542527322,
#   'field_id': 4733936,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': 'Subscription'},
#  {'id': 13542527323,
#   'field_id': 4761134,
#   'list_entry_id': 171673564,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:15.900-07:00',
#   'updated_at': None,
#   'value': '{\'https://www.cytocast.com\': "H1: Home\\nH1: Imagine...a world where new therapies can be discovered and developed in a fraction of what it takes now.\\nH1: How can we help?\\nH1: People and Values\\nH1: How we do it\\nH1: 0\\nH1: 0\\nH1: 0\\nH1: 0\\nH1: News\\nH1: Blog\\nH1: Interested in a demo?\\nH2: Drug Discovery\\nH2: Precision medicine\\nH2: MAKE MEDICINE BETTER WITH ADVANCED CELL SIMULATION TECHNOLOGY\\nH2: Cytocast is using computer simulations to determine the most effective treatment for patients while minimazing potential side effects\\nH2: Proteins per simulation\\nH2: Protein-protein interactions\\nH2: Binding sites per simulation\\nH2: Nr. of cell types\\nH3: OUR VALUES\\nH3: THE TEAM\\nPARAGRAPH: Join our pilot study partnership to test Cytocast Simulated Cell!\\nPARAGRAPH: a world where new therapies can be discovered and developed in a fraction of what it takes now.\\nPARAGRAPH: Cytocast is an emerging TechBio startup based in Budapest that  specializes in data-driven medical technology. We leverage this data to  add value and achieve impactful results.\\nPARAGRAPH: We are proud to be a company with a curious mindset and a strong research orientation.  What sets us apart is the way we integrate multi-omics data, extensive scientific knowledge, expertise, high-performance computing, and cutting-edge data science methods to maximize insights into patient biology and accelerate the pace of drug discovery and development.  We also have the privilege of working with numerous collaborative partners.  We value these partnerships and recognize their importance in advancing our mission.\\nPARAGRAPH: At Cytocast, we believe in creative solutions and in the power of teamwork in a familiar atmosphere. Many of our team members have university affiliations continually exploring new possibilities.\\nPARAGRAPH: Last week, we had the pleasure of presenting Cytocast\'s cutting-edge technology at the 4th Digital Health Summit as the Best Solution in the Digital Therapy category winner.\\nPARAGRAPH: We are thrilled to announce that we have successfully secured our second investment round...\\nPARAGRAPH: Cytocast team recently participated in the Hungarian Molecular Life Science Conference held in Eger. The conference...\\nPARAGRAPH: Cytocast\\xa0 has made significant strides during the second quarter of 2024, advancing its cutting-edge technology in the field of digital twin simulations and predictive algorithms.\\nPARAGRAPH: Cytocast, at the forefront of innovation, utilizes AI in the Cytocast Simulated Cell to model drug-target interactions, predict efficacy, and identify potential side effects early in drug development. Our commitment extends to ethical considerations, ensuring responsible AI use in shaping the future of drug discovery.\\nPARAGRAPH: Get in touch today to see how the Cytocast platform works.", \'https://www.cytocast.com/cytocast-digital-twin/\': "H1: No Title\\nPARAGRAPH: Join our pilot study partnership to test Cytocast Simulated Cell!\\nH1: Transforming Patient CareEmbark on a groundbreaking journey towards personalized medicine with Cytocast Digital Twin. Our revolutionary technology combines multi-omics data and patient-specific clinical information to create an exact digital replica of each individual.\\nPARAGRAPH: Embark on a groundbreaking journey towards personalized medicine with Cytocast Digital Twin. Our revolutionary technology combines multi-omics data and patient-specific clinical information to create an exact digital replica of each individual.\\nH1: Cytocast™ Digital Twin\\nPARAGRAPH: We use data to add value and generate meaningful results thatdrive positive technological progress in precision medicine. Our aim with Cytocast™ Digital Twin is to significantly improve treatment efficacy and provide patients with effective therapeutic options.\\n**drive positive technological progress in precision medicine**\\nPARAGRAPH: Our latest breakthrough technology, the Cytocast™ Digital Twi ...
#  {'id': 13542527640,
#   'field_id': 3909160,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.221-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527645,
#   'field_id': 3909163,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.265-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527650,
#   'field_id': 3909164,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.305-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527668,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527666,
#   'field_id': 3909168,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 5,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.338-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527670,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527671,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527672,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527673,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527674,
#   'field_id': 3909161,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.356-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527683,
#   'field_id': 3909169,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 4,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.418-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527693,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527694,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527695,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527709,
#   'field_id': 3909166,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.488-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527697,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527698,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527699,
#   'field_id': 3909162,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.426-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527719,
#   'field_id': 3909165,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.525-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527724,
#   'field_id': 3909167,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.553-07:00',
#   'updated_at': None,
#   'value': None},
#  {'id': 13542527729,
#   'field_id': 3909177,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.595-07:00',
#   'updated_at': None,
#   'value': 2340900.0},
#  {'id': 13542527743,
#   'field_id': 3909178,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.638-07:00',
#   'updated_at': None,
#   'value': 1836000.0},
#  {'id': 13542527772,
#   'field_id': 3909175,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.827-07:00',
#   'updated_at': None,
#   'value': 15.0},
#  {'id': 13542527752,
#   'field_id': 3909174,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.696-07:00',
#   'updated_at': None,
#   'value': "Cytocast is a TechBio startup company pioneering the future of drug development with its revolutionary Cytocast Simulated Cell platform. We're transforming the landscape by enabling safer and smarter drug development, putting patient well-being at the forefront. By combining multi-omics data integration with advanced computational modeling, we're redefining drug development. Our platform allows us to predict how different drugs will affect cellular processes, making drug side effect predictions in the early phases of drug development a reality. Our focus extends to the future of personalized medicine. We're advancing beyond one-size-fits-all treatments, embracing tailored therapies powered by advanced technologies to revolutionize drug development."},
#  {'id': 13542527776,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Bioinformatics'},
#  {'id': 13542527777,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Biotechnology'},
#  {'id': 13542527778,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Computer'},
#  {'id': 13542527779,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Pharmaceutical'},
#  {'id': 13542527780,
#   'field_id': 3909172,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.836-07:00',
#   'updated_at': None,
#   'value': 'Simulation'},
#  {'id': 13542527784,
#   'field_id': 3909176,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.865-07:00',
#   'updated_at': None,
#   'value': 2019.0},
#  {'id': 13542527788,
#   'field_id': 3909182,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.910-07:00',
#   'updated_at': None,
#   'value': 'https://linkedin.com/company/cytocast'},
#  {'id': 13542527793,
#   'field_id': 3909179,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 5,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:18.970-07:00',
#   'updated_at': None,
#   'value': {'street_address': None,
#    'city': 'Budapest',
#    'state': 'Budapest',
#    'country': 'Hungary',
#    'continent': None}},
#  {'id': 13542529074,
#   'field_id': 3909195,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.590-07:00',
#   'updated_at': None,
#   'value': 'SaaS'},
#  {'id': 13542529142,
#   'field_id': 3909190,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.778-07:00',
#   'updated_at': None,
#   'value': 'Venture Capital'},
#  {'id': 13542529145,
#   'field_id': 3909190,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.778-07:00',
#   'updated_at': None,
#   'value': 'accelerator'},
#  {'id': 13542529159,
#   'field_id': 3909197,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.821-07:00',
#   'updated_at': None,
#   'value': 2040000.0},
#  {'id': 13542529081,
#   'field_id': 3909194,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.611-07:00',
#   'updated_at': None,
#   'value': 'b2b'},
#  {'id': 13542529140,
#   'field_id': 3909201,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 5,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.770-07:00',
#   'updated_at': None,
#   'value': {'street_address': None,
#    'city': 'Budapest',
#    'state': 'Budapest',
#    'country': 'Hungary',
#    'continent': None}},
#  {'id': 13542529116,
#   'field_id': 3909191,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.678-07:00',
#   'updated_at': None,
#   'value': 'Subscription'},
#  {'id': 13542529153,
#   'field_id': 3909188,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.803-07:00',
#   'updated_at': None,
#   'value': 'Artificial Intelligence'},
#  {'id': 13542529154,
#   'field_id': 3909188,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.803-07:00',
#   'updated_at': None,
#   'value': 'Big Data'},
#  {'id': 13542529176,
#   'field_id': 3909186,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.862-07:00',
#   'updated_at': None,
#   'value': 97.0},
#  {'id': 13542529091,
#   'field_id': 3909199,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.646-07:00',
#   'updated_at': None,
#   'value': 'Simulated cells to shape the future of medicine'},
#  {'id': 13542529102,
#   'field_id': 3909192,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.667-07:00',
#   'updated_at': None,
#   'value': '11-50'},
#  {'id': 13542529120,
#   'field_id': 3909200,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.710-07:00',
#   'updated_at': None,
#   'value': 'Health'},
#  {'id': 13542529121,
#   'field_id': 3909200,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.710-07:00',
#   'updated_at': None,
#   'value': 'Pharmaceutical'},
#  {'id': 13542529122,
#   'field_id': 3909200,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 2,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.710-07:00',
#   'updated_at': None,
#   'value': 'BioTechnology'},
#  {'id': 13542529136,
#   'field_id': 3909196,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.749-07:00',
#   'updated_at': None,
#   'value': 1600000.0},
#  {'id': 13542529165,
#   'field_id': 3909187,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.832-07:00',
#   'updated_at': None,
#   'value': 57.0},
#  {'id': 13542529183,
#   'field_id': 3909185,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.886-07:00',
#   'updated_at': None,
#   'value': 1.0},
#  {'id': 13542529197,
#   'field_id': 3909184,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.916-07:00',
#   'updated_at': None,
#   'value': 53.0},
#  {'id': 13542529200,
#   'field_id': 3909183,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 6,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.929-07:00',
#   'updated_at': None,
#   'value': 'https://app.dealroom.co/companies/cytocast'},
#  {'id': 13542529212,
#   'field_id': 3909198,
#   'list_entry_id': None,
#   'entity_type': 1,
#   'value_type': 3,
#   'entity_id': 224088093,
#   'created_at': '2024-10-18T01:35:33.962-07:00',
#   'updated_at': None,
#   'value': 2019.0}]

# %%
field_value_id = 13542527317  # The field value ID you're trying to update
value = 16696434  # The dropdown ID for 'To Screen'

# Update URL
url = f"{base_url}/field-values/{field_value_id}"

# Correct payload: just send the integer value (dropdown option ID)
payload = {
    "value": {"id": (value)}  # Use the ID of the dropdown option as the value
}

# Make the PUT request to update the field value
response = requests.put(url, json=payload, auth=HTTPBasicAuth('', api_key))

# Check the response
print(response.status_code)
print(response.json())
# Out:
# 422
# ["Field value: Record doesn't have field entity_attribute_id set to 4711807 (Affinity::Validator::HasFieldError)"]

# %%
response.json()
# Out:
# ["Field value: Record doesn't have field entity_attribute_id set to 4711807 (Affinity::Validator::HasFieldError)"]

# %%
Hello,

I have a problem to update the Status field via an API request here is a simple python example:

from the list ID "271745" I want to modify the entity Cytocast here is it's dictionnary:
{'id': 171964735,
  'list_id': 271745,
  'creator_id': 185792297,
  'entity_id': 224088093,
  'entity_type': 1,
  'created_at': '2024-10-21T06:10:54.842-07:00',
  'entity': {'id': 224088093,
   'name': 'Cytocast',
   'domain': 'cytocast.com',
   'domains': ['cytocast.com'],
   'crunchbase_uuid': None,
   'global': True}}

from the Status filed in the API-test list here is it's dictionnary of the field:
[{'id': 13542527317,
  'field_id': 4711807,
  'list_entry_id': 171673564,
  'entity_type': 1,
  'value_type': 7,
  'entity_id': 224088093,
  'created_at': '2024-10-18T01:35:15.900-07:00',
  'updated_at': None,
  'value': {'id': 16671075, 'text': 'To Screen', 'rank': 7, 'color': 0}},

 the field value id is this:
[{'id': 13542527317,
  'field_id': 4711807,
  'list_entry_id': 171673564,
  'entity_type': 1,
  'value_type': 7,
  'entity_id': 224088093,
  'created_at': '2024-10-18T01:35:15.900-07:00',
  'updated_at': None,
  'value': {'id': 16671075, 'text': 'To Screen', 'rank': 7, 'color': 0}},

 But when I try:
    
field_value_id = 13542527317
value = 16696434

# Update URL
url = f"{base_url}/field-values/{field_value_id}"

# Correct payload: just send the integer value (dropdown option ID)
payload = {
    "value": str(value)  # Use the ID of the dropdown option as the value
}

# Make the PUT request to update the field value
response = requests.put(url, json=payload, auth=HTTPBasicAuth('', api_key))

I get:
["Field value: Record doesn't have field entity_attribute_id set to 4711807 (Affinity::Validator::HasFieldError)"]
# Out:
#   Cell In[48], line 5
#     from the list ID "271745" I want to modify the entity Cytocast here is it's dictionnary:
#                                                                              ^
# SyntaxError: unterminated string literal (detected at line 5)
